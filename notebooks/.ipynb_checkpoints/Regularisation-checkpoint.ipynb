# %% [markdown]
# Look at ratio (row/column), If ratio is lower than 15 or 20, We should use ElasticNetCV. ElasticNetCV is required to use scaler first.

# %%
# %matplotlib inline
import pandas

# %%
weather = pandas.read_csv("sydney_climate.csv")
weather
# Out:
#     Year_Month_Day  MANGROVE_MOUNTAIN  GOSFORD  SPRINGWOOD  SYDNEY_AIRPORT  \
# 0       2016-01-02               24.5     24.8        25.2            25.3
# 1       2016-01-03               21.2     23.4        21.0            24.3
# 2       2016-01-04               22.2     24.4        20.1            25.4
# 3       2016-01-05               18.6     20.6        16.2            21.0
# 4       2016-01-06               16.4     19.0        18.4            19.2
# 5       2016-01-07                NaN     23.3        22.5            22.3
# 6       2016-01-08               25.9     25.6        25.8            25.8
# 7       2016-01-09               25.6     24.6        26.3            26.0
# 8       2016-01-10               28.4     27.0        29.8            28.8
# 9       2016-01-11               35.8     33.1        35.0            34.6
# 10      2016-01-12               34.7     34.5        32.8            33.6
# 11      2016-01-13               31.0     30.6        33.1            31.1
# 12      2016-01-14               38.9     39.9        39.0            40.6
# 13      2016-01-15               18.9     21.7        21.4            20.4
# 14      2016-01-16               22.1     23.1        20.0            22.9
# 15      2016-01-17               21.8     23.7        23.5            25.1
# 16      2016-01-18               25.5     25.5        27.0            27.6
# 17      2016-01-19               33.2     30.6        33.0            33.3
# 18      2016-01-20               36.4     38.0        37.5            40.3
# 19      2016-01-21               37.5     37.6        37.2            37.8
# 20      2016-01-22               28.6     28.8        27.8            26.9
# 21      2016-01-23               27.2     27.2        27.5            24.7
# 22      2016-01-24               23.9     25.0        22.0            25.3
# 23      2016-01-25               24.0     25.2        23.4            25.0
# 24      2016-01-26               26.3     27.0        26.6            27.5
# 25      2016-01-27               23.2     24.7        21.8            26.4
# 26      2016-01-28               28.1     28.2        28.2            29.4
# 27      2016-01-29               29.5     29.2        25.6            29.9
# 28      2016-01-30               29.4     28.2        27.0            26.3
# 29      2016-01-31               30.0     31.3        28.8            31.8
# ..             ...                ...      ...         ...             ...
# 182     2016-07-02               15.9     16.7        16.1            18.3
# 183     2016-07-03               15.7     16.9        14.9            18.0
# 184     2016-07-04               16.7     18.1        12.4            15.8
# 185     2016-07-05               16.5     18.6        15.0            19.1
# 186     2016-07-06               14.4     17.2        15.2            18.4
# 187     2016-07-07               14.7     17.1        15.7            17.2
# 188     2016-07-08               14.1     15.5        14.6            17.6
# 189     2016-07-09               15.9     17.6        16.1            16.7
# 190     2016-07-10               16.8     17.5        15.4            19.0
# 191     2016-07-11               20.9     22.1        16.9            19.6
# 192     2016-07-12               18.0     19.6        17.5            21.4
# 193     2016-07-13               12.6     14.4        12.0            14.5
# 194     2016-07-14               15.2     16.7        16.4            17.3
# 195     2016-07-15               15.8     16.8        15.0            17.1
# 196     2016-07-16               15.6     17.7        16.6            17.4
# 197     2016-07-17               14.7     18.1        17.2            20.1
# 198     2016-07-18               22.2     23.9        23.1            25.3
# 199     2016-07-19               22.9     23.5        24.5            25.7
# 200     2016-07-20               16.3     17.3        15.5            16.8
# 201     2016-07-21               16.4     19.9        18.6            19.8
# 202     2016-07-22               23.1     24.9        24.0            27.0
# 203     2016-07-23               15.4     17.6        14.5            18.7
# 204     2016-07-24               10.4     12.8        12.4            15.3
# 205     2016-07-25               15.4     17.6        15.4            18.8
# 206     2016-07-26               17.8     19.4        18.0            18.7
# 207     2016-07-27               16.9     18.8        16.0            19.6
# 208     2016-07-28               17.2     18.9        18.2            20.4
# 209     2016-07-29               17.3     18.6        17.2            19.7
# 210     2016-07-30               17.5     18.5        17.0            18.4
# 211     2016-07-31               20.6     20.5        17.5            21.0
#
#      TERREY_HILLS  SYDNEY  PARRAMATTA_NORTH  BANKSTOWN_AIRPORT  \
# 0            23.3    25.4              24.9               26.1
# 1             NaN    24.6              25.0               25.6
# 2             NaN    23.6              21.8               23.6
# 3             NaN    20.3              19.8               20.5
# 4             NaN    18.6              19.0               20.0
# 5            21.6    24.4              24.0               25.0
# 6            24.2    25.4              27.0               27.1
# 7            24.6    25.5              27.3               28.4
# 8            26.2    27.1              30.0               30.0
# 9            32.5    31.6              37.2               38.6
# 10           34.1    34.0              34.2               34.4
# 11           30.5    31.0              31.7               31.1
# 12           38.9    39.2              39.0               40.4
# 13           19.7    21.7              21.4               22.0
# 14           21.9    23.8              23.2               23.6
# 15           23.5    26.1              24.2               25.4
# 16           24.7    27.0              27.8               28.5
# 17           30.4    30.2              35.0               35.0
# 18           36.8    37.5              38.0               38.6
# 19           35.8    33.5              38.2               38.6
# 20           28.1    29.2              27.5               28.9
# 21           26.1    26.0              26.5               27.1
# 22           23.4    25.0              25.0               25.3
# 23           23.7    25.2              24.2               24.8
# 24           25.7    27.8              27.4               28.5
# 25           23.0    24.9              24.2               24.9
# 26           27.9    27.6              30.0               30.9
# 27           27.7    28.1              29.2               30.1
# 28           26.5    28.7              28.1               28.2
# 29           28.8    31.1              29.2               29.5
# ..            ...     ...               ...                ...
# 182          15.7    18.2              17.7               17.8
# 183          15.7    18.1              17.2               17.3
# 184          15.6    15.6              15.0               14.7
# 185          17.0    18.8              18.0               18.3
# 186          15.9    17.7              17.6               18.1
# 187          14.9    17.2              16.7               17.1
# 188          14.3    15.6              14.9               15.9
# 189          16.2    18.0              17.2               17.7
# 190          16.8    17.9              18.0               18.7
# 191          19.2    18.6              18.3               19.6
# 192          18.1    20.2              20.2               20.3
# 193          12.6    14.0              14.3               13.9
# 194          14.9    17.0              16.8               16.7
# 195          16.1    17.7              18.0               17.9
# 196          16.8    18.9              18.4               19.0
# 197          18.8    18.8              19.7               20.3
# 198          22.9    24.2              24.0               24.2
# 199           NaN    24.9              25.2               25.0
# 200          15.6    16.9              16.7               16.9
# 201          18.0    19.3              19.4               19.9
# 202          23.8    25.7              25.5               25.8
# 203          15.5    17.4              17.0               17.3
# 204          11.9    14.3              13.3               14.5
# 205          16.0    17.9              17.3               17.7
# 206           NaN    17.9              19.3               19.6
# 207           NaN    18.6              18.2               18.9
# 208           NaN    19.4              19.0               19.3
# 209           NaN    18.5              18.4               19.0
# 210          16.6    19.8              19.1               19.5
# 211          18.8    20.9               NaN               20.8
#
#      HOLSWORTHY_AERODROME      ...       SYDNEY_HARBOUR  PROSPECT_RESERVOIR  \
# 0                    26.2      ...                 22.6                26.1
# 1                    24.1      ...                 22.7                24.0
# 2                    23.5      ...                 23.1                23.0
# 3                    19.9      ...                 20.7                19.2
# 4                    20.5      ...                 19.9                19.7
# 5                    23.8      ...                 21.4                23.8
# 6                    26.6      ...                 23.5                28.6
# 7                    27.1      ...                 23.7                28.5
# 8                    30.2      ...                 23.5                31.3
# 9                    38.2      ...                 27.2                37.7
# 10                   32.8      ...                 27.9                33.5
# 11                   30.2      ...                 25.5                32.0
# 12                   40.6      ...                 32.9                40.0
# 13                   21.4      ...                 20.5                21.3
# 14                   22.7      ...                 21.4                23.2
# 15                   24.6      ...                 23.1                25.0
# 16                   27.7      ...                 24.5                29.2
# 17                   35.2      ...                 26.5                35.9
# 18                   39.1      ...                 29.2                38.7
# 19                   38.7      ...                 30.3                38.4
# 20                   28.2      ...                 27.0                28.0
# 21                   25.9      ...                 25.1                26.7
# 22                   24.3      ...                 23.9                25.0
# 23                   24.4      ...                 24.8                24.0
# 24                   27.4      ...                 24.7                28.7
# 25                   24.6      ...                 23.7                24.7
# 26                   30.4      ...                 24.0                32.2
# 27                   29.6      ...                 25.4                29.3
# 28                   27.6      ...                 26.8                28.9
# 29                   29.8      ...                 29.8                29.7
# ..                    ...      ...                  ...                 ...
# 182                  17.5      ...                 16.8                16.5
# 183                  16.7      ...                 17.3                16.2
# 184                  13.9      ...                 15.3                13.5
# 185                  16.3      ...                 18.0                17.2
# 186                  16.4      ...                 17.3                17.0
# 187                  17.0      ...                 17.8                17.6
# 188                  15.6      ...                 15.8                15.4
# 189                  17.2      ...                 16.4                17.4
# 190                  17.9      ...                 18.0                18.3
# 191                  18.4      ...                 19.6                18.4
# 192                  19.6      ...                 19.5                19.9
# 193                  13.1      ...                 13.5                12.1
# 194                  16.2      ...                 16.0                16.7
# 195                  17.7      ...                 17.4                17.3
# 196                  18.1      ...                 17.6                18.5
# 197                  19.0      ...                 17.8                19.2
# 198                  23.4      ...                 23.6                23.3
# 199                  24.6      ...                 23.1                24.5
# 200                  16.2      ...                 17.3                16.8
# 201                  18.9      ...                 19.5                19.1
# 202                  25.4      ...                 25.2                25.2
# 203                  16.9      ...                 16.9                16.4
# 204                  14.2      ...                 13.0                13.5
# 205                  16.9      ...                 16.8                17.1
# 206                  18.6      ...                 18.7                19.6
# 207                  17.6      ...                 17.5                17.3
# 208                  19.1      ...                 18.3                18.8
# 209                  18.5      ...                 17.9                18.8
# 210                  19.0      ...                 17.8                18.6
# 211                  20.4      ...                 19.8                19.7
#
#      RICHMOND_RAAF  BADGERYS_CREEK  PENRITH_LAKES  \
# 0             26.6            28.8           28.2
# 1             24.3            24.6           23.6
# 2             22.3            22.1           21.1
# 3             19.8            19.3           18.8
# 4             21.2            21.2           21.4
# 5             25.4            25.2           25.1
# 6             28.0            28.8           29.0
# 7             28.8            28.9           29.0
# 8             31.8            32.4           32.4
# 9             36.8             NaN           37.7
# 10            35.7            34.6           34.3
# 11            34.0            33.4           34.3
# 12            40.0            40.8           40.7
# 13            23.0            22.9           22.7
# 14            24.1            22.7           22.8
# 15            24.9            26.5           25.8
# 16            29.2            29.5           29.8
# 17            34.3            35.0           35.0
# 18            37.7            38.9           39.2
# 19            38.6            38.5           40.1
# 20            27.1            27.3           26.9
# 21            28.3            27.6           28.7
# 22            25.0            24.6           24.4
# 23            26.0            24.7           25.5
# 24            29.0            29.2           29.4
# 25            24.9            24.3           24.3
# 26            30.6            31.5           31.4
# 27            28.8            27.8           28.8
# 28            31.0            29.1           30.8
# 29            29.3            28.9           29.4
# ..             ...             ...            ...
# 182           17.6            17.3           17.9
# 183           16.8            17.6           17.1
# 184           14.2            14.3           13.6
# 185           17.9            16.1           15.9
# 186           17.7            17.3           17.3
# 187           18.8            18.1           18.5
# 188           16.7            16.5           16.9
# 189           18.0            17.8           17.7
# 190           18.0            18.8           17.8
# 191           19.4            19.9           19.3
# 192           20.1            20.0           19.4
# 193           14.6            13.6           14.0
# 194           16.9            16.7           17.2
# 195           17.0            18.1           16.7
# 196           17.4            18.9           17.4
# 197           19.5            20.4           19.3
# 198           24.9            24.4           24.0
# 199           25.2            25.2           24.3
# 200           16.4            16.4           16.6
# 201           19.3            19.9           20.8
# 202           25.7            25.7           25.5
# 203           17.2            17.1           16.5
# 204           14.2            14.4           14.4
# 205           17.4            17.0           17.0
# 206           19.7            19.3           18.9
# 207           19.0            18.1           17.8
# 208           19.5            19.6           20.1
# 209           18.3            18.5           18.1
# 210           18.9            19.3           19.3
# 211           20.4            20.6           20.2
#
#      HORSLEY_PARK_EQUESTRIAN_CENTRE  CAMDEN_AIRPORT  BELLAMBI  \
# 0                              26.7            27.5      22.9
# 1                              23.3            24.6      22.9
# 2                              22.8            23.0      22.4
# 3                              18.9            19.8      21.0
# 4                              20.3            21.4      19.6
# 5                               NaN            24.9      21.9
# 6                              27.7            28.3      23.3
# 7                              28.3            28.3      24.5
# 8                              30.6            31.6      24.8
# 9                              36.8            37.6      31.5
# 10                             32.6            34.9      28.0
# 11                             31.9            32.8      29.2
# 12                             39.3            40.2      36.0
# 13                             21.7            22.9      19.9
# 14                             22.8            23.0      20.9
# 15                             25.3            25.6      22.8
# 16                             28.9            29.1      25.0
# 17                             34.6            34.7      30.3
# 18                             37.8            38.4      36.5
# 19                             37.8            36.7      28.0
# 20                             27.5            27.8      25.9
# 21                             26.9            27.5      23.7
# 22                             24.7            25.4      23.9
# 23                             23.5            23.9      23.6
# 24                             27.8            28.6      25.8
# 25                             24.1            23.5      24.0
# 26                             31.4            30.5      25.9
# 27                             28.3            28.0      25.9
# 28                             28.5            29.4      24.7
# 29                             29.0            29.2      25.8
# ..                              ...             ...       ...
# 182                            17.1            17.2      17.7
# 183                            17.2            17.7      18.4
# 184                            14.3            15.1      16.7
# 185                            17.0            15.1      17.6
# 186                            17.1            16.8      16.8
# 187                            17.6            18.0      15.8
# 188                            15.7            16.9      16.3
# 189                            17.2            17.6      16.9
# 190                            18.3            18.5      17.3
# 191                            18.4            21.2      20.1
# 192                            19.4            20.0      19.5
# 193                            13.7            13.3      12.9
# 194                            16.6            16.2      16.3
# 195                            17.7            19.1      16.8
# 196                            18.4            19.2      17.1
# 197                            19.4            20.1      19.3
# 198                            23.6            23.7      24.0
# 199                            24.2            25.6      21.9
# 200                            16.1            16.7      16.3
# 201                            20.2            19.9      17.9
# 202                            25.5            26.0      25.3
# 203                            16.5            17.1      16.2
# 204                            13.6            14.4      14.5
# 205                            17.0            16.8      16.7
# 206                            19.4            18.8      18.6
# 207                            18.1            17.9      17.3
# 208                            19.0            19.2      19.1
# 209                            18.6            18.1      18.7
# 210                            18.9            19.0      16.8
# 211                            20.6            20.4      18.1
#
#      PORT_KEMBLA_NTC  CAMPBELLTOWN
# 0               22.0          27.6
# 1               22.9          24.6
# 2               21.8          23.1
# 3               21.3          20.4
# 4               19.8          20.8
# 5               22.5          24.3
# 6                NaN          28.3
# 7               22.7          28.0
# 8               23.1          31.0
# 9               30.8          37.4
# 10              25.6          34.6
# 11              30.9          32.0
# 12              33.6          39.3
# 13              20.4          22.0
# 14              21.6          22.9
# 15              21.9          25.5
# 16              23.3          28.6
# 17              30.7          34.2
# 18              34.1          37.5
# 19              27.7          36.4
# 20              25.1          27.9
# 21              23.6          27.8
# 22              23.5          24.5
# 23              23.9          23.7
# 24              24.1          28.1
# 25              23.6          24.2
# 26              24.1          30.1
# 27              24.8          28.3
# 28              25.5          28.4
# 29              24.8          28.6
# ..               ...           ...
# 182             17.3          17.1
# 183             18.3          17.5
# 184             15.7          15.0
# 185             16.8          15.5
# 186             16.5          16.9
# 187             15.9          17.6
# 188             16.7          16.2
# 189             17.2          17.6
# 190             17.2          18.9
# 191             20.5          18.5
# 192             19.1          19.8
# 193             12.7          13.0
# 194             15.9          16.4
# 195             17.4          19.0
# 196             16.8          19.6
# 197             19.2          19.9
# 198             23.9          23.4
# 199             22.8          24.8
# 200             16.6          16.1
# 201             19.4          19.8
# 202             25.4          25.7
# 203             15.9          16.4
# 204             14.0          14.2
# 205             15.7          16.3
# 206             17.9          18.7
# 207             16.9          17.9
# 208             18.7          19.1
# 209             18.0          18.2
# 210             17.1          19.4
# 211             18.3          20.2
#
# [212 rows x 21 columns]

# %%
weather[['SYDNEY',"SYDNEY_AIRPORT","MANGROVE_MOUNTAIN"]].plot()

# %%
weather.dropna(inplace=True)

# %%
import seaborn
seaborn.pairplot(weather[['SYDNEY',"SYDNEY_AIRPORT","MANGROVE_MOUNTAIN"]])

# %%
import sklearn.linear_model
lr = sklearn.linear_model.LinearRegression()

non_sydney_columns = [x for x in weather.columns if x not in ['SYDNEY','Year_Month_Day']]
lr.fit(weather[non_sydney_columns],weather.SYDNEY)
predictions = lr.predict(weather[non_sydney_columns])
import matplotlib.pyplot
matplotlib.pyplot.scatter(weather.SYDNEY,predictions)

# %%
lr.score(weather[non_sydney_columns],weather.SYDNEY)
# Out:
# 0.97840261999037548

# %%
zip(non_sydney_columns,lr.coef_)
# Out:
# [('MANGROVE_MOUNTAIN', -0.26220631164824493),
#  ('GOSFORD', 0.13576763097254207),
#  ('SPRINGWOOD', 0.10356996984971922),
#  ('SYDNEY_AIRPORT', -0.15399718905103998),
#  ('TERREY_HILLS', 0.41991260599990921),
#  ('PARRAMATTA_NORTH', 0.3970205324821614),
#  ('BANKSTOWN_AIRPORT', -0.035978722658213891),
#  ('HOLSWORTHY_AERODROME', 0.17478117127800097),
#  ('CANTERBURY_RACECOURSE', -0.080282870119453648),
#  ('SYDNEY_HARBOUR', 0.43403900742427964),
#  ('PROSPECT_RESERVOIR', -0.048002716084284303),
#  ('RICHMOND_RAAF', 0.079538542262051232),
#  ('BADGERYS_CREEK', -0.051296195240682241),
#  ('PENRITH_LAKES', 0.014995402357884935),
#  ('HORSLEY_PARK_EQUESTRIAN_CENTRE', -0.34343871333617437),
#  ('CAMDEN_AIRPORT', 0.025221908647474506),
#  ('BELLAMBI', 0.13797446309147154),
#  ('PORT_KEMBLA_NTC', -0.0087360771503590395),
#  ('CAMPBELLTOWN', 0.13329920380432719)]

# %%
lasso = sklearn.linear_model.Lasso(alpha=5)
lasso.fit(weather[non_sydney_columns],weather.SYDNEY)
print lasso.score(weather[non_sydney_columns],weather.SYDNEY)
print lasso.intercept_
zip(non_sydney_columns,lasso.coef_)
# Out:
# 0.89878454664
# 8.6309864533
# [('MANGROVE_MOUNTAIN', 0.0),
#  ('GOSFORD', 0.0),
#  ('SPRINGWOOD', 0.061339823397064883),
#  ('SYDNEY_AIRPORT', 0.0),
#  ('TERREY_HILLS', 0.052516567927554728),
#  ('PARRAMATTA_NORTH', 0.0),
#  ('BANKSTOWN_AIRPORT', 0.0),
#  ('HOLSWORTHY_AERODROME', 0.160299159491986),
#  ('CANTERBURY_RACECOURSE', 0.0),
#  ('SYDNEY_HARBOUR', 0.0),
#  ('PROSPECT_RESERVOIR', 0.14310562519964923),
#  ('RICHMOND_RAAF', 0.0),
#  ('BADGERYS_CREEK', 0.0),
#  ('PENRITH_LAKES', 0.21160595085958231),
#  ('HORSLEY_PARK_EQUESTRIAN_CENTRE', 0.0),
#  ('CAMDEN_AIRPORT', 0.0),
#  ('BELLAMBI', 0.0),
#  ('PORT_KEMBLA_NTC', 0.0),
#  ('CAMPBELLTOWN', 0.0)]

# %%
ridge = sklearn.linear_model.Ridge(alpha=100)
ridge.fit(weather[non_sydney_columns],weather.SYDNEY)
print ridge.score(weather[non_sydney_columns],weather.SYDNEY)
print ridge.intercept_
zip(non_sydney_columns,ridge.coef_)
# Out:
# 0.975249940395
# 0.0642378556535
# [('MANGROVE_MOUNTAIN', -0.057368173657028274),
#  ('GOSFORD', 0.12021612535932942),
#  ('SPRINGWOOD', 0.064570989843478949),
#  ('SYDNEY_AIRPORT', -0.032615074281762552),
#  ('TERREY_HILLS', 0.18180686222466802),
#  ('PARRAMATTA_NORTH', 0.084690780072670807),
#  ('BANKSTOWN_AIRPORT', 0.044335283131726903),
#  ('HOLSWORTHY_AERODROME', 0.054370621655341997),
#  ('CANTERBURY_RACECOURSE', 0.071675530789116634),
#  ('SYDNEY_HARBOUR', 0.29443913645270453),
#  ('PROSPECT_RESERVOIR', -0.03569873506730744),
#  ('RICHMOND_RAAF', 0.038834712797110642),
#  ('BADGERYS_CREEK', -0.0049138503489783887),
#  ('PENRITH_LAKES', -0.00038342002997743252),
#  ('HORSLEY_PARK_EQUESTRIAN_CENTRE', -0.042253123132568217),
#  ('CAMDEN_AIRPORT', 0.016863642730307767),
#  ('BELLAMBI', 0.081652585913140396),
#  ('PORT_KEMBLA_NTC', 0.12060467902465835),
#  ('CAMPBELLTOWN', 0.041348211264877706)]

# %%
elastic = sklearn.linear_model.ElasticNetCV()
elastic.fit(weather[non_sydney_columns],weather.SYDNEY)
print elastic.score(weather[non_sydney_columns],weather.SYDNEY)
print elastic.intercept_
zip(non_sydney_columns,elastic.coef_)
# Out:
# 0.975022914539
# 0.192580532447
# [('MANGROVE_MOUNTAIN', -0.0),
#  ('GOSFORD', 0.020071937512207837),
#  ('SPRINGWOOD', 0.057864519276811952),
#  ('SYDNEY_AIRPORT', 0.0),
#  ('TERREY_HILLS', 0.27654019903663091),
#  ('PARRAMATTA_NORTH', 0.068083400547409606),
#  ('BANKSTOWN_AIRPORT', 0.0),
#  ('HOLSWORTHY_AERODROME', 0.060809078951503955),
#  ('CANTERBURY_RACECOURSE', 0.0),
#  ('SYDNEY_HARBOUR', 0.37984574372102781),
#  ('PROSPECT_RESERVOIR', 0.0),
#  ('RICHMOND_RAAF', 0.0),
#  ('BADGERYS_CREEK', 0.0),
#  ('PENRITH_LAKES', 0.0),
#  ('HORSLEY_PARK_EQUESTRIAN_CENTRE', 0.0),
#  ('CAMDEN_AIRPORT', 0.0),
#  ('BELLAMBI', 0.035377957758790116),
#  ('PORT_KEMBLA_NTC', 0.11557884553180474),
#  ('CAMPBELLTOWN', 0.033922895564349138)]

# %% [markdown]
# # Scaling

# %%
weather[non_sydney_columns].std()
# Out:
# MANGROVE_MOUNTAIN                 5.688594
# GOSFORD                           4.974931
# SPRINGWOOD                        5.796824
# SYDNEY_AIRPORT                    5.079707
# TERREY_HILLS                      5.106845
# PARRAMATTA_NORTH                  5.402940
# BANKSTOWN_AIRPORT                 5.556021
# HOLSWORTHY_AERODROME              5.673538
# CANTERBURY_RACECOURSE             5.020166
# SYDNEY_HARBOUR                    3.653828
# PROSPECT_RESERVOIR                5.911210
# RICHMOND_RAAF                     5.827525
# BADGERYS_CREEK                    5.907684
# PENRITH_LAKES                     6.171921
# HORSLEY_PARK_EQUESTRIAN_CENTRE    5.714526
# CAMDEN_AIRPORT                    5.824256
# BELLAMBI                          3.954496
# PORT_KEMBLA_NTC                   3.689115
# CAMPBELLTOWN                      5.767958
# dtype: float64

# %%
weather[non_sydney_columns].mean()
# Out:
# MANGROVE_MOUNTAIN                 23.110526
# GOSFORD                           23.782105
# SPRINGWOOD                        22.914737
# SYDNEY_AIRPORT                    24.222105
# TERREY_HILLS                      22.570526
# PARRAMATTA_NORTH                  24.376316
# BANKSTOWN_AIRPORT                 24.838947
# HOLSWORTHY_AERODROME              24.108421
# CANTERBURY_RACECOURSE             23.999474
# SYDNEY_HARBOUR                    22.204211
# PROSPECT_RESERVOIR                24.564737
# RICHMOND_RAAF                     25.255263
# BADGERYS_CREEK                    24.914737
# PENRITH_LAKES                     25.212105
# HORSLEY_PARK_EQUESTRIAN_CENTRE    24.528421
# CAMDEN_AIRPORT                    24.720526
# BELLAMBI                          22.202632
# PORT_KEMBLA_NTC                   21.773684
# CAMPBELLTOWN                      24.686316
# dtype: float64

# %%
"""
import sklearn.preprocessing
robust = sklearn.preprocessing.StandardScaler()
scaled_weather = robust.fit_transform(weather[non_sydney_columns])
scaled_weather.mean() , scaled_weather.std()
"""

import sklearn.preprocessing
robust = sklearn.preprocessing.RobustScaler()
scaled_weather = robust.fit_transform(weather[non_sydney_columns])
scaled_weather.mean() , scaled_weather.std()
# Out:
# (-0.056111592497093556, 0.67702148976755749)

# %%
lasso = sklearn.linear_model.Lasso(alpha=1)
lasso.fit(scaled_weather,weather.SYDNEY)
print lasso.score(scaled_weather,weather.SYDNEY)
print lasso.intercept_
zip(non_sydney_columns,lasso.coef_)
# Out:
# 0.874303596647
# 24.3277510923
# [('MANGROVE_MOUNTAIN', 0.0),
#  ('GOSFORD', 0.0),
#  ('SPRINGWOOD', 0.0),
#  ('SYDNEY_AIRPORT', 1.7125039031531992),
#  ('TERREY_HILLS', 0.0),
#  ('PARRAMATTA_NORTH', 0.0),
#  ('BANKSTOWN_AIRPORT', 0.0),
#  ('HOLSWORTHY_AERODROME', 0.0),
#  ('CANTERBURY_RACECOURSE', 0.0),
#  ('SYDNEY_HARBOUR', 2.3260912003496497),
#  ('PROSPECT_RESERVOIR', 0.0),
#  ('RICHMOND_RAAF', 0.0),
#  ('BADGERYS_CREEK', 0.0),
#  ('PENRITH_LAKES', 0.0),
#  ('HORSLEY_PARK_EQUESTRIAN_CENTRE', 0.0),
#  ('CAMDEN_AIRPORT', 0.0),
#  ('BELLAMBI', 0.33219156534075289),
#  ('PORT_KEMBLA_NTC', 0.0),
#  ('CAMPBELLTOWN', 0.0)]

# %%
y_scaler = sklearn.preprocessing.RobustScaler()
sydney_transformed = y_scaler.fit_transform(weather[['SYDNEY']])
lasso = sklearn.linear_model.Lasso(alpha=0.1)
lasso.fit(scaled_weather,sydney_transformed)
print lasso.score(scaled_weather,sydney_transformed)
print lasso.intercept_
zip(non_sydney_columns,lasso.coef_)
# Out:
# 0.919718775426
# [-0.02330258]
# [('MANGROVE_MOUNTAIN', 0.0),
#  ('GOSFORD', 0.0),
#  ('SPRINGWOOD', 0.0),
#  ('SYDNEY_AIRPORT', 0.18465190706543894),
#  ('TERREY_HILLS', 0.10051723935097098),
#  ('PARRAMATTA_NORTH', 0.010225190122127824),
#  ('BANKSTOWN_AIRPORT', 0.0),
#  ('HOLSWORTHY_AERODROME', 0.0),
#  ('CANTERBURY_RACECOURSE', 0.0),
#  ('SYDNEY_HARBOUR', 0.31911689828792339),
#  ('PROSPECT_RESERVOIR', 0.0),
#  ('RICHMOND_RAAF', 0.0),
#  ('BADGERYS_CREEK', 0.0),
#  ('PENRITH_LAKES', 0.0),
#  ('HORSLEY_PARK_EQUESTRIAN_CENTRE', 0.0),
#  ('CAMDEN_AIRPORT', 0.0),
#  ('BELLAMBI', 0.068290498561999494),
#  ('PORT_KEMBLA_NTC', 0.0),
#  ('CAMPBELLTOWN', 0.0)]

# %%
elastic = sklearn.linear_model.ElasticNetCV()
elastic.fit(scaled_weather,sydney_transformed)
print elastic.score(scaled_weather,sydney_transformed)
print elastic.intercept_
zip(non_sydney_columns,elastic.coef_)
# Out:
# 0.974926137865
# -0.00758180265474
# /Users/tianjiaoxie/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:1051: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [('MANGROVE_MOUNTAIN', 0.0),
#  ('GOSFORD', 0.044460927220250905),
#  ('SPRINGWOOD', 0.055031676471712941),
#  ('SYDNEY_AIRPORT', 0.0),
#  ('TERREY_HILLS', 0.23144598211329404),
#  ('PARRAMATTA_NORTH', 0.090615343027094009),
#  ('BANKSTOWN_AIRPORT', 0.0019808373838273181),
#  ('HOLSWORTHY_AERODROME', 0.045505687224363392),
#  ('CANTERBURY_RACECOURSE', 0.016716562098215666),
#  ('SYDNEY_HARBOUR', 0.26607574348059765),
#  ('PROSPECT_RESERVOIR', 0.0),
#  ('RICHMOND_RAAF', 0.0),
#  ('BADGERYS_CREEK', 0.0),
#  ('PENRITH_LAKES', 0.0),
#  ('HORSLEY_PARK_EQUESTRIAN_CENTRE', 0.0),
#  ('CAMDEN_AIRPORT', 0.0),
#  ('BELLAMBI', 0.042219532389455527),
#  ('PORT_KEMBLA_NTC', 0.074600686325061602),
#  ('CAMPBELLTOWN', 0.048006909363901409)]

# %%
elastic.predict(scaled_weather)[0]
# Out:
# 0.024229725354342153

# %% [markdown]
# transfer to degrees

# %%
y_scaler.inverse_transform([[0.024229725354342153]])
# Out:
# array([[ 24.72566551]])

# %%
transformed_space_predictions = elastic.predict(scaled_weather)
reality_predictions = y_scaler.inverse_transform(transformed_space_predictions)
matplotlib.pyplot.scatter(reality_predictions,weather.SYDNEY)
# Out:
# /Users/tianjiaoxie/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:965: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/tianjiaoxie/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:1037: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %% [markdown]
# #
