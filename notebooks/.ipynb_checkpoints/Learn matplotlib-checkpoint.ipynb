# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import matplotlib.pyplot

# %%
x = [1, 2, 3, 4, 5]

# %%
y = [1, 4, 9, 16, 25]

# %%
matplotlib.pyplot.plot(x, y,'b')
matplotlib.pyplot.title("plots of used cars")
matplotlib.pyplot.xlabel('price')
matplotlib.pyplot.ylabel('Duration')
matplotlib.pyplot.xlim(1.0,7.0)
matplotlib.pyplot.ylim(1.0,40.0)
# Out:
# (1.0, 40.0)

# %%
a = [15,22,34,53,56]

# %%
b = [1,3,5,6,9]

# %%
a1 = [12,54,76,84,32]

# %%
b1 = [99,56,33,22,11]

# %%
matplotlib.pyplot.plot(a,b,'.r')
matplotlib.pyplot.plot(a1,b1,'.c')

# %%
f, car = matplotlib.pyplot.subplots(2,1,sharex=True)
car[0].plot(x, y)
car[0].set_title('Sharing X axis')
car[1].plot(x, y,'oc')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)
