# %%
import pandas

# %%
billboard = pandas.read_csv("2.4-lab/assets/datasets/billboard.csv", )

# %%
rock = pandas.read_csv("2.4-lab/assets/datasets/rock.csv")
rock
# Out:
#                                        Song Clean   ARTIST CLEAN Release Year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# 5                                      Kryptonite   3 Doors Down         2000
# 6                                           Loser   3 Doors Down         2000
# 7                                   When I'm Gone   3 Doors Down         2002
# 8                                      What's Up?  4 Non Blondes         1992
# 9                                      Take On Me           a-ha         1985
# 10                          Baby, Please Don't Go          AC/DC          NaN
# ...

# %%
billboard.describe()
# Out:
#          year   x1st.week   x2nd.week   x3rd.week   x4th.week   x5th.week  \
# count   317.0  317.000000  312.000000  307.000000  300.000000  292.000000
# mean   2000.0   79.958991   71.173077   65.045603   59.763333   56.339041
# std       0.0   14.686865   18.200443   20.752302   22.324619   23.780022
# min    2000.0   15.000000    8.000000    6.000000    5.000000    2.000000
# 25%    2000.0   74.000000   63.000000   53.000000   44.750000   38.750000
# 50%    2000.0   81.000000   73.000000   66.000000   61.000000   57.000000
# 75%    2000.0   91.000000   84.000000   79.000000   76.000000   73.250000
# max    2000.0  100.000000  100.000000  100.000000  100.000000  100.000000
#
#         x6th.week   x7th.week   x8th.week   x9th.week     ...      x67th.week  \
# count  280.000000  269.000000  260.000000  253.000000     ...             0.0
# mean    52.360714   49.219331   47.119231   46.343874     ...             NaN
# ...

# %%
rock.describe()
# Out:
#        First?        Year?    PlayCount          F*G
# count  2230.0  2230.000000  2230.000000  2230.000000
# mean      1.0     0.741256    16.872646    15.048430
# std       0.0     0.438043    25.302972    25.288366
# min       1.0     0.000000     0.000000     0.000000
# 25%       1.0     0.000000     1.000000     0.000000
# 50%       1.0     1.000000     4.000000     3.000000
# 75%       1.0     1.000000    21.000000    18.000000
# max       1.0     1.000000   142.000000   142.000000

# %%
number_sold = billboard.loc[:,'x1st.week':'x76th.week']
number_sold
# Out:
#      x1st.week  x2nd.week  x3rd.week  x4th.week  x5th.week  x6th.week  \
# 0           78       63.0       49.0       33.0       23.0       15.0
# 1           15        8.0        6.0        5.0        2.0        3.0
# 2           71       48.0       43.0       31.0       20.0       13.0
# 3           41       23.0       18.0       14.0        2.0        1.0
# 4           57       47.0       45.0       29.0       23.0       18.0
# 5           59       52.0       43.0       30.0       29.0       22.0
# 6           83       83.0       44.0       38.0       16.0       13.0
# 7           63       45.0       34.0       23.0       17.0       12.0
# 8           77       66.0       61.0       61.0       61.0       55.0
# 9           81       54.0       44.0       39.0       38.0       33.0
# 10          82       70.0       51.0       39.0       26.0       19.0
# 11          71       51.0       28.0       18.0       13.0       13.0
# ...

# %%
numeric_columns = [x for x in billboard.columns if x.endswith('week') ]
numeric_columns
# Out:
# ['x1st.week',
#  'x2nd.week',
#  'x3rd.week',
#  'x4th.week',
#  'x5th.week',
#  'x6th.week',
#  'x7th.week',
#  'x8th.week',
#  'x9th.week',
#  'x10th.week',
#  'x11th.week',
#  'x12th.week',
#  'x13th.week',
#  'x14th.week',
#  'x15th.week',
#  'x16th.week',
#  'x17th.week',
#  'x18th.week',
#  'x19th.week',
#  'x20th.week',
#  'x21st.week',
#  'x22nd.week',
#  'x23rd.week',
#  'x24th.week',
#  'x25th.week',
#  'x26th.week',
#  'x27th.week',
#  'x28th.week',
#  'x29th.week',
#  'x30th.week',
#  'x31st.week',
#  'x32nd.week',
#  'x33rd.week',
#  'x34th.week',
#  'x35th.week',
#  'x36th.week',
#  'x37th.week',
#  'x38th.week',
#  'x39th.week',
#  'x40th.week',
#  'x41st.week',
#  'x42nd.week',
#  'x43rd.week',
#  'x44th.week',
#  'x45th.week',
#  'x46th.week',
#  'x47th.week',
#  'x48th.week',
#  'x49th.week',
#  'x50th.week',
#  'x51st.week',
#  'x52nd.week',
#  'x53rd.week',
#  'x54th.week',
#  'x55th.week',
#  'x56th.week',
#  'x57th.week',
#  'x58th.week',
#  'x59th.week',
# ...

# %%
pandas.pivot_table(billboard,index = "track", values=numeric_columns)
# Out:
#                                      x10th.week  x11th.week  x12th.week  \
# track
# (Hot S**t) Country Grammar                 36.0        37.0        30.0
# 3 Little Words                              NaN         NaN         NaN
# 911                                        38.0        44.0        49.0
# A Country Boy Can Survive                   NaN         NaN         NaN
# A Little Gasoline                           NaN         NaN         NaN
# A Puro Dolor (Purest Of Pain)              60.0        48.0        48.0
# Aaron's Party (Come Get It)                55.0        67.0        83.0
# Absolutely (Story Of A Girl)               13.0        11.0         6.0
# All Good?                                   NaN         NaN         NaN
# All The Small Things                       15.0         7.0         6.0
# Amazed                                     27.0        26.0        24.0
# American Pie                                NaN         NaN         NaN
# ...

# %%
track = pandas.pivot_table(billboard,index = "track", values=numeric_columns,aggfunc=sum).T
track
# Out:
# track       (Hot S**t) Country Grammar  3 Little Words   911  \
# x10th.week                        36.0             NaN  38.0
# x11th.week                        37.0             NaN  44.0
# x12th.week                        30.0             NaN  49.0
# x13th.week                        23.0             NaN  53.0
# x14th.week                        21.0             NaN  61.0
# x15th.week                        17.0             NaN  66.0
# x16th.week                        17.0             NaN  68.0
# x17th.week                        15.0             NaN  80.0
# x18th.week                        11.0             NaN  85.0
# x19th.week                        11.0             NaN  96.0
# x1st.week                        100.0            97.0  77.0
# x20th.week                        10.0             NaN   NaN
# x21st.week                         7.0             NaN   NaN
# x22nd.week                         7.0             NaN   NaN
# ...

# %%
new_table = pandas.pivot_table(billboard,index = ['genre','date.entered'], values=numeric_columns )
new_table
# Out:
#                       x10th.week  x11th.week  x12th.week  x13th.week  \
# genre   date.entered
# Country 1999-06-05     27.000000   26.000000   24.000000   27.000000
#         1999-10-16     26.000000   26.000000   23.000000   30.000000
#         1999-10-30     46.000000   53.000000   43.000000   33.000000
#         1999-11-13     52.000000   43.000000   47.000000   55.000000
#         1999-11-27     51.000000   49.000000   52.333333   31.500000
#         1999-12-04     92.000000   98.000000         NaN         NaN
#         1999-12-18     39.000000   43.000000   41.000000   43.000000
#         1999-12-25           NaN         NaN         NaN         NaN
#         2000-01-01           NaN         NaN         NaN         NaN
#         2000-01-15     46.000000   45.000000   52.000000   64.000000
#         2000-01-22           NaN         NaN         NaN         NaN
#         2000-01-29     42.250000   41.250000   44.000000   52.250000
# ...

# %%
import numpy
type(numpy.nan)
# Out:
# float

# %%
def clean_nan(n):
    if numpy.isreal(n):
        if numpy.isnan(n):
            return 0
    return n

# %%
new_table.applymap(clean_nan)
# Out:
#                       x10th.week  x11th.week  x12th.week  x13th.week  \
# genre   date.entered
# Country 1999-06-05     27.000000   26.000000   24.000000   27.000000
#         1999-10-16     26.000000   26.000000   23.000000   30.000000
#         1999-10-30     46.000000   53.000000   43.000000   33.000000
#         1999-11-13     52.000000   43.000000   47.000000   55.000000
#         1999-11-27     51.000000   49.000000   52.333333   31.500000
#         1999-12-04     92.000000   98.000000    0.000000    0.000000
#         1999-12-18     39.000000   43.000000   41.000000   43.000000
#         1999-12-25      0.000000    0.000000    0.000000    0.000000
#         2000-01-01      0.000000    0.000000    0.000000    0.000000
#         2000-01-15     46.000000   45.000000   52.000000   64.000000
#         2000-01-22      0.000000    0.000000    0.000000    0.000000
#         2000-01-29     42.250000   41.250000   44.000000   52.250000
# ...

# %%
type(1.5)
# Out:
# float

# %%
import numpy
type(numpy.nan)
# Out:
# float

# %% [markdown]
# # example

# %%
import pandas
billboard = pandas.read_csv('2.4-lab/assets/datasets/billboard.csv',parse_dates=['date.entered','date.peaked'])

# %%
new_column_names = []
for column in billboard.columns:
    if column.endswith('week') and len(column)==9:
        good_name = 'x0' + column[1:]
        print "Bad column name", column, 'should be', good_name
        new_column_names.append(good_name)
    else:
        new_column_names.append(column)
new_column_names
# Out:
# Bad column name x1st.week should be x01st.week
# Bad column name x2nd.week should be x02nd.week
# Bad column name x3rd.week should be x03rd.week
# Bad column name x4th.week should be x04th.week
# Bad column name x5th.week should be x05th.week
# Bad column name x6th.week should be x06th.week
# Bad column name x7th.week should be x07th.week
# Bad column name x8th.week should be x08th.week
# Bad column name x9th.week should be x09th.week
# ['year',
#  'artist.inverted',
#  'track',
#  'time',
#  'genre',
#  'date.entered',
#  'date.peaked',
#  'x01st.week',
#  'x02nd.week',
#  'x03rd.week',
#  'x04th.week',
#  'x05th.week',
#  'x06th.week',
#  'x07th.week',
#  'x08th.week',
#  'x09th.week',
#  'x10th.week',
#  'x11th.week',
#  'x12th.week',
#  'x13th.week',
#  'x14th.week',
#  'x15th.week',
#  'x16th.week',
#  'x17th.week',
#  'x18th.week',
#  'x19th.week',
#  'x20th.week',
#  'x21st.week',
#  'x22nd.week',
#  'x23rd.week',
#  'x24th.week',
#  'x25th.week',
#  'x26th.week',
# ...

# %%
billboard.columns = new_column_names

# %%
billboard.mean()
# Out:
# year          2000.000000
# x01st.week      79.958991
# x02nd.week      71.173077
# x03rd.week      65.045603
# x04th.week      59.763333
# x05th.week      56.339041
# x06th.week      52.360714
# x07th.week      49.219331
# x08th.week      47.119231
# x09th.week      46.343874
# x10th.week      45.786885
# x11th.week      45.474576
# x12th.week      44.198198
# x13th.week      44.352381
# x14th.week      45.892157
# x15th.week      47.898477
# x16th.week      48.241758
# x17th.week      51.265537
# x18th.week      52.108434
# x19th.week      53.166667
# x20th.week      54.267123
# x21st.week      26.184615
# x22nd.week      25.636364
# x23rd.week      23.812500
# x24th.week      26.782609
# x25th.week      26.131579
# x26th.week      28.000000
# x27th.week      27.344828
# x28th.week      25.000000
# x29th.week      23.650000
#                  ...
# x47th.week      22.800000
# x48th.week      20.000000
# x49th.week      22.000000
# x50th.week      26.000000
# ...

# %%
billboard['x66th.week'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
#        ...
# 287    True
# 288    True
# 289    True
# 290    True
# 291    True
# 292    True
# 293    True
# 294    True
# 295    True
# 296    True
# 297    True
# 298    True
# 299    True
# 300    True
# 301    True
# 302    True
# 303    True
# 304    True
# 305    True
# 306    True
# 307    True
# 308    True
# 309    True
# 310    True
# 311    True
# 312    True
# 313    True
# 314    True
# 315    True
# 316    True
# Name: x66th.week, dtype: bool

# %%
billboard['x66th.week'].isnull().all()
# Out:
# True

# %%
billboard.median()
# Out:
# year          2000.0
# x01st.week      81.0
# x02nd.week      73.0
# x03rd.week      66.0
# x04th.week      61.0
# x05th.week      57.0
# x06th.week      51.5
# x07th.week      47.0
# x08th.week      45.5
# x09th.week      42.0
# x10th.week      40.0
# x11th.week      42.5
# x12th.week      42.0
# x13th.week      42.5
# x14th.week      44.0
# x15th.week      46.0
# x16th.week      47.0
# x17th.week      52.0
# x18th.week      56.5
# x19th.week      55.5
# x20th.week      58.5
# x21st.week      24.0
# x22nd.week      21.0
# x23rd.week      20.5
# x24th.week      21.5
# x25th.week      22.5
# x26th.week      26.0
# x27th.week      26.0
# x28th.week      23.5
# x29th.week      22.5
#                ...
# x47th.week      22.0
# x48th.week      16.5
# x49th.week      18.5
# x50th.week      22.5
# x51st.week      28.0
# x52nd.week      29.0
# x53rd.week      33.5
# x54th.week      19.5
# x55th.week      21.5
# x56th.week      25.5
# x57th.week      27.5
# x58th.week      31.5
# ...

# %%
billboard.std()
# Out:
# year           0.000000
# x01st.week    14.686865
# x02nd.week    18.200443
# x03rd.week    20.752302
# x04th.week    22.324619
# x05th.week    23.780022
# x06th.week    24.473273
# x07th.week    25.654279
# x08th.week    26.370782
# x09th.week    27.136419
# x10th.week    28.152357
# x11th.week    29.060527
# x12th.week    28.893100
# x13th.week    29.481315
# x14th.week    30.529936
# x15th.week    31.542486
# x16th.week    31.899476
# x17th.week    33.093233
# x18th.week    33.194199
# x19th.week    33.022540
# x20th.week    32.890475
# x21st.week    20.232162
# x22nd.week    21.127798
# x23rd.week    18.235640
# x24th.week    18.556716
# x25th.week    18.737404
# x26th.week    19.149040
# x27th.week    19.736254
# x28th.week    16.229335
# x29th.week    15.239405
#                 ...
# x47th.week    16.543881
# x48th.week    14.628739
# x49th.week    16.062378
# x50th.week    18.529256
# x51st.week    18.997807
# x52nd.week    17.211914
# x53rd.week    17.095321
# ...

# %%
import numpy
columns_that_are_numbers = billboard.columns[
(billboard.dtypes == numpy.int64) | (billboard.dtypes == numpy.float64)]
columns_that_are_numbers
# Out:
# Index([u'year', u'x01st.week', u'x02nd.week', u'x03rd.week', u'x04th.week',
#        u'x05th.week', u'x06th.week', u'x07th.week', u'x08th.week',
#        u'x09th.week', u'x10th.week', u'x11th.week', u'x12th.week',
#        u'x13th.week', u'x14th.week', u'x15th.week', u'x16th.week',
#        u'x17th.week', u'x18th.week', u'x19th.week', u'x20th.week',
#        u'x21st.week', u'x22nd.week', u'x23rd.week', u'x24th.week',
#        u'x25th.week', u'x26th.week', u'x27th.week', u'x28th.week',
#        u'x29th.week', u'x30th.week', u'x31st.week', u'x32nd.week',
#        u'x33rd.week', u'x34th.week', u'x35th.week', u'x36th.week',
#        u'x37th.week', u'x38th.week', u'x39th.week', u'x40th.week',
#        u'x41st.week', u'x42nd.week', u'x43rd.week', u'x44th.week',
#        u'x45th.week', u'x46th.week', u'x47th.week', u'x48th.week',
#        u'x49th.week', u'x50th.week', u'x51st.week', u'x52nd.week',
#        u'x53rd.week', u'x54th.week', u'x55th.week', u'x56th.week',
# ...

# %%
billboard.max()[columns_that_are_numbers]-billboard.min()[columns_that_are_numbers]
# Out:
# Series([], dtype: object)

# %%
stats = pandas.DataFrame({'mean':  billboard.mean(),
                         'median': billboard.median(),
                        'stddev': billboard.std(),
                        'range': (billboard.max()[columns_that_are_numbers]-billboard.min()[columns_that_are_numbers])})
stats
# Out:
#                    mean  median range     stddev
# x01st.week    79.958991    81.0   NaN  14.686865
# x02nd.week    71.173077    73.0   NaN  18.200443
# x03rd.week    65.045603    66.0   NaN  20.752302
# x04th.week    59.763333    61.0   NaN  22.324619
# x05th.week    56.339041    57.0   NaN  23.780022
# x06th.week    52.360714    51.5   NaN  24.473273
# x07th.week    49.219331    47.0   NaN  25.654279
# x08th.week    47.119231    45.5   NaN  26.370782
# x09th.week    46.343874    42.0   NaN  27.136419
# x10th.week    45.786885    40.0   NaN  28.152357
# x11th.week    45.474576    42.5   NaN  29.060527
# x12th.week    44.198198    42.0   NaN  28.893100
# x13th.week    44.352381    42.5   NaN  29.481315
# x14th.week    45.892157    44.0   NaN  30.529936
# x15th.week    47.898477    46.0   NaN  31.542486
# x16th.week    48.241758    47.0   NaN  31.899476
# x17th.week    51.265537    52.0   NaN  33.093233
# x18th.week    52.108434    56.5   NaN  33.194199
# ...

# %%
billboard.mode()
# Out:
#      year artist.inverted             track  time genre date.entered  \
# 0  2000.0           Jay-Z  Where I Wanna Be  3:50  Rock   2000-01-29
# 1     NaN             NaN               NaN   NaN   NaN          NaT
# 2     NaN             NaN               NaN   NaN   NaN          NaT
# 3     NaN             NaN               NaN   NaN   NaN          NaT
# 4     NaN             NaN               NaN   NaN   NaN          NaT
# 5     NaN             NaN               NaN   NaN   NaN          NaT
# 6     NaN             NaN               NaN   NaN   NaN          NaT
# 7     NaN             NaN               NaN   NaN   NaN          NaT
#
#   date.peaked  x01st.week  x02nd.week  x03rd.week     ...      x67th.week  \
# 0  2000-12-02        77.0        72.0        65.0     ...             NaN
# 1         NaT         NaN        76.0         NaN     ...             NaN
# 2         NaT         NaN         NaN         NaN     ...             NaN
# ...

# %%
billboard.columns
# Out:
# Index([u'year', u'artist.inverted', u'track', u'time', u'genre',
#        u'date.entered', u'date.peaked', u'x01st.week', u'x02nd.week',
#        u'x03rd.week', u'x04th.week', u'x05th.week', u'x06th.week',
#        u'x07th.week', u'x08th.week', u'x09th.week', u'x10th.week',
#        u'x11th.week', u'x12th.week', u'x13th.week', u'x14th.week',
#        u'x15th.week', u'x16th.week', u'x17th.week', u'x18th.week',
#        u'x19th.week', u'x20th.week', u'x21st.week', u'x22nd.week',
#        u'x23rd.week', u'x24th.week', u'x25th.week', u'x26th.week',
#        u'x27th.week', u'x28th.week', u'x29th.week', u'x30th.week',
#        u'x31st.week', u'x32nd.week', u'x33rd.week', u'x34th.week',
#        u'x35th.week', u'x36th.week', u'x37th.week', u'x38th.week',
#        u'x39th.week', u'x40th.week', u'x41st.week', u'x42nd.week',
#        u'x43rd.week', u'x44th.week', u'x45th.week', u'x46th.week',
#        u'x47th.week', u'x48th.week', u'x49th.week', u'x50th.week',
# ...

# %%
pandas.pivot_table(billboard,index='genre')
# Out:
#              x01st.week  x02nd.week  x03rd.week  x04th.week  x05th.week  \
# genre
# Country       82.405405   75.256757   71.808219   68.309859   65.271429
# Electronica   84.500000   71.000000   64.000000   61.000000   57.000000
# Gospel        76.000000   76.000000   74.000000   69.000000   68.000000
# Jazz          89.000000   89.000000    7.000000    8.000000   66.000000
# Latin         73.222222   64.333333   58.777778   52.666667   52.000000
# Pop           79.222222   68.000000   65.500000   60.333333   52.125000
# R&B           84.086957   74.095238   67.190476   60.894737   61.473684
# Rap           85.172414   76.228070   68.781818   63.925926   60.384615
# Reggae        72.000000   72.000000   63.000000   56.000000   62.000000
# Rock          76.116788   66.852941   60.298507   54.015267   49.330709
#
#              x06th.week  x07th.week  x08th.week  x09th.week  x10th.week  \
# genre
# Country       62.357143   57.692308   54.859375   52.983871   52.377049
# ...

# %%
genre_table = pandas.pivot_table(billboard,index='genre').T
genre_table
# Out:
# genre           Country  Electronica  Gospel    Jazz        Latin  \
# x01st.week    82.405405    84.500000    76.0    89.0    73.222222
# x02nd.week    75.256757    71.000000    76.0    89.0    64.333333
# x03rd.week    71.808219    64.000000    74.0     7.0    58.777778
# x04th.week    68.309859    61.000000    69.0     8.0    52.666667
# x05th.week    65.271429    57.000000    68.0    66.0    52.000000
# x06th.week    62.357143    54.000000    67.0     NaN    42.625000
# x07th.week    57.692308    54.500000    61.0     NaN    38.500000
# x08th.week    54.859375    52.250000    58.0     NaN    39.000000
# x09th.week    52.983871    51.500000    57.0     NaN    39.625000
# x10th.week    52.377049    55.750000    59.0     NaN    43.250000
# x11th.week    51.016949    53.250000    66.0     NaN    49.625000
# x12th.week    50.714286    59.750000    68.0     NaN    35.285714
# x13th.week    52.301887    49.333333    61.0     NaN    39.285714
# ...

# %%
# %matplotlib inline

# %%
genre_table['x01st.week':"x64th.week"].plot()

# %%
genre_table['x01st.week':"x64th.week"].plot(ylim=(100,0))

# %%
billboard['date.entered']
# Out:
# 0     2000-09-23
# 1     2000-02-12
# 2     1999-10-23
# 3     2000-08-12
# 4     2000-08-05
# 5     2000-06-17
# 6     1999-12-25
# 7     2000-04-01
# 8     2000-06-24
# 9     1999-06-05
# 10    2000-05-06
# 11    1999-11-27
# 12    2000-01-22
# 13    2000-05-13
# 14    2000-03-18
# 15    2000-04-29
# 16    1999-12-11
# 17    1999-11-06
# 18    2000-08-19
# 19    2000-09-30
# 20    2000-03-18
# 21    2000-02-26
# 22    2000-08-19
# 23    2000-05-13
# 24    2000-04-08
# 25    2000-01-29
# 26    2000-04-15
# 27    1999-09-04
# 28    2000-01-01
# 29    1999-10-23
#          ...
# 287   2000-09-02
# 288   2000-07-08
# 289   2000-07-15
# 290   1999-12-04
# 291   2000-03-04
# 292   2000-06-03
# 293   2000-03-25
# 294   2000-08-19
# 295   1999-11-27
# 296   2000-01-01
# 297   2000-11-11
# 298   2000-05-13
# 299   2000-06-17
# 300   2000-03-18
# 301   2000-04-01
# 302   2000-09-09
# 303   2000-08-12
# 304   2000-07-08
# 305   2000-11-11
# 306   2000-12-23
# 307   2000-03-04
# ...

# %%
billboard['peak_duration'] = billboard['date.peaked'] - billboard['date.entered']
billboard['peak_duration']
# Out:
# 0      56 days
# 1      56 days
# 2      98 days
# 3      35 days
# 4      70 days
# 5      70 days
# 6      84 days
# 7      84 days
# 8      49 days
# 9     273 days
# 10     84 days
# 11     49 days
# 12    175 days
# 13    182 days
# 14     91 days
# 15     84 days
# 16     70 days
# 17    168 days
# 18    105 days
# 19     91 days
# 20     49 days
# 21     98 days
# 22     42 days
# 23     98 days
# 24    217 days
# 25    112 days
# 26     77 days
# 27    126 days
# 28    182 days
# 29    112 days
#         ...
# 287     7 days
# 288    70 days
# 289     7 days
# 290    63 days
# 291     7 days
# 292    14 days
# 293    21 days
# 294     7 days
# 295    49 days
# 296    21 days
# 297    21 days
# 298     7 days
# 299     0 days
# 300    49 days
# 301     0 days
# 302     7 days
# 303    35 days
# 304    21 days
# 305     7 days
# 306     0 days
# 307     7 days
# 308     0 days
# 309     0 days
# 310     7 days
# 311     0 days
# 312     0 days
# 313     0 days
# 314     0 days
# ...

# %%
pandas.pivot_table[billboard,index='genre',values='peak_duration',aggfunc=[min,max]]
# Out:
#   File "<ipython-input-170-2b59f856cf72>", line 1
#     pandas.pivot_table[billboard,index='genre',values='peak_duration',aggfunc=[min,max]]
#                                       ^
# SyntaxError: invalid syntax
