# %% [markdown]
# # Introduction to Data Science with Python
# ## General Assembly
# ## Natural Language Processing (NLP)
#
# Make sure you have installed nltk and downloaded the following copora:
#
# * punkt
# * gutenberg

# %% [markdown]
# ## Lab Part 1
#
# ###Tokenization
#
# What:  Separate text into units such as sentences or words
#
# Why:   Gives structure to previously unstructured text
#
# Notes: Relatively easy with English language text, not easy with some languages
#
#
# "corpus" = collection of documents
#
# "corpora" = plural form of corpus

# %%
import nltk

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# [u'austen-emma.txt',
#  u'austen-persuasion.txt',
#  u'austen-sense.txt',
#  u'bible-kjv.txt',
#  u'blake-poems.txt',
#  u'bryant-stories.txt',
#  u'burgess-busterbrown.txt',
#  u'carroll-alice.txt',
#  u'chesterton-ball.txt',
#  u'chesterton-brown.txt',
#  u'chesterton-thursday.txt',
#  u'edgeworth-parents.txt',
#  u'melville-moby_dick.txt',
#  u'milton-paradise.txt',
#  u'shakespeare-caesar.txt',
#  u'shakespeare-hamlet.txt',
#  u'shakespeare-macbeth.txt',
#  u'whitman-leaves.txt']

# %%
# Import the NLTK library, and use ntlk.corpus.gutenberg.fileids() to
# find the filenames for Jane Austen's Emma and Lewis Carrol's Alice in 
# Wonderland

emma = nltk.corpus.gutenberg.raw("austen-emma.txt")
alice = nltk.corpus.gutenberg.raw("carroll-alice.txt")

# %%
# Break these novels up into sentences. Put these sentence lists into
# a list so that you can use it later
emma_sentences = nltk.sent_tokenize(emma)
alice_sentences = nltk.sent_tokenize(alice)
emma_sentences
# Out:
# [u'[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\nEmma Woodhouse, handsome, clever, and rich, with a comfortable home\nand happy disposition, seemed to unite some of the best blessings\nof existence; and had lived nearly twenty-one years in the world\nwith very little to distress or vex her.',
#  u"She was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister's marriage,\nbeen mistress of his house from a very early period.",
#  u'Her mother\nhad died too long ago for her to have more than an indistinct\nremembrance of her caresses; and her place had been supplied\nby an excellent woman as governess, who had fallen little short\nof a mother in affection.',
#  u"Sixteen years had Miss Taylor been in Mr. Woodhouse's family,\nless as a governess than a friend, very fond of both daughters,\nbut particularly of Emma.",
#  u'Between _them_ it was more the intimacy\nof sisters.',
#  u"Even before Miss Taylor had ceased to hold the nominal\noffice of governess, the mildness of her temper had hardly allowed\nher to impose any restraint; and the shadow of authority being\nnow long passed away, they had been living together as friend and\nfriend very mutually attached, and Emma doing just what she liked;\nhighly esteeming Miss Taylor's judgment, but directed chiefly by\nher own.",
#  u"The real evils, indeed, of Emma's situation were the power of having\nrather too much her own way, and a disposition to think a little\ntoo well of herself; these were the disadvantages which threatened\nalloy to her many enjoyments.",
#  u'The danger, however, was at present\nso unperceived, that they did not by any means rank as misfortunes\nwith her.',
#  u'Sorrow came--a gentle sorrow--but not at all in the shape of any\ndisagreeable consciousness.--Miss Taylor married.',
#  u"It was Miss\nTaylor's loss which first brought grief.",
#  u'It was on the wedding-day\nof this beloved friend that Emma first sat in mournful thought\nof any continuance.',
#  u'The wedding over, and the bride-people gone,\nher father and herself were left to dine together, with no prospect\nof a third to cheer a long evening.',
#  u'Her father composed himself\nto sleep after dinner, as usual, and she had then only to sit\nand think of what she had lost.',
#  u'The event had every promise of happiness for her friend.',
#  u"Mr. Weston\nwas a man of unexceptionable character, easy fortune, suitable age,\nand pleasant manners; and there was some satisfaction in considering\nwith what self-denying, generous friendship she had always wished\nand promoted the match; but it was a black morning's work for her.",
#  u'The want of Miss Taylor would be felt every hour of every day.',
#  u'She recalled her past kindness--the kindness, the affection of sixteen\nyears--how she had taught and how she had played with her from five\nyears old--how she had devoted all her powers to attach and amuse\nher in health--and how nursed her through the various illnesses\nof childhood.',
#  u"A large debt of gratitude was owing here; but the\nintercourse of the last seven years, the equal footing and perfect\nunreserve which had soon followed Isabella's marriage, on their\nbeing left to each other, was yet a dearer, tenderer recollection.",
#  u'She had been a friend and companion such as few possessed: intelligent,\nwell-informed, useful, gentle, knowing all the ways of the family,\ninterested in all its concerns, and peculiarly interested in herself,\nin every pleasure, every scheme of hers--one to whom she could speak\nevery thought as it arose, and who had such an affection for her\nas could never find fault.',
#  u'How was she to bear the change?--It was true that her friend was\ngoing only half a mile from them; but Emma was aware that great must\nbe the difference between a Mrs. Weston, only half a mile from them,\nand a Miss Taylor in the house; and with all her advantages,\nnatural and domestic, she was now in great danger of suffering\nfrom intellectual solitude.',
#  u'She dearly loved her father, but he\nwas no companion for her.',
#  u'He could not meet her in conversation,\nrational or playful.',
#  u'The evil of the actual disparity in their ages (and Mr. Woodhouse had\nnot married early) was much increased by his constitution and habits;\nfor having been a valetudinarian all his life, without activity\nof mind or body, he was a much older man in ways than in years;\nand though everywhere beloved for the friendliness of his heart\nand his amiable temper, his talents could not have recommended him\nat any time.',
#  u'Her sister, though comparatively but little removed by matrimony,\nbeing settled in London, only sixteen miles off, was much beyond\nher daily reach; and many a long October and November evening must\nbe struggled through at Hartfield, before Christmas brought the next\nvisit from Isabella and her husband, and their little children,\nto fill the house, and give her pleasant society again.',
#  u'Highbury, the large and populous village, almost amounting to a town,\nto which Hartfield, in spite of its separate lawn, and shrubberies,\nand name, did really belong, afforded her no equals.',
#  u'The Woodhouses\nwere first in consequence there.',
#  u'All looked up to them.',
#  u'She had\nmany acquaintance in the place, for her father was universally civil,\nbut not one among them who could be accepted in lieu of Miss\nTaylor for even half a day.',
#  u'It was a melancholy change; and Emma\ncould not but sigh over it, and wish for impossible things,\ntill her father awoke, and made it necessary to be cheerful.',
#  u'His spirits required support.',
#  u'He was a nervous man, easily depressed;\nfond of every body that he was used to, and hating to part with them;\nhating change of every kind.',
#  u"Matrimony, as the origin of change,\nwas always disagreeable; and he was by no means yet reconciled\nto his own daughter's marrying, nor could ever speak of her but\nwith compassion, though it had been entirely a match of affection,\nwhen he was now obliged to part with Miss Taylor too; and from\nhis habits of gentle selfishness, and of being never able to\nsuppose that other people could feel differently from himself,\nhe was very much disposed to think Miss Taylor had done as sad\na thing for herself as for them, and would have been a great deal\nhappier if she had spent all the rest of her life at Hartfield.",
#  u'Emma smiled and chatted as cheerfully as she could, to keep him\nfrom such thoughts; but when tea came, it was impossible for him\nnot to say exactly as he had said at dinner,\n\n"Poor Miss Taylor!--I wish she were here again.',
#  u'What a pity it\nis that Mr. Weston ever thought of her!"',
#  u'"I cannot agree with you, papa; you know I cannot.',
#  u'Mr. Weston is such\na good-humoured, pleasant, excellent man, that he thoroughly deserves\na good wife;--and you would not have had Miss Taylor live with us\nfor ever, and bear all my odd humours, when she might have a house of her own?"',
#  u'"A house of her own!--But where is the advantage of a house of her own?',
#  u'This is three times as large.--And you have never any odd humours,\nmy dear."',
#  u'"How often we shall be going to see them, and they coming to see\nus!--We shall be always meeting!',
#  u'_We_ must begin; we must go and pay\nwedding visit very soon."',
#  u'"My dear, how am I to get so far?',
#  u'Randalls is such a distance.',
#  u'I could not walk half so far."',
#  u'"No, papa, nobody thought of your walking.',
#  u'We must go in the carriage,\nto be sure."',
#  u'"The carriage!',
#  u'But James will not like to put the horses to for\nsuch a little way;--and where are the poor horses to be while we\nare paying our visit?"',
#  u'"They are to be put into Mr. Weston\'s stable, papa.',
#  u'You know we\nhave settled all that already.',
#  u'We talked it all over with Mr. Weston\nlast night.',
#  u"And as for James, you may be very sure he will always like\ngoing to Randalls, because of his daughter's being housemaid there.",
#  u'I only doubt whether he will ever take us anywhere else.',
#  u'That was\nyour doing, papa.',
#  u'You got Hannah that good place.',
#  u'Nobody thought\nof Hannah till you mentioned her--James is so obliged to you!"',
#  u'"I am very glad I did think of her.',
#  u'It was very lucky, for I would\nnot have had poor James think himself slighted upon any account;\nand I am sure she will make a very good servant: she is a civil,\npretty-spoken girl; I have a great opinion of her.',
#  u'Whenever I see her,\nshe always curtseys and asks me how I do, in a very pretty manner;\nand when you have had her here to do needlework, I observe she\nalways turns the lock of the door the right way and never bangs it.',
#  u'I am sure she will be an excellent servant; and it will be a great\ncomfort to poor Miss Taylor to have somebody about her that she is\nused to see.',
#  u'Whenever James goes over to see his daughter, you know,\nshe will be hearing of us.',
#  u'He will be able to tell her how we\nall are."',
#  u'Emma spared no exertions to maintain this happier flow of ideas,\nand hoped, by the help of backgammon, to get her father tolerably\nthrough the evening, and be attacked by no regrets but her own.',
#  u'The backgammon-table was placed; but a visitor immediately afterwards\nwalked in and made it unnecessary.',
#  u"Mr. Knightley, a sensible man about seven or eight-and-thirty, was not\nonly a very old and intimate friend of the family, but particularly\nconnected with it, as the elder brother of Isabella's husband.",
#  u'He lived about a mile from Highbury, was a frequent visitor,\nand always welcome, and at this time more welcome than usual,\nas coming directly from their mutual connexions in London.',
#  u"He had\nreturned to a late dinner, after some days' absence, and now walked\nup to Hartfield to say that all were well in Brunswick Square.",
#  u'It was a happy circumstance, and animated Mr. Woodhouse for some time.',
#  u'Mr. Knightley had a cheerful manner, which always did him good;\nand his many inquiries after "poor Isabella" and her children were\nanswered most satisfactorily.',
#  u'When this was over, Mr. Woodhouse\ngratefully observed, "It is very kind of you, Mr. Knightley, to come\nout at this late hour to call upon us.',
#  u'I am afraid you must have\nhad a shocking walk."',
#  u'"Not at all, sir.',
#  u'It is a beautiful moonlight night; and so mild\nthat I must draw back from your great fire."',
#  u'"But you must have found it very damp and dirty.',
#  u'I wish you may\nnot catch cold."',
#  u'"Dirty, sir!',
#  u'Look at my shoes.',
#  u'Not a speck on them."',
#  u'"Well!',
#  u'that is quite surprising, for we have had a vast deal\nof rain here.',
#  u'It rained dreadfully hard for half an hour\nwhile we were at breakfast.',
#  u'I wanted them to put off the wedding."',
#  u'"By the bye--I have not wished you joy.',
#  u'Being pretty well aware\nof what sort of joy you must both be feeling, I have been in no hurry\nwith my congratulations; but I hope it all went off tolerably well.',
#  u'How did you all behave?',
#  u'Who cried most?"',
#  u'"Ah!',
#  u'poor Miss Taylor!',
#  u'\'Tis a sad business."',
#  u'"Poor Mr. and Miss Woodhouse, if you please; but I cannot possibly\nsay `poor Miss Taylor.\'',
#  u'I have a great regard for you and Emma;\nbut when it comes to the question of dependence or independence!--At\nany rate, it must be better to have only one to please than two."',
#  u'"Especially when _one_ of those two is such a fanciful, troublesome creature!"',
#  u'said Emma playfully.',
#  u'"That is what you have in your head,\nI know--and what you would certainly say if my father were not by."',
#  u'"I believe it is very true, my dear, indeed," said Mr. Woodhouse,\nwith a sigh.',
#  u'"I am afraid I am sometimes very fanciful and troublesome."',
#  u'"My dearest papa!',
#  u'You do not think I could mean _you_, or suppose\nMr. Knightley to mean _you_.',
#  u'What a horrible idea!',
#  u'Oh no!',
#  u'I meant\nonly myself.',
#  u'Mr. Knightley loves to find fault with me, you know--\nin a joke--it is all a joke.',
#  u'We always say what we like to one another."',
#  u'Mr. Knightley, in fact, was one of the few people who could see\nfaults in Emma Woodhouse, and the only one who ever told her of them:\nand though this was not particularly agreeable to Emma herself,\nshe knew it would be so much less so to her father, that she would\nnot have him really suspect such a circumstance as her not being\nthought perfect by every body.',
#  u'"Emma knows I never flatter her," said Mr. Knightley, "but I\nmeant no reflection on any body.',
#  u'Miss Taylor has been used\nto have two persons to please; she will now have but one.',
#  u'The chances are that she must be a gainer."',
#  u'"Well," said Emma, willing to let it pass--"you want to hear\nabout the wedding; and I shall be happy to tell you, for we all\nbehaved charmingly.',
#  u'Every body was punctual, every body in their\nbest looks: not a tear, and hardly a long face to be seen.',
#  u'Oh no;\nwe all felt that we were going to be only half a mile apart,\nand were sure of meeting every day."',
#  u'"Dear Emma bears every thing so well," said her father.',
#  u'"But, Mr. Knightley, she is really very sorry to lose poor Miss Taylor,\nand I am sure she _will_ miss her more than she thinks for."',
#  u'Emma turned away her head, divided between tears and smiles.',
#  u'"It is impossible that Emma should not miss such a companion,"\nsaid Mr. Knightley.',
#  u'"We should not like her so well as we do, sir,\nif we could suppose it; but she knows how much the marriage is to\nMiss Taylor\'s advantage; she knows how very acceptable it must be,\nat Miss Taylor\'s time of life, to be settled in a home of her own,\nand how important to her to be secure of a comfortable provision,\nand therefore cannot allow herself to feel so much pain as pleasure.',
#  u'Every friend of Miss Taylor must be glad to have her so happily\nmarried."',
#  u'"And you have forgotten one matter of joy to me," said Emma,\n"and a very considerable one--that I made the match myself.',
#  u'I made the match, you know, four years ago; and to have it take place,\nand be proved in the right, when so many people said Mr. Weston would\nnever marry again, may comfort me for any thing."',
#  u'Mr. Knightley shook his head at her.',
#  u'Her father fondly replied,\n"Ah!',
#  u'my dear, I wish you would not make matches and foretell things,\nfor whatever you say always comes to pass.',
#  u'Pray do not make any\nmore matches."',
#  u'"I promise you to make none for myself, papa; but I must, indeed,\nfor other people.',
#  u'It is the greatest amusement in the world!',
#  u'And\nafter such success, you know!--Every body said that Mr. Weston would\nnever marry again.',
#  u'Oh dear, no!',
#  u'Mr. Weston, who had been a widower\nso long, and who seemed so perfectly comfortable without a wife,\nso constantly occupied either in his business in town or among his\nfriends here, always acceptable wherever he went, always cheerful--\nMr. Weston need not spend a single evening in the year alone if he did\nnot like it.',
#  u'Oh no!',
#  u'Mr. Weston certainly would never marry again.',
#  u'Some people even talked of a promise to his wife on her deathbed,\nand others of the son and the uncle not letting him.',
#  u'All manner\nof solemn nonsense was talked on the subject, but I believed none\nof it.',
#  u'"Ever since the day--about four years ago--that Miss Taylor and I\nmet with him in Broadway Lane, when, because it began to drizzle,\nhe darted away with so much gallantry, and borrowed two umbrellas\nfor us from Farmer Mitchell\'s, I made up my mind on the subject.',
#  u'I planned the match from that hour; and when such success has blessed\nme in this instance, dear papa, you cannot think that I shall leave\noff match-making."',
#  u'"I do not understand what you mean by `success,\'" said Mr. Knightley.',
#  u'"Success supposes endeavour.',
#  u'Your time has been properly and\ndelicately spent, if you have been endeavouring for the last four\nyears to bring about this marriage.',
#  u"A worthy employment for a young\nlady's mind!",
#  u"But if, which I rather imagine, your making the match,\nas you call it, means only your planning it, your saying to yourself\none idle day, `I think it would be a very good thing for Miss Taylor\nif Mr. Weston were to marry her,' and saying it again to yourself\nevery now and then afterwards, why do you talk of success?",
#  u'Where\nis your merit?',
#  u'What are you proud of?',
#  u'You made a lucky guess;\nand _that_ is all that can be said."',
#  u'"And have you never known the pleasure and triumph of a lucky guess?--\nI pity you.--I thought you cleverer--for, depend upon it a lucky\nguess is never merely luck.',
#  u'There is always some talent in it.',
#  u"And as to my poor word `success,' which you quarrel with, I do not\nknow that I am so entirely without any claim to it.",
#  u'You have drawn\ntwo pretty pictures; but I think there may be a third--a something\nbetween the do-nothing and the do-all.',
#  u"If I had not promoted Mr. Weston's\nvisits here, and given many little encouragements, and smoothed\nmany little matters, it might not have come to any thing after all.",
#  u'I think you must know Hartfield enough to comprehend that."',
#  u'"A straightforward, open-hearted man like Weston, and a rational,\nunaffected woman like Miss Taylor, may be safely left to manage their\nown concerns.',
#  u'You are more likely to have done harm to yourself,\nthan good to them, by interference."',
#  u'"Emma never thinks of herself, if she can do good to others,"\nrejoined Mr. Woodhouse, understanding but in part.',
#  u'"But, my dear,\npray do not make any more matches; they are silly things, and break up\none\'s family circle grievously."',
#  u'"Only one more, papa; only for Mr. Elton.',
#  u'Poor Mr. Elton!',
#  u'You\nlike Mr. Elton, papa,--I must look about for a wife for him.',
#  u'There is nobody in Highbury who deserves him--and he has been\nhere a whole year, and has fitted up his house so comfortably,\nthat it would be a shame to have him single any longer--and I thought\nwhen he was joining their hands to-day, he looked so very much as if\nhe would like to have the same kind office done for him!',
#  u'I think\nvery well of Mr. Elton, and this is the only way I have of doing\nhim a service."',
#  u'"Mr. Elton is a very pretty young man, to be sure, and a very\ngood young man, and I have a great regard for him.',
#  u'But if you\nwant to shew him any attention, my dear, ask him to come\nand dine with us some day.',
#  u'That will be a much better thing.',
#  u'I dare say Mr. Knightley will be so kind as to meet him."',
#  u'"With a great deal of pleasure, sir, at any time," said Mr. Knightley,\nlaughing, "and I agree with you entirely, that it will be a much\nbetter thing.',
#  u'Invite him to dinner, Emma, and help him to the best\nof the fish and the chicken, but leave him to chuse his own wife.',
#  u'Depend upon it, a man of six or seven-and-twenty can take care\nof himself."',
#  u'CHAPTER II\n\n\nMr. Weston was a native of Highbury, and born of a respectable family,\nwhich for the last two or three generations had been rising into\ngentility and property.',
#  u'He had received a good education, but,\non succeeding early in life to a small independence, had become\nindisposed for any of the more homely pursuits in which his brothers\nwere engaged, and had satisfied an active, cheerful mind and social\ntemper by entering into the militia of his county, then embodied.',
#  u'Captain Weston was a general favourite; and when the chances\nof his military life had introduced him to Miss Churchill,\nof a great Yorkshire family, and Miss Churchill fell in love\nwith him, nobody was surprized, except her brother and his wife,\nwho had never seen him, and who were full of pride and importance,\nwhich the connexion would offend.',
#  u'Miss Churchill, however, being of age, and with the full command\nof her fortune--though her fortune bore no proportion to the\nfamily-estate--was not to be dissuaded from the marriage, and it\ntook place, to the infinite mortification of Mr. and Mrs. Churchill,\nwho threw her off with due decorum.',
#  u'It was an unsuitable connexion,\nand did not produce much happiness.',
#  u'Mrs. Weston ought to have found\nmore in it, for she had a husband whose warm heart and sweet temper\nmade him think every thing due to her in return for the great goodness\nof being in love with him; but though she had one sort of spirit,\nshe had not the best.',
#  u"She had resolution enough to pursue\nher own will in spite of her brother, but not enough to refrain\nfrom unreasonable regrets at that brother's unreasonable anger,\nnor from missing the luxuries of her former home.",
#  u'They lived beyond\ntheir income, but still it was nothing in comparison of Enscombe:\nshe did not cease to love her husband, but she wanted at once\nto be the wife of Captain Weston, and Miss Churchill of Enscombe.',
#  u"Captain Weston, who had been considered, especially by the Churchills,\nas making such an amazing match, was proved to have much the worst\nof the bargain; for when his wife died, after a three years' marriage,\nhe was rather a poorer man than at first, and with a child to maintain.",
#  u'From the expense of the child, however, he was soon relieved.',
#  u"The boy had, with the additional softening claim of a lingering\nillness of his mother's, been the means of a sort of reconciliation;\nand Mr. and Mrs. Churchill, having no children of their own,\nnor any other young creature of equal kindred to care for, offered to\ntake the whole charge of the little Frank soon after her decease.",
#  u'Some scruples and some reluctance the widower-father may be supposed\nto have felt; but as they were overcome by other considerations,\nthe child was given up to the care and the wealth of the Churchills,\nand he had only his own comfort to seek, and his own situation to\nimprove as he could.',
#  u'A complete change of life became desirable.',
#  u'He quitted the militia\nand engaged in trade, having brothers already established in a\ngood way in London, which afforded him a favourable opening.',
#  u'It was a concern which brought just employment enough.',
#  u'He had still\na small house in Highbury, where most of his leisure days were spent;\nand between useful occupation and the pleasures of society,\nthe next eighteen or twenty years of his life passed cheerfully away.',
#  u'He had, by that time, realised an easy competence--enough to secure\nthe purchase of a little estate adjoining Highbury, which he had\nalways longed for--enough to marry a woman as portionless even\nas Miss Taylor, and to live according to the wishes of his own\nfriendly and social disposition.',
#  u'It was now some time since Miss Taylor had begun to influence\nhis schemes; but as it was not the tyrannic influence of youth\non youth, it had not shaken his determination of never settling\ntill he could purchase Randalls, and the sale of Randalls was long\nlooked forward to; but he had gone steadily on, with these objects\nin view, till they were accomplished.',
#  u'He had made his fortune,\nbought his house, and obtained his wife; and was beginning a new\nperiod of existence, with every probability of greater happiness\nthan in any yet passed through.',
#  u'He had never been an unhappy man;\nhis own temper had secured him from that, even in his first marriage;\nbut his second must shew him how delightful a well-judging and truly\namiable woman could be, and must give him the pleasantest proof\nof its being a great deal better to choose than to be chosen,\nto excite gratitude than to feel it.',
#  u"He had only himself to please in his choice: his fortune was\nhis own; for as to Frank, it was more than being tacitly brought\nup as his uncle's heir, it had become so avowed an adoption\nas to have him assume the name of Churchill on coming of age.",
#  u"It was most unlikely, therefore, that he should ever want his\nfather's assistance.",
#  u'His father had no apprehension of it.',
#  u"The aunt was a capricious woman, and governed her husband entirely;\nbut it was not in Mr. Weston's nature to imagine that any caprice\ncould be strong enough to affect one so dear, and, as he believed,\nso deservedly dear.",
#  u'He saw his son every year in London,\nand was proud of him; and his fond report of him as a very fine\nyoung man had made Highbury feel a sort of pride in him too.',
#  u'He was looked on as sufficiently belonging to the place to make his\nmerits and prospects a kind of common concern.',
#  u'Mr. Frank Churchill was one of the boasts of Highbury, and a lively\ncuriosity to see him prevailed, though the compliment was so little\nreturned that he had never been there in his life.',
#  u'His coming\nto visit his father had been often talked of but never achieved.',
#  u"Now, upon his father's marriage, it was very generally proposed,\nas a most proper attention, that the visit should take place.",
#  u'There was not a dissentient voice on the subject, either when\nMrs. Perry drank tea with Mrs. and Miss Bates, or when Mrs. and\nMiss Bates returned the visit.',
#  u'Now was the time for Mr. Frank\nChurchill to come among them; and the hope strengthened when it was\nunderstood that he had written to his new mother on the occasion.',
#  u'For a few days, every morning visit in Highbury included some mention\nof the handsome letter Mrs. Weston had received.',
#  u'"I suppose you\nhave heard of the handsome letter Mr. Frank Churchill has written\nto Mrs. Weston?',
#  u'I understand it was a very handsome letter, indeed.',
#  u'Mr. Woodhouse told me of it.',
#  u'Mr. Woodhouse saw the letter, and he\nsays he never saw such a handsome letter in his life."',
#  u'It was, indeed, a highly prized letter.',
#  u'Mrs. Weston had, of course,\nformed a very favourable idea of the young man; and such a pleasing\nattention was an irresistible proof of his great good sense,\nand a most welcome addition to every source and every expression\nof congratulation which her marriage had already secured.',
#  u'She felt\nherself a most fortunate woman; and she had lived long enough\nto know how fortunate she might well be thought, where the only\nregret was for a partial separation from friends whose friendship\nfor her had never cooled, and who could ill bear to part with her.',
#  u"She knew that at times she must be missed; and could not think,\nwithout pain, of Emma's losing a single pleasure, or suffering\nan hour's ennui, from the want of her companionableness: but dear\nEmma was of no feeble character; she was more equal to her situation\nthan most girls would have been, and had sense, and energy,\nand spirits that might be hoped would bear her well and happily\nthrough its little difficulties and privations.",
#  u"And then there was\nsuch comfort in the very easy distance of Randalls from Hartfield,\nso convenient for even solitary female walking, and in Mr. Weston's\ndisposition and circumstances, which would make the approaching\nseason no hindrance to their spending half the evenings in the\nweek together.",
#  u"Her situation was altogether the subject of hours of gratitude\nto Mrs. Weston, and of moments only of regret; and her\nsatisfaction--her more than satisfaction--her cheerful enjoyment,\nwas so just and so apparent, that Emma, well as she knew her father,\nwas sometimes taken by surprize at his being still able to pity\n`poor Miss Taylor,' when they left her at Randalls in the centre\nof every domestic comfort, or saw her go away in the evening\nattended by her pleasant husband to a carriage of her own.",
#  u'But never did she go without Mr. Woodhouse\'s giving a gentle sigh,\nand saying, "Ah, poor Miss Taylor!',
#  u'She would be very glad to stay."',
#  u'There was no recovering Miss Taylor--nor much likelihood of\nceasing to pity her; but a few weeks brought some alleviation\nto Mr. Woodhouse.',
#  u'The compliments of his neighbours were over;\nhe was no longer teased by being wished joy of so sorrowful an event;\nand the wedding-cake, which had been a great distress to him,\nwas all eat up.',
#  u'His own stomach could bear nothing rich, and he\ncould never believe other people to be different from himself.',
#  u"What was unwholesome to him he regarded as unfit for any body;\nand he had, therefore, earnestly tried to dissuade them from having\nany wedding-cake at all, and when that proved vain, as earnestly\ntried to prevent any body's eating it.",
#  u'He had been at the pains\nof consulting Mr. Perry, the apothecary, on the subject.',
#  u"Mr. Perry\nwas an intelligent, gentlemanlike man, whose frequent visits were one\nof the comforts of Mr. Woodhouse's life; and upon being applied to,\nhe could not but acknowledge (though it seemed rather against the\nbias of inclination) that wedding-cake might certainly disagree\nwith many--perhaps with most people, unless taken moderately.",
#  u'With such an opinion, in confirmation of his own, Mr. Woodhouse hoped\nto influence every visitor of the newly married pair; but still the\ncake was eaten; and there was no rest for his benevolent nerves till\nit was all gone.',
#  u"There was a strange rumour in Highbury of all the little Perrys\nbeing seen with a slice of Mrs. Weston's wedding-cake in their\nhands: but Mr. Woodhouse would never believe it.",
#  u'CHAPTER III\n\n\nMr. Woodhouse was fond of society in his own way.',
#  u'He liked very much\nto have his friends come and see him; and from various united causes,\nfrom his long residence at Hartfield, and his good nature,\nfrom his fortune, his house, and his daughter, he could command the\nvisits of his own little circle, in a great measure, as he liked.',
#  u'He had not much intercourse with any families beyond that circle;\nhis horror of late hours, and large dinner-parties, made him unfit\nfor any acquaintance but such as would visit him on his own terms.',
#  u'Fortunately for him, Highbury, including Randalls in the same parish,\nand Donwell Abbey in the parish adjoining, the seat of Mr. Knightley,\ncomprehended many such.',
#  u"Not unfrequently, through Emma's persuasion,\nhe had some of the chosen and the best to dine with him: but evening\nparties were what he preferred; and, unless he fancied himself at any\ntime unequal to company, there was scarcely an evening in the week\nin which Emma could not make up a card-table for him.",
#  u"Real, long-standing regard brought the Westons and Mr. Knightley;\nand by Mr. Elton, a young man living alone without liking it,\nthe privilege of exchanging any vacant evening of his own blank solitude\nfor the elegancies and society of Mr. Woodhouse's drawing-room,\nand the smiles of his lovely daughter, was in no danger of being\nthrown away.",
#  u'After these came a second set; among the most come-at-able\nof whom were Mrs. and Miss Bates, and Mrs. Goddard, three ladies\nalmost always at the service of an invitation from Hartfield,\nand who were fetched and carried home so often, that Mr. Woodhouse\nthought it no hardship for either James or the horses.',
#  u'Had it\ntaken place only once a year, it would have been a grievance.',
#  u'Mrs. Bates, the widow of a former vicar of Highbury, was a\nvery old lady, almost past every thing but tea and quadrille.',
#  u'She lived with her single daughter in a very small way, and was\nconsidered with all the regard and respect which a harmless old lady,\nunder such untoward circumstances, can excite.',
#  u'Her daughter enjoyed\na most uncommon degree of popularity for a woman neither young,\nhandsome, rich, nor married.',
#  u'Miss Bates stood in the very worst\npredicament in the world for having much of the public favour;\nand she had no intellectual superiority to make atonement to herself,\nor frighten those who might hate her into outward respect.',
#  u'She had never boasted either beauty or cleverness.',
#  u'Her youth\nhad passed without distinction, and her middle of life was devoted\nto the care of a failing mother, and the endeavour to make a small\nincome go as far as possible.',
#  u'And yet she was a happy woman,\nand a woman whom no one named without good-will.',
#  u'It was her own\nuniversal good-will and contented temper which worked such wonders.',
#  u"She loved every body, was interested in every body's happiness,\nquicksighted to every body's merits; thought herself a most fortunate\ncreature, and surrounded with blessings in such an excellent mother,\nand so many good neighbours and friends, and a home that wanted\nfor nothing.",
#  u'The simplicity and cheerfulness of her nature,\nher contented and grateful spirit, were a recommendation to every body,\nand a mine of felicity to herself.',
#  u'She was a great talker upon\nlittle matters, which exactly suited Mr. Woodhouse, full of trivial\ncommunications and harmless gossip.',
#  u'Mrs. Goddard was the mistress of a School--not of a seminary,\nor an establishment, or any thing which professed, in long sentences of\nrefined nonsense, to combine liberal acquirements with elegant morality,\nupon new principles and new systems--and where young ladies for\nenormous pay might be screwed out of health and into vanity--but\na real, honest, old-fashioned Boarding-school, where a reasonable\nquantity of accomplishments were sold at a reasonable price,\nand where girls might be sent to be out of the way, and scramble\nthemselves into a little education, without any danger of coming\nback prodigies.',
#  u"Mrs. Goddard's school was in high repute--and\nvery deservedly; for Highbury was reckoned a particularly healthy\nspot: she had an ample house and garden, gave the children plenty\nof wholesome food, let them run about a great deal in the summer,\nand in winter dressed their chilblains with her own hands.",
#  u'It was no wonder that a train of twenty young couple now walked\nafter her to church.',
#  u"She was a plain, motherly kind of woman,\nwho had worked hard in her youth, and now thought herself entitled\nto the occasional holiday of a tea-visit; and having formerly\nowed much to Mr. Woodhouse's kindness, felt his particular claim\non her to leave her neat parlour, hung round with fancy-work,\nwhenever she could, and win or lose a few sixpences by his fireside.",
#  u"These were the ladies whom Emma found herself very frequently\nable to collect; and happy was she, for her father's sake,\nin the power; though, as far as she was herself concerned,\nit was no remedy for the absence of Mrs. Weston.",
#  u'She was delighted\nto see her father look comfortable, and very much pleased with\nherself for contriving things so well; but the quiet prosings\nof three such women made her feel that every evening so spent\nwas indeed one of the long evenings she had fearfully anticipated.',
#  u'As she sat one morning, looking forward to exactly such a close\nof the present day, a note was brought from Mrs. Goddard, requesting,\nin most respectful terms, to be allowed to bring Miss Smith with her;\na most welcome request: for Miss Smith was a girl of seventeen,\nwhom Emma knew very well by sight, and had long felt an interest in,\non account of her beauty.',
#  u'A very gracious invitation was returned,\nand the evening no longer dreaded by the fair mistress of the mansion.',
#  u'Harriet Smith was the natural daughter of somebody.',
#  u"Somebody had\nplaced her, several years back, at Mrs. Goddard's school,\nand somebody had lately raised her from the condition of scholar\nto that of parlour-boarder.",
#  u'This was all that was generally known\nof her history.',
#  u'She had no visible friends but what had been\nacquired at Highbury, and was now just returned from a long visit\nin the country to some young ladies who had been at school there with her.',
#  u'She was a very pretty girl, and her beauty happened to be of a sort\nwhich Emma particularly admired.',
#  u'She was short, plump, and fair,\nwith a fine bloom, blue eyes, light hair, regular features,\nand a look of great sweetness, and, before the end of the evening,\nEmma was as much pleased with her manners as her person, and quite\ndetermined to continue the acquaintance.',
#  u"She was not struck by any thing remarkably clever in Miss Smith's\nconversation, but she found her altogether very engaging--not\ninconveniently shy, not unwilling to talk--and yet so far from pushing,\nshewing so proper and becoming a deference, seeming so pleasantly\ngrateful for being admitted to Hartfield, and so artlessly\nimpressed by the appearance of every thing in so superior a style\nto what she had been used to, that she must have good sense,\nand deserve encouragement.",
#  u'Encouragement should be given.',
#  u'Those soft blue eyes, and all those natural graces, should not be\nwasted on the inferior society of Highbury and its connexions.',
#  u'The acquaintance she had already formed were unworthy of her.',
#  u'The friends from whom she had just parted, though very good sort\nof people, must be doing her harm.',
#  u'They were a family of the name\nof Martin, whom Emma well knew by character, as renting a large farm\nof Mr. Knightley, and residing in the parish of Donwell--very creditably,\nshe believed--she knew Mr. Knightley thought highly of them--but they\nmust be coarse and unpolished, and very unfit to be the intimates\nof a girl who wanted only a little more knowledge and elegance\nto be quite perfect.',
#  u'_She_ would notice her; she would improve her;\nshe would detach her from her bad acquaintance, and introduce her\ninto good society; she would form her opinions and her manners.',
#  u'It would be an interesting, and certainly a very kind undertaking;\nhighly becoming her own situation in life, her leisure, and powers.',
#  u'She was so busy in admiring those soft blue eyes, in talking\nand listening, and forming all these schemes in the in-betweens, that\nthe evening flew away at a very unusual rate; and the supper-table,\nwhich always closed such parties, and for which she had been\nused to sit and watch the due time, was all set out and ready,\nand moved forwards to the fire, before she was aware.',
#  u'With an\nalacrity beyond the common impulse of a spirit which yet was never\nindifferent to the credit of doing every thing well and attentively,\nwith the real good-will of a mind delighted with its own ideas,\ndid she then do all the honours of the meal, and help and recommend\nthe minced chicken and scalloped oysters, with an urgency which she\nknew would be acceptable to the early hours and civil scruples of their guests.',
#  u'Upon such occasions poor Mr. Woodhouses feelings were in sad warfare.',
#  u'He loved to have the cloth laid, because it had been the fashion\nof his youth, but his conviction of suppers being very unwholesome\nmade him rather sorry to see any thing put on it; and while his\nhospitality would have welcomed his visitors to every thing,\nhis care for their health made him grieve that they would eat.',
#  u'Such another small basin of thin gruel as his own was all that\nhe could, with thorough self-approbation, recommend; though he\nmight constrain himself, while the ladies were comfortably clearing\nthe nicer things, to say:\n\n"Mrs. Bates, let me propose your venturing on one of these eggs.',
#  u'An egg boiled very soft is not unwholesome.',
#  u'Serle understands boiling\nan egg better than any body.',
#  u'I would not recommend an egg boiled\nby any body else; but you need not be afraid, they are very small,\nyou see--one of our small eggs will not hurt you.',
#  u'Miss Bates,\nlet Emma help you to a _little_ bit of tart--a _very_ little bit.',
#  u'Ours are all apple-tarts.',
#  u'You need not be afraid of unwholesome\npreserves here.',
#  u'I do not advise the custard.',
#  u'Mrs. Goddard, what say\nyou to _half_ a glass of wine?',
#  u'A _small_ half-glass, put into a tumbler\nof water?',
#  u'I do not think it could disagree with you."',
#  u'Emma allowed her father to talk--but supplied her visitors in\na much more satisfactory style, and on the present evening had\nparticular pleasure in sending them away happy.',
#  u'The happiness\nof Miss Smith was quite equal to her intentions.',
#  u'Miss Woodhouse\nwas so great a personage in Highbury, that the prospect of the\nintroduction had given as much panic as pleasure; but the humble,\ngrateful little girl went off with highly gratified feelings,\ndelighted with the affability with which Miss Woodhouse had treated\nher all the evening, and actually shaken hands with her at last!',
#  u"CHAPTER IV\n\n\nHarriet Smith's intimacy at Hartfield was soon a settled thing.",
#  u'Quick and decided in her ways, Emma lost no time in inviting, encouraging,\nand telling her to come very often; and as their acquaintance increased,\nso did their satisfaction in each other.',
#  u'As a walking companion,\nEmma had very early foreseen how useful she might find her.',
#  u"In that respect Mrs. Weston's loss had been important.",
#  u"Her father\nnever went beyond the shrubbery, where two divisions of the ground\nsufficed him for his long walk, or his short, as the year varied;\nand since Mrs. Weston's marriage her exercise had been too much confined.",
#  u'She had ventured once alone to Randalls, but it was not pleasant;\nand a Harriet Smith, therefore, one whom she could summon at any\ntime to a walk, would be a valuable addition to her privileges.',
#  u'But in every respect, as she saw more of her, she approved her,\nand was confirmed in all her kind designs.',
#  u'Harriet certainly was not clever, but she had a sweet, docile,\ngrateful disposition, was totally free from conceit, and only desiring\nto be guided by any one she looked up to.',
#  u'Her early attachment\nto herself was very amiable; and her inclination for good company,\nand power of appreciating what was elegant and clever, shewed that\nthere was no want of taste, though strength of understanding must\nnot be expected.',
#  u"Altogether she was quite convinced of Harriet\nSmith's being exactly the young friend she wanted--exactly the\nsomething which her home required.",
#  u'Such a friend as Mrs. Weston\nwas out of the question.',
#  u'Two such could never be granted.',
#  u'Two such she did not want.',
#  u'It was quite a different sort of thing,\na sentiment distinct and independent.',
#  u'Mrs. Weston was the object\nof a regard which had its basis in gratitude and esteem.',
#  u'Harriet would be loved as one to whom she could be useful.',
#  u'For Mrs. Weston there was nothing to be done; for Harriet every thing.',
#  u'Her first attempts at usefulness were in an endeavour to find out who\nwere the parents, but Harriet could not tell.',
#  u'She was ready to tell\nevery thing in her power, but on this subject questions were vain.',
#  u'Emma was obliged to fancy what she liked--but she could never\nbelieve that in the same situation _she_ should not have discovered\nthe truth.',
#  u'Harriet had no penetration.',
#  u'She had been satisfied\nto hear and believe just what Mrs. Goddard chose to tell her;\nand looked no farther.',
#  u'Mrs. Goddard, and the teachers, and the girls and the affairs of the\nschool in general, formed naturally a great part of the conversation--and\nbut for her acquaintance with the Martins of Abbey-Mill Farm,\nit must have been the whole.',
#  u'But the Martins occupied her thoughts\na good deal; she had spent two very happy months with them,\nand now loved to talk of the pleasures of her visit, and describe\nthe many comforts and wonders of the place.',
#  u'Emma encouraged her\ntalkativeness--amused by such a picture of another set of beings,\nand enjoying the youthful simplicity which could speak with so much\nexultation of Mrs. Martin\'s having "_two_ parlours, two very good parlours,\nindeed; one of them quite as large as Mrs. Goddard\'s drawing-room;\nand of her having an upper maid who had lived five-and-twenty years\nwith her; and of their having eight cows, two of them Alderneys,\nand one a little Welch cow, a very pretty little Welch cow indeed;\nand of Mrs. Martin\'s saying as she was so fond of it, it should be\ncalled _her_ cow; and of their having a very handsome summer-house\nin their garden, where some day next year they were all to drink\ntea:--a very handsome summer-house, large enough to hold a dozen people."',
#  u'For some time she was amused, without thinking beyond the immediate cause;\nbut as she came to understand the family better, other feelings arose.',
#  u"She had taken up a wrong idea, fancying it was a mother and daughter,\na son and son's wife, who all lived together; but when it appeared\nthat the Mr. Martin, who bore a part in the narrative, and was always\nmentioned with approbation for his great good-nature in doing something\nor other, was a single man; that there was no young Mrs. Martin,\nno wife in the case; she did suspect danger to her poor little\nfriend from all this hospitality and kindness, and that, if she\nwere not taken care of, she might be required to sink herself forever.",
#  u'With this inspiriting notion, her questions increased in number\nand meaning; and she particularly led Harriet to talk more of Mr. Martin,\nand there was evidently no dislike to it.',
#  u'Harriet was very ready\nto speak of the share he had had in their moonlight walks and merry\nevening games; and dwelt a good deal upon his being so very good-humoured\nand obliging.',
#  u'He had gone three miles round one day in order to bring\nher some walnuts, because she had said how fond she was of them,\nand in every thing else he was so very obliging.',
#  u"He had his\nshepherd's son into the parlour one night on purpose to sing to her.",
#  u'She was very fond of singing.',
#  u'He could sing a little himself.',
#  u'She believed he was very clever, and understood every thing.',
#  u'He had a very fine flock, and, while she was with them,\nhe had been bid more for his wool than any body in the country.',
#  u'She believed every body spoke well of him.',
#  u'His mother and sisters\nwere very fond of him.',
#  u'Mrs. Martin had told her one day (and there\nwas a blush as she said it,) that it was impossible for any body\nto be a better son, and therefore she was sure, whenever he married,\nhe would make a good husband.',
#  u'Not that she _wanted_ him to marry.',
#  u'She was in no hurry at all.',
#  u'"Well done, Mrs.',
#  u'Martin!"',
#  u'thought Emma.',
#  u'"You know what you are about."',
#  u'"And when she had come away, Mrs. Martin was so very kind as to send\nMrs. Goddard a beautiful goose--the finest goose Mrs. Goddard had\never seen.',
#  u'Mrs. Goddard had dressed it on a Sunday, and asked all\nthe three teachers, Miss Nash, and Miss Prince, and Miss Richardson,\nto sup with her."',
#  u'"Mr. Martin, I suppose, is not a man of information beyond the line\nof his own business?',
#  u'He does not read?"',
#  u'"Oh yes!--that is, no--I do not know--but I believe he has\nread a good deal--but not what you would think any thing of.',
#  u'He reads the Agricultural Reports, and some other books that lay\nin one of the window seats--but he reads all _them_ to himself.',
#  u'But sometimes of an evening, before we went to cards, he would read\nsomething aloud out of the Elegant Extracts, very entertaining.',
#  u'And I know he has read the Vicar of Wakefield.',
#  u'He never read the\nRomance of the Forest, nor The Children of the Abbey.',
#  u'He had never\nheard of such books before I mentioned them, but he is determined\nto get them now as soon as ever he can."',
#  u'The next question was--\n\n"What sort of looking man is Mr.',
#  u'Martin?"',
#  u'"Oh!',
#  u'not handsome--not at all handsome.',
#  u'I thought him very plain\nat first, but I do not think him so plain now.',
#  u'One does not, you know,\nafter a time.',
#  u'But did you never see him?',
#  u'He is in Highbury every\nnow and then, and he is sure to ride through every week in his way\nto Kingston.',
#  u'He has passed you very often."',
#  u'"That may be, and I may have seen him fifty times, but without\nhaving any idea of his name.',
#  u'A young farmer, whether on horseback\nor on foot, is the very last sort of person to raise my curiosity.',
#  u'The yeomanry are precisely the order of people with whom I feel I\ncan have nothing to do.',
# ...
#  u'Hitherto I fancy you and I are the only people to whom his looks\nand manners have explained themselves."',
#  u'Harriet blushed and smiled, and said something about wondering\nthat people should like her so much.',
#  u'The idea of Mr. Elton was\ncertainly cheering; but still, after a time, she was tender-hearted\nagain towards the rejected Mr. Martin.',
#  u'"Now he has got my letter," said she softly.',
#  u'"I wonder what they\nare all doing--whether his sisters know--if he is unhappy,\nthey will be unhappy too.',
#  u'I hope he will not mind it so very much."',
#  u'"Let us think of those among our absent friends who are more\ncheerfully employed," cried Emma.',
#  u'"At this moment, perhaps, Mr. Elton\nis shewing your picture to his mother and sisters, telling how much\nmore beautiful is the original, and after being asked for it five\nor six times, allowing them to hear your name, your own dear name."',
#  u'"My picture!--But he has left my picture in Bond-street."',
#  u'"Has he so!--Then I know nothing of Mr. Elton.',
#  u'No, my dear\nlittle modest Harriet, depend upon it the picture will not be\nin Bond-street till just before he mounts his horse to-morrow.',
#  u'It is his companion all this evening, his solace, his delight.',
#  u'It opens his designs to his family, it introduces you among them,\nit diffuses through the party those pleasantest feelings of our nature,\neager curiosity and warm prepossession.',
#  u'How cheerful, how animated,\nhow suspicious, how busy their imaginations all are!"',
#  u'Harriet smiled again, and her smiles grew stronger.',
#  u'CHAPTER VIII\n\n\nHarriet slept at Hartfield that night.',
#  u'For some weeks past she\nhad been spending more than half her time there, and gradually\ngetting to have a bed-room appropriated to herself; and Emma\njudged it best in every respect, safest and kindest, to keep her\nwith them as much as possible just at present.',
#  u"She was obliged\nto go the next morning for an hour or two to Mrs. Goddard's,\nbut it was then to be settled that she should return to Hartfield,\nto make a regular visit of some days.",
#  u'While she was gone, Mr. Knightley called, and sat some time with\nMr. Woodhouse and Emma, till Mr. Woodhouse, who had previously made up\nhis mind to walk out, was persuaded by his daughter not to defer it,\nand was induced by the entreaties of both, though against the scruples\nof his own civility, to leave Mr. Knightley for that purpose.',
#  u'Mr. Knightley, who had nothing of ceremony about him, was offering\nby his short, decided answers, an amusing contrast to the protracted\napologies and civil hesitations of the other.',
#  u'"Well, I believe, if you will excuse me, Mr. Knightley, if you\nwill not consider me as doing a very rude thing, I shall take\nEmma\'s advice and go out for a quarter of an hour.',
#  u'As the sun\nis out, I believe I had better take my three turns while I can.',
#  u'I treat you without ceremony, Mr. Knightley.',
#  u'We invalids think we\nare privileged people."',
#  u'"My dear sir, do not make a stranger of me."',
#  u'"I leave an excellent substitute in my daughter.',
#  u'Emma will be happy\nto entertain you.',
#  u'And therefore I think I will beg your excuse\nand take my three turns--my winter walk."',
#  u'"You cannot do better, sir."',
#  u'"I would ask for the pleasure of your company, Mr. Knightley,\nbut I am a very slow walker, and my pace would be tedious to you;\nand, besides, you have another long walk before you, to Donwell Abbey."',
#  u'"Thank you, sir, thank you; I am going this moment myself; and I\nthink the sooner _you_ go the better.',
#  u'I will fetch your greatcoat\nand open the garden door for you."',
#  u'Mr. Woodhouse at last was off; but Mr. Knightley, instead of being\nimmediately off likewise, sat down again, seemingly inclined\nfor more chat.',
#  u'He began speaking of Harriet, and speaking\nof her with more voluntary praise than Emma had ever heard before.',
#  u'"I cannot rate her beauty as you do," said he; "but she is a\npretty little creature, and I am inclined to think very well of\nher disposition.',
#  u'Her character depends upon those she is with;\nbut in good hands she will turn out a valuable woman."',
#  u'"I am glad you think so; and the good hands, I hope, may not be wanting."',
#  u'"Come," said he, "you are anxious for a compliment, so I will\ntell you that you have improved her.',
#  u'You have cured her of her\nschool-girl\'s giggle; she really does you credit."',
#  u'"Thank you.',
#  u'I should be mortified indeed if I did not believe I\nhad been of some use; but it is not every body who will bestow\npraise where they may.',
#  u'_You_ do not often overpower me with it."',
#  u'"You are expecting her again, you say, this morning?"',
#  u'"Almost every moment.',
#  u'She has been gone longer already than\nshe intended."',
#  u'"Something has happened to delay her; some visitors perhaps."',
#  u'"Highbury gossips!--Tiresome wretches!"',
#  u'"Harriet may not consider every body tiresome that you would."',
#  u'Emma knew this was too true for contradiction, and therefore\nsaid nothing.',
#  u'He presently added, with a smile,\n\n"I do not pretend to fix on times or places, but I must tell you\nthat I have good reason to believe your little friend will soon\nhear of something to her advantage."',
#  u'"Indeed!',
#  u'how so?',
#  u'of what sort?"',
#  u'"A very serious sort, I assure you;" still smiling.',
#  u'"Very serious!',
#  u'I can think of but one thing--Who is in love\nwith her?',
#  u'Who makes you their confidant?"',
#  u"Emma was more than half in hopes of Mr. Elton's having dropt a hint.",
#  u'Mr. Knightley was a sort of general friend and adviser, and she knew\nMr. Elton looked up to him.',
#  u'"I have reason to think," he replied, "that Harriet Smith will\nsoon have an offer of marriage, and from a most unexceptionable\nquarter:--Robert Martin is the man.',
#  u'Her visit to Abbey-Mill,\nthis summer, seems to have done his business.',
#  u'He is desperately\nin love and means to marry her."',
#  u'"He is very obliging," said Emma; "but is he sure that Harriet\nmeans to marry him?"',
#  u'"Well, well, means to make her an offer then.',
#  u'Will that do?',
#  u'He came\nto the Abbey two evenings ago, on purpose to consult me about it.',
#  u'He knows I have a thorough regard for him and all his family, and,\nI believe, considers me as one of his best friends.',
#  u'He came to ask\nme whether I thought it would be imprudent in him to settle so early;\nwhether I thought her too young: in short, whether I approved his\nchoice altogether; having some apprehension perhaps of her being\nconsidered (especially since _your_ making so much of her) as in a line\nof society above him.',
#  u'I was very much pleased with all that he said.',
#  u'I never hear better sense from any one than Robert Martin.',
#  u'He always speaks to the purpose; open, straightforward, and very\nwell judging.',
#  u'He told me every thing; his circumstances and plans,\nand what they all proposed doing in the event of his marriage.',
#  u'He is\nan excellent young man, both as son and brother.',
#  u'I had no hesitation\nin advising him to marry.',
#  u'He proved to me that he could afford it;\nand that being the case, I was convinced he could not do better.',
#  u'I praised the fair lady too, and altogether sent him away very happy.',
#  u'If he had never esteemed my opinion before, he would have thought\nhighly of me then; and, I dare say, left the house thinking me the\nbest friend and counsellor man ever had.',
#  u'This happened the night\nbefore last.',
#  u'Now, as we may fairly suppose, he would not allow\nmuch time to pass before he spoke to the lady, and as he does not\nappear to have spoken yesterday, it is not unlikely that he should\nbe at Mrs. Goddard\'s to-day; and she may be detained by a visitor,\nwithout thinking him at all a tiresome wretch."',
#  u'"Pray, Mr. Knightley," said Emma, who had been smiling to herself\nthrough a great part of this speech, "how do you know that Mr. Martin\ndid not speak yesterday?"',
#  u'"Certainly," replied he, surprized, "I do not absolutely know it;\nbut it may be inferred.',
#  u'Was not she the whole day with you?"',
#  u'"Come," said she, "I will tell you something, in return for what\nyou have told me.',
#  u'He did speak yesterday--that is, he wrote,\nand was refused."',
#  u'This was obliged to be repeated before it could be believed;\nand Mr. Knightley actually looked red with surprize and displeasure,\nas he stood up, in tall indignation, and said,\n\n"Then she is a greater simpleton than I ever believed her.',
#  u'What is the foolish girl about?"',
#  u'"Oh!',
#  u'to be sure," cried Emma, "it is always incomprehensible\nto a man that a woman should ever refuse an offer of marriage.',
#  u'A man always imagines a woman to be ready for any body who asks her."',
#  u'"Nonsense!',
#  u'a man does not imagine any such thing.',
#  u'But what is\nthe meaning of this?',
#  u'Harriet Smith refuse Robert Martin?',
#  u'madness,\nif it is so; but I hope you are mistaken."',
#  u'"I saw her answer!--nothing could be clearer."',
#  u'"You saw her answer!--you wrote her answer too.',
#  u'Emma, this is\nyour doing.',
#  u'You persuaded her to refuse him."',
#  u'"And if I did, (which, however, I am far from allowing) I should\nnot feel that I had done wrong.',
#  u"Mr. Martin is a very respectable\nyoung man, but I cannot admit him to be Harriet's equal; and am\nrather surprized indeed that he should have ventured to address her.",
#  u'By your account, he does seem to have had some scruples.',
#  u'It is\na pity that they were ever got over."',
#  u'"Not Harriet\'s equal!"',
#  u'exclaimed Mr. Knightley loudly and warmly;\nand with calmer asperity, added, a few moments afterwards, "No, he\nis not her equal indeed, for he is as much her superior in sense\nas in situation.',
#  u'Emma, your infatuation about that girl blinds you.',
#  u"What are Harriet Smith's claims, either of birth, nature or education,\nto any connexion higher than Robert Martin?",
#  u'She is the natural\ndaughter of nobody knows whom, with probably no settled provision\nat all, and certainly no respectable relations.',
#  u'She is known only\nas parlour-boarder at a common school.',
#  u'She is not a sensible girl,\nnor a girl of any information.',
#  u'She has been taught nothing useful,\nand is too young and too simple to have acquired any thing herself.',
#  u'At her age she can have no experience, and with her little wit,\nis not very likely ever to have any that can avail her.',
#  u'She is pretty, and she is good tempered, and that is all.',
#  u'My only scruple in advising the match was on his account, as being\nbeneath his deserts, and a bad connexion for him.',
#  u'I felt that,\nas to fortune, in all probability he might do much better; and that as\nto a rational companion or useful helpmate, he could not do worse.',
#  u'But I could not reason so to a man in love, and was willing\nto trust to there being no harm in her, to her having that sort\nof disposition, which, in good hands, like his, might be easily led\naright and turn out very well.',
#  u'The advantage of the match I felt\nto be all on her side; and had not the smallest doubt (nor have I now)\nthat there would be a general cry-out upon her extreme good luck.',
#  u'Even _your_ satisfaction I made sure of.',
#  u"It crossed my mind immediately\nthat you would not regret your friend's leaving Highbury, for the\nsake of her being settled so well.",
#  u'I remember saying to myself,\n`Even Emma, with all her partiality for Harriet, will think this a\ngood match.\'"',
#  u'"I cannot help wondering at your knowing so little of Emma as to say\nany such thing.',
#  u'What!',
#  u'think a farmer, (and with all his sense and all\nhis merit Mr. Martin is nothing more,) a good match for my intimate\nfriend!',
#  u'Not regret her leaving Highbury for the sake of marrying\na man whom I could never admit as an acquaintance of my own!',
#  u'I\nwonder you should think it possible for me to have such feelings.',
#  u'I assure you mine are very different.',
#  u'I must think your statement\nby no means fair.',
#  u"You are not just to Harriet's claims.",
#  u'They would be estimated very differently by others as well as myself;\nMr. Martin may be the richest of the two, but he is undoubtedly\nher inferior as to rank in society.--The sphere in which she moves\nis much above his.--It would be a degradation."',
#  u'"A degradation to illegitimacy and ignorance, to be married\nto a respectable, intelligent gentleman-farmer!"',
#  u'"As to the circumstances of her birth, though in a legal sense\nshe may be called Nobody, it will not hold in common sense.',
#  u'She is not to pay for the offence of others, by being held below\nthe level of those with whom she is brought up.--There can scarcely\nbe a doubt that her father is a gentleman--and a gentleman of\nfortune.--Her allowance is very liberal; nothing has ever been grudged\nfor her improvement or comfort.--That she is a gentleman\'s daughter,\nis indubitable to me; that she associates with gentlemen\'s daughters,\nno one, I apprehend, will deny.--She is superior to Mr. Robert Martin."',
#  u'"Whoever might be her parents," said Mr. Knightley, "whoever may\nhave had the charge of her, it does not appear to have been any part\nof their plan to introduce her into what you would call good society.',
#  u"After receiving a very indifferent education she is left in\nMrs. Goddard's hands to shift as she can;--to move, in short,\nin Mrs. Goddard's line, to have Mrs. Goddard's acquaintance.",
#  u'Her friends evidently thought this good enough for her; and it _was_\ngood enough.',
#  u'She desired nothing better herself.',
#  u'Till you chose\nto turn her into a friend, her mind had no distaste for her own set,\nnor any ambition beyond it.',
#  u'She was as happy as possible with the\nMartins in the summer.',
#  u'She had no sense of superiority then.',
#  u'If she has it now, you have given it.',
#  u'You have been no friend to\nHarriet Smith, Emma.',
#  u'Robert Martin would never have proceeded so far,\nif he had not felt persuaded of her not being disinclined to him.',
#  u'I know him well.',
#  u'He has too much real feeling to address any\nwoman on the haphazard of selfish passion.',
#  u'And as to conceit,\nhe is the farthest from it of any man I know.',
#  u'Depend upon it he\nhad encouragement."',
#  u'It was most convenient to Emma not to make a direct reply to this\nassertion; she chose rather to take up her own line of the subject again.',
#  u'"You are a very warm friend to Mr. Martin; but, as I said before,\nare unjust to Harriet.',
#  u"Harriet's claims to marry well are not\nso contemptible as you represent them.",
#  u'She is not a clever girl,\nbut she has better sense than you are aware of, and does not\ndeserve to have her understanding spoken of so slightingly.',
#  u'Waiving that point, however, and supposing her to be, as you\ndescribe her, only pretty and good-natured, let me tell you, that in\nthe degree she possesses them, they are not trivial recommendations\nto the world in general, for she is, in fact, a beautiful girl,\nand must be thought so by ninety-nine people out of an hundred;\nand till it appears that men are much more philosophic on the subject\nof beauty than they are generally supposed; till they do fall\nin love with well-informed minds instead of handsome faces, a girl,\nwith such loveliness as Harriet, has a certainty of being admired\nand sought after, of having the power of chusing from among many,\nconsequently a claim to be nice.',
#  u'Her good-nature, too, is not so very\nslight a claim, comprehending, as it does, real, thorough sweetness\nof temper and manner, a very humble opinion of herself, and a great\nreadiness to be pleased with other people.',
#  u'I am very much mistaken\nif your sex in general would not think such beauty, and such temper,\nthe highest claims a woman could possess."',
#  u'"Upon my word, Emma, to hear you abusing the reason you have,\nis almost enough to make me think so too.',
#  ...]

# %%
# Count the number of sentences in each novel.
len(emma_sentences), len(alice_sentences)
# Out:
# (7493, 1625)

# %%
# Break each sentence up into words. You will end up with a 
# list of lists of words for Emma and another one for Alice in
# Wonderland


#emma_words = [nltk.word_tokenize(s) for s in emma_sentences]
#alice_words = [nltk.word_tokenize(s) for s in alice_sentences]
#emma_words
emma_words = nltk.word_tokenize(nltk.corpus.gutenberg.raw('austen-emma.txt'))
emma_words
# Out:
# [u'[',
#  u'Emma',
#  u'by',
#  u'Jane',
#  u'Austen',
#  u'1816',
#  u']',
#  u'VOLUME',
#  u'I',
#  u'CHAPTER',
#  u'I',
#  u'Emma',
#  u'Woodhouse',
#  u',',
#  u'handsome',
#  u',',
#  u'clever',
#  u',',
#  u'and',
#  u'rich',
#  u',',
#  u'with',
#  u'a',
#  u'comfortable',
#  u'home',
#  u'and',
#  u'happy',
#  u'disposition',
#  u',',
#  u'seemed',
#  u'to',
#  u'unite',
#  u'some',
#  u'of',
#  u'the',
#  u'best',
#  u'blessings',
#  u'of',
#  u'existence',
#  u';',
#  u'and',
#  u'had',
#  u'lived',
#  u'nearly',
#  u'twenty-one',
#  u'years',
#  u'in',
#  u'the',
#  u'world',
#  u'with',
#  u'very',
#  u'little',
#  u'to',
#  u'distress',
#  u'or',
#  u'vex',
#  u'her',
#  u'.',
#  u'She',
#  u'was',
#  u'the',
#  u'youngest',
#  u'of',
#  u'the',
#  u'two',
#  u'daughters',
#  u'of',
#  u'a',
#  u'most',
#  u'affectionate',
#  u',',
#  u'indulgent',
#  u'father',
#  u';',
#  u'and',
#  u'had',
#  u',',
#  u'in',
#  u'consequence',
#  u'of',
#  u'her',
#  u'sister',
#  u"'s",
#  u'marriage',
#  u',',
#  u'been',
#  u'mistress',
#  u'of',
#  u'his',
#  u'house',
#  u'from',
#  u'a',
#  u'very',
#  u'early',
#  u'period',
#  u'.',
#  u'Her',
#  u'mother',
#  u'had',
#  u'died',
#  u'too',
#  u'long',
#  u'ago',
#  u'for',
#  u'her',
#  u'to',
#  u'have',
#  u'more',
#  u'than',
#  u'an',
#  u'indistinct',
#  u'remembrance',
#  u'of',
#  u'her',
#  u'caresses',
#  u';',
#  u'and',
#  u'her',
#  u'place',
#  u'had',
#  u'been',
#  u'supplied',
#  u'by',
#  u'an',
#  u'excellent',
#  u'woman',
#  u'as',
#  u'governess',
#  u',',
#  u'who',
#  u'had',
#  u'fallen',
#  u'little',
#  u'short',
#  u'of',
#  u'a',
#  u'mother',
#  u'in',
#  u'affection',
#  u'.',
#  u'Sixteen',
#  u'years',
#  u'had',
#  u'Miss',
#  u'Taylor',
#  u'been',
#  u'in',
#  u'Mr.',
#  u'Woodhouse',
#  u"'s",
#  u'family',
#  u',',
#  u'less',
#  u'as',
#  u'a',
#  u'governess',
#  u'than',
#  u'a',
#  u'friend',
#  u',',
#  u'very',
#  u'fond',
#  u'of',
#  u'both',
#  u'daughters',
#  u',',
#  u'but',
#  u'particularly',
#  u'of',
#  u'Emma',
#  u'.',
#  u'Between',
#  u'_them_',
#  u'it',
#  u'was',
#  u'more',
#  u'the',
#  u'intimacy',
#  u'of',
#  u'sisters',
#  u'.',
#  u'Even',
#  u'before',
#  u'Miss',
#  u'Taylor',
#  u'had',
#  u'ceased',
#  u'to',
#  u'hold',
#  u'the',
#  u'nominal',
#  u'office',
#  u'of',
#  u'governess',
#  u',',
#  u'the',
#  u'mildness',
#  u'of',
#  u'her',
#  u'temper',
#  u'had',
#  u'hardly',
#  u'allowed',
#  u'her',
#  u'to',
#  u'impose',
#  u'any',
#  u'restraint',
#  u';',
#  u'and',
#  u'the',
#  u'shadow',
#  u'of',
#  u'authority',
#  u'being',
#  u'now',
#  u'long',
#  u'passed',
#  u'away',
#  u',',
#  u'they',
#  u'had',
#  u'been',
#  u'living',
#  u'together',
#  u'as',
#  u'friend',
#  u'and',
#  u'friend',
#  u'very',
#  u'mutually',
#  u'attached',
#  u',',
#  u'and',
#  u'Emma',
#  u'doing',
#  u'just',
#  u'what',
#  u'she',
#  u'liked',
#  u';',
#  u'highly',
#  u'esteeming',
#  u'Miss',
#  u'Taylor',
#  u"'s",
#  u'judgment',
#  u',',
#  u'but',
#  u'directed',
#  u'chiefly',
#  u'by',
#  u'her',
#  u'own',
#  u'.',
#  u'The',
#  u'real',
#  u'evils',
#  u',',
#  u'indeed',
#  u',',
#  u'of',
#  u'Emma',
#  u"'s",
#  u'situation',
#  u'were',
#  u'the',
#  u'power',
#  u'of',
#  u'having',
#  u'rather',
#  u'too',
#  u'much',
#  u'her',
#  u'own',
#  u'way',
#  u',',
#  u'and',
#  u'a',
#  u'disposition',
#  u'to',
#  u'think',
#  u'a',
#  u'little',
#  u'too',
#  u'well',
#  u'of',
#  u'herself',
#  u';',
#  u'these',
#  u'were',
#  u'the',
#  u'disadvantages',
#  u'which',
#  u'threatened',
#  u'alloy',
#  u'to',
#  u'her',
#  u'many',
#  u'enjoyments',
#  u'.',
#  u'The',
#  u'danger',
#  u',',
#  u'however',
#  u',',
#  u'was',
#  u'at',
#  u'present',
#  u'so',
#  u'unperceived',
#  u',',
#  u'that',
#  u'they',
#  u'did',
#  u'not',
#  u'by',
#  u'any',
#  u'means',
#  u'rank',
#  u'as',
#  u'misfortunes',
#  u'with',
#  u'her',
#  u'.',
#  u'Sorrow',
#  u'came',
#  u'--',
#  u'a',
#  u'gentle',
#  u'sorrow',
#  u'--',
#  u'but',
#  u'not',
#  u'at',
#  u'all',
#  u'in',
#  u'the',
#  u'shape',
#  u'of',
#  u'any',
#  u'disagreeable',
#  u'consciousness.',
#  u'--',
#  u'Miss',
#  u'Taylor',
#  u'married',
#  u'.',
#  u'It',
#  u'was',
#  u'Miss',
#  u'Taylor',
#  u"'s",
#  u'loss',
#  u'which',
#  u'first',
#  u'brought',
#  u'grief',
#  u'.',
#  u'It',
#  u'was',
#  u'on',
#  u'the',
#  u'wedding-day',
#  u'of',
#  u'this',
#  u'beloved',
#  u'friend',
#  u'that',
#  u'Emma',
#  u'first',
#  u'sat',
#  u'in',
#  u'mournful',
#  u'thought',
#  u'of',
#  u'any',
#  u'continuance',
#  u'.',
#  u'The',
#  u'wedding',
#  u'over',
#  u',',
#  u'and',
#  u'the',
#  u'bride-people',
#  u'gone',
#  u',',
#  u'her',
#  u'father',
#  u'and',
#  u'herself',
#  u'were',
#  u'left',
#  u'to',
#  u'dine',
#  u'together',
#  u',',
#  u'with',
#  u'no',
#  u'prospect',
#  u'of',
#  u'a',
#  u'third',
#  u'to',
#  u'cheer',
#  u'a',
#  u'long',
#  u'evening',
#  u'.',
#  u'Her',
#  u'father',
#  u'composed',
#  u'himself',
#  u'to',
#  u'sleep',
#  u'after',
#  u'dinner',
#  u',',
#  u'as',
#  u'usual',
#  u',',
#  u'and',
#  u'she',
#  u'had',
#  u'then',
#  u'only',
#  u'to',
#  u'sit',
#  u'and',
#  u'think',
#  u'of',
#  u'what',
#  u'she',
#  u'had',
#  u'lost',
#  u'.',
#  u'The',
#  u'event',
#  u'had',
#  u'every',
#  u'promise',
#  u'of',
#  u'happiness',
#  u'for',
#  u'her',
#  u'friend',
#  u'.',
#  u'Mr.',
#  u'Weston',
#  u'was',
#  u'a',
#  u'man',
#  u'of',
#  u'unexceptionable',
#  u'character',
#  u',',
#  u'easy',
#  u'fortune',
#  u',',
#  u'suitable',
#  u'age',
#  u',',
#  u'and',
#  u'pleasant',
#  u'manners',
#  u';',
#  u'and',
#  u'there',
#  u'was',
#  u'some',
#  u'satisfaction',
#  u'in',
#  u'considering',
#  u'with',
#  u'what',
#  u'self-denying',
#  u',',
#  u'generous',
#  u'friendship',
#  u'she',
#  u'had',
#  u'always',
#  u'wished',
#  u'and',
#  u'promoted',
#  u'the',
#  u'match',
#  u';',
#  u'but',
#  u'it',
#  u'was',
#  u'a',
#  u'black',
#  u'morning',
#  u"'s",
#  u'work',
#  u'for',
#  u'her',
#  u'.',
#  u'The',
#  u'want',
#  u'of',
#  u'Miss',
#  u'Taylor',
#  u'would',
#  u'be',
#  u'felt',
#  u'every',
#  u'hour',
#  u'of',
#  u'every',
#  u'day',
#  u'.',
#  u'She',
#  u'recalled',
#  u'her',
#  u'past',
#  u'kindness',
#  u'--',
#  u'the',
#  u'kindness',
#  u',',
#  u'the',
#  u'affection',
#  u'of',
#  u'sixteen',
#  u'years',
#  u'--',
#  u'how',
#  u'she',
#  u'had',
#  u'taught',
#  u'and',
#  u'how',
#  u'she',
#  u'had',
#  u'played',
#  u'with',
#  u'her',
#  u'from',
#  u'five',
#  u'years',
#  u'old',
#  u'--',
#  u'how',
#  u'she',
#  u'had',
#  u'devoted',
#  u'all',
#  u'her',
#  u'powers',
#  u'to',
#  u'attach',
#  u'and',
#  u'amuse',
#  u'her',
#  u'in',
#  u'health',
#  u'--',
#  u'and',
#  u'how',
#  u'nursed',
#  u'her',
#  u'through',
#  u'the',
#  u'various',
#  u'illnesses',
#  u'of',
#  u'childhood',
#  u'.',
#  u'A',
#  u'large',
#  u'debt',
#  u'of',
#  u'gratitude',
#  u'was',
#  u'owing',
#  u'here',
#  u';',
#  u'but',
#  u'the',
#  u'intercourse',
#  u'of',
#  u'the',
#  u'last',
#  u'seven',
#  u'years',
#  u',',
#  u'the',
#  u'equal',
#  u'footing',
#  u'and',
#  u'perfect',
#  u'unreserve',
#  u'which',
#  u'had',
#  u'soon',
#  u'followed',
#  u'Isabella',
#  u"'s",
#  u'marriage',
#  u',',
#  u'on',
#  u'their',
#  u'being',
#  u'left',
#  u'to',
#  u'each',
#  u'other',
#  u',',
#  u'was',
#  u'yet',
#  u'a',
#  u'dearer',
#  u',',
#  u'tenderer',
#  u'recollection',
#  u'.',
#  u'She',
#  u'had',
#  u'been',
#  u'a',
#  u'friend',
#  u'and',
#  u'companion',
#  u'such',
#  u'as',
#  u'few',
#  u'possessed',
#  u':',
#  u'intelligent',
#  u',',
#  u'well-informed',
#  u',',
#  u'useful',
#  u',',
#  u'gentle',
#  u',',
#  u'knowing',
#  u'all',
#  u'the',
#  u'ways',
#  u'of',
#  u'the',
#  u'family',
#  u',',
#  u'interested',
#  u'in',
#  u'all',
#  u'its',
#  u'concerns',
#  u',',
#  u'and',
#  u'peculiarly',
#  u'interested',
#  u'in',
#  u'herself',
#  u',',
#  u'in',
#  u'every',
#  u'pleasure',
#  u',',
#  u'every',
#  u'scheme',
#  u'of',
#  u'hers',
#  u'--',
#  u'one',
#  u'to',
#  u'whom',
#  u'she',
#  u'could',
#  u'speak',
#  u'every',
#  u'thought',
#  u'as',
#  u'it',
#  u'arose',
#  u',',
#  u'and',
#  u'who',
#  u'had',
#  u'such',
#  u'an',
#  u'affection',
#  u'for',
#  u'her',
#  u'as',
#  u'could',
#  u'never',
#  u'find',
#  u'fault',
#  u'.',
#  u'How',
#  u'was',
#  u'she',
#  u'to',
#  u'bear',
#  u'the',
#  u'change',
#  u'?',
#  u'--',
#  u'It',
#  u'was',
#  u'true',
#  u'that',
#  u'her',
#  u'friend',
#  u'was',
#  u'going',
#  u'only',
#  u'half',
#  u'a',
#  u'mile',
#  u'from',
#  u'them',
#  u';',
#  u'but',
#  u'Emma',
#  u'was',
#  u'aware',
#  u'that',
#  u'great',
#  u'must',
#  u'be',
#  u'the',
#  u'difference',
#  u'between',
#  u'a',
#  u'Mrs.',
#  u'Weston',
#  u',',
#  u'only',
#  u'half',
#  u'a',
#  u'mile',
#  u'from',
#  u'them',
#  u',',
#  u'and',
#  u'a',
#  u'Miss',
#  u'Taylor',
#  u'in',
#  u'the',
#  u'house',
#  u';',
#  u'and',
#  u'with',
#  u'all',
#  u'her',
#  u'advantages',
#  u',',
#  u'natural',
#  u'and',
#  u'domestic',
#  u',',
#  u'she',
#  u'was',
#  u'now',
#  u'in',
#  u'great',
#  u'danger',
#  u'of',
#  u'suffering',
#  u'from',
#  u'intellectual',
#  u'solitude',
#  u'.',
#  u'She',
#  u'dearly',
#  u'loved',
#  u'her',
#  u'father',
#  u',',
#  u'but',
#  u'he',
#  u'was',
#  u'no',
#  u'companion',
#  u'for',
#  u'her',
#  u'.',
#  u'He',
#  u'could',
#  u'not',
#  u'meet',
#  u'her',
#  u'in',
#  u'conversation',
#  u',',
#  u'rational',
#  u'or',
#  u'playful',
#  u'.',
#  u'The',
#  u'evil',
#  u'of',
#  u'the',
#  u'actual',
#  u'disparity',
#  u'in',
#  u'their',
#  u'ages',
#  u'(',
#  u'and',
#  u'Mr.',
#  u'Woodhouse',
#  u'had',
#  u'not',
#  u'married',
#  u'early',
#  u')',
#  u'was',
#  u'much',
#  u'increased',
#  u'by',
#  u'his',
#  u'constitution',
#  u'and',
#  u'habits',
#  u';',
#  u'for',
#  u'having',
#  u'been',
#  u'a',
#  u'valetudinarian',
#  u'all',
#  u'his',
#  u'life',
#  u',',
#  u'without',
#  u'activity',
#  u'of',
#  u'mind',
#  u'or',
#  u'body',
#  u',',
#  u'he',
#  u'was',
#  u'a',
#  u'much',
#  u'older',
#  u'man',
#  u'in',
#  u'ways',
#  u'than',
#  u'in',
#  u'years',
#  u';',
#  u'and',
#  u'though',
#  u'everywhere',
#  u'beloved',
#  u'for',
#  u'the',
#  u'friendliness',
#  u'of',
#  u'his',
#  u'heart',
#  u'and',
#  u'his',
#  u'amiable',
#  u'temper',
#  u',',
#  u'his',
#  u'talents',
#  u'could',
#  u'not',
#  u'have',
#  u'recommended',
#  u'him',
#  u'at',
#  u'any',
#  u'time',
#  u'.',
#  u'Her',
#  u'sister',
#  u',',
#  u'though',
#  u'comparatively',
#  u'but',
#  u'little',
#  u'removed',
#  u'by',
#  u'matrimony',
#  u',',
#  u'being',
#  u'settled',
#  u'in',
#  u'London',
#  u',',
#  u'only',
#  u'sixteen',
#  u'miles',
#  u'off',
#  u',',
#  u'was',
#  u'much',
#  u'beyond',
#  u'her',
#  u'daily',
#  u'reach',
#  u';',
#  u'and',
#  u'many',
#  u'a',
#  u'long',
#  u'October',
#  u'and',
#  u'November',
#  u'evening',
#  u'must',
#  u'be',
#  u'struggled',
#  u'through',
#  u'at',
#  u'Hartfield',
#  u',',
#  u'before',
#  u'Christmas',
#  u'brought',
#  u'the',
#  u'next',
#  u'visit',
#  u'from',
#  u'Isabella',
#  u'and',
#  u'her',
#  u'husband',
#  u',',
#  u'and',
#  u'their',
#  u'little',
#  u'children',
#  u',',
#  u'to',
#  u'fill',
#  u'the',
#  u'house',
#  u',',
#  u'and',
#  u'give',
#  u'her',
#  u'pleasant',
#  u'society',
#  u'again',
#  u'.',
#  u'Highbury',
#  u',',
#  u'the',
#  u'large',
#  u'and',
#  u'populous',
#  u'village',
#  u',',
#  u'almost',
#  u'amounting',
#  u'to',
#  u'a',
#  u'town',
#  u',',
#  u'to',
#  u'which',
#  u'Hartfield',
#  u',',
#  u'in',
#  u'spite',
#  u'of',
#  u'its',
#  u'separate',
#  u'lawn',
#  u',',
#  u'and',
#  u'shrubberies',
#  u',',
#  u'and',
#  u'name',
#  u',',
#  u'did',
#  u'really',
#  u'belong',
#  u',',
#  u'afforded',
#  u'her',
#  u'no',
#  u'equals',
#  u'.',
#  u'The',
#  u'Woodhouses',
#  u'were',
#  u'first',
#  u'in',
#  u'consequence',
#  u'there',
#  u'.',
#  u'All',
#  u'looked',
#  u'up',
#  ...]

# %%
alice_words = [nltk.word_tokenize(s) for s in alice_sentences]
alice_words
# Out:
# [[u'[',
#   u'Alice',
#   u"'s",
#   u'Adventures',
#   u'in',
#   u'Wonderland',
#   u'by',
#   u'Lewis',
#   u'Carroll',
#   u'1865',
#   u']',
#   u'CHAPTER',
#   u'I',
#   u'.'],
#  [u'Down',
#   u'the',
#   u'Rabbit-Hole',
#   u'Alice',
#   u'was',
#   u'beginning',
#   u'to',
#   u'get',
#   u'very',
#   u'tired',
#   u'of',
#   u'sitting',
#   u'by',
#   u'her',
#   u'sister',
#   u'on',
#   u'the',
#   u'bank',
#   u',',
#   u'and',
#   u'of',
#   u'having',
#   u'nothing',
#   u'to',
#   u'do',
#   u':',
#   u'once',
#   u'or',
#   u'twice',
#   u'she',
#   u'had',
#   u'peeped',
#   u'into',
#   u'the',
#   u'book',
#   u'her',
#   u'sister',
#   u'was',
#   u'reading',
#   u',',
#   u'but',
#   u'it',
#   u'had',
#   u'no',
#   u'pictures',
#   u'or',
#   u'conversations',
#   u'in',
#   u'it',
#   u',',
#   u"'and",
#   u'what',
#   u'is',
#   u'the',
#   u'use',
#   u'of',
#   u'a',
#   u'book',
#   u',',
#   u"'",
#   u'thought',
#   u'Alice',
#   u"'without",
#   u'pictures',
#   u'or',
#   u'conversation',
#   u'?',
#   u"'"],
#  [u'So',
#   u'she',
#   u'was',
#   u'considering',
#   u'in',
#   u'her',
#   u'own',
#   u'mind',
#   u'(',
#   u'as',
#   u'well',
#   u'as',
#   u'she',
#   u'could',
#   u',',
#   u'for',
#   u'the',
#   u'hot',
#   u'day',
#   u'made',
#   u'her',
#   u'feel',
#   u'very',
#   u'sleepy',
#   u'and',
#   u'stupid',
#   u')',
#   u',',
#   u'whether',
#   u'the',
#   u'pleasure',
#   u'of',
#   u'making',
#   u'a',
#   u'daisy-chain',
#   u'would',
#   u'be',
#   u'worth',
#   u'the',
#   u'trouble',
#   u'of',
#   u'getting',
#   u'up',
#   u'and',
#   u'picking',
#   u'the',
#   u'daisies',
#   u',',
#   u'when',
#   u'suddenly',
#   u'a',
#   u'White',
#   u'Rabbit',
#   u'with',
#   u'pink',
#   u'eyes',
#   u'ran',
#   u'close',
#   u'by',
#   u'her',
#   u'.'],
#  [u'There',
#   u'was',
#   u'nothing',
#   u'so',
#   u'VERY',
#   u'remarkable',
#   u'in',
#   u'that',
#   u';',
#   u'nor',
#   u'did',
#   u'Alice',
#   u'think',
#   u'it',
#   u'so',
#   u'VERY',
#   u'much',
#   u'out',
#   u'of',
#   u'the',
#   u'way',
#   u'to',
#   u'hear',
#   u'the',
#   u'Rabbit',
#   u'say',
#   u'to',
#   u'itself',
#   u',',
#   u"'Oh",
#   u'dear',
#   u'!'],
#  [u'Oh', u'dear', u'!'],
#  [u'I', u'shall', u'be', u'late', u'!', u"'"],
#  [u'(',
#   u'when',
#   u'she',
#   u'thought',
#   u'it',
#   u'over',
#   u'afterwards',
#   u',',
#   u'it',
#   u'occurred',
#   u'to',
#   u'her',
#   u'that',
#   u'she',
#   u'ought',
#   u'to',
#   u'have',
#   u'wondered',
#   u'at',
#   u'this',
#   u',',
#   u'but',
#   u'at',
#   u'the',
#   u'time',
#   u'it',
#   u'all',
#   u'seemed',
#   u'quite',
#   u'natural',
#   u')',
#   u';',
#   u'but',
#   u'when',
#   u'the',
#   u'Rabbit',
#   u'actually',
#   u'TOOK',
#   u'A',
#   u'WATCH',
#   u'OUT',
#   u'OF',
#   u'ITS',
#   u'WAISTCOAT-POCKET',
#   u',',
#   u'and',
#   u'looked',
#   u'at',
#   u'it',
#   u',',
#   u'and',
#   u'then',
#   u'hurried',
#   u'on',
#   u',',
#   u'Alice',
#   u'started',
#   u'to',
#   u'her',
#   u'feet',
#   u',',
#   u'for',
#   u'it',
#   u'flashed',
#   u'across',
#   u'her',
#   u'mind',
#   u'that',
#   u'she',
#   u'had',
#   u'never',
#   u'before',
#   u'seen',
#   u'a',
#   u'rabbit',
#   u'with',
#   u'either',
#   u'a',
#   u'waistcoat-pocket',
#   u',',
#   u'or',
#   u'a',
#   u'watch',
#   u'to',
#   u'take',
#   u'out',
#   u'of',
#   u'it',
#   u',',
#   u'and',
#   u'burning',
#   u'with',
#   u'curiosity',
#   u',',
#   u'she',
#   u'ran',
#   u'across',
#   u'the',
#   u'field',
#   u'after',
#   u'it',
#   u',',
#   u'and',
#   u'fortunately',
#   u'was',
#   u'just',
#   u'in',
#   u'time',
#   u'to',
#   u'see',
#   u'it',
#   u'pop',
#   u'down',
#   u'a',
#   u'large',
#   u'rabbit-hole',
#   u'under',
#   u'the',
#   u'hedge',
#   u'.'],
#  [u'In',
#   u'another',
#   u'moment',
#   u'down',
#   u'went',
#   u'Alice',
#   u'after',
#   u'it',
#   u',',
#   u'never',
#   u'once',
#   u'considering',
#   u'how',
#   u'in',
#   u'the',
#   u'world',
#   u'she',
#   u'was',
#   u'to',
#   u'get',
#   u'out',
#   u'again',
#   u'.'],
#  [u'The',
#   u'rabbit-hole',
#   u'went',
#   u'straight',
#   u'on',
#   u'like',
#   u'a',
#   u'tunnel',
#   u'for',
#   u'some',
#   u'way',
#   u',',
#   u'and',
#   u'then',
#   u'dipped',
#   u'suddenly',
#   u'down',
#   u',',
#   u'so',
#   u'suddenly',
#   u'that',
#   u'Alice',
#   u'had',
#   u'not',
#   u'a',
#   u'moment',
#   u'to',
#   u'think',
#   u'about',
#   u'stopping',
#   u'herself',
#   u'before',
#   u'she',
#   u'found',
#   u'herself',
#   u'falling',
#   u'down',
#   u'a',
#   u'very',
#   u'deep',
#   u'well',
#   u'.'],
#  [u'Either',
#   u'the',
#   u'well',
#   u'was',
#   u'very',
#   u'deep',
#   u',',
#   u'or',
#   u'she',
#   u'fell',
#   u'very',
#   u'slowly',
#   u',',
#   u'for',
#   u'she',
#   u'had',
#   u'plenty',
#   u'of',
#   u'time',
#   u'as',
#   u'she',
#   u'went',
#   u'down',
#   u'to',
#   u'look',
#   u'about',
#   u'her',
#   u'and',
#   u'to',
#   u'wonder',
#   u'what',
#   u'was',
#   u'going',
#   u'to',
#   u'happen',
#   u'next',
#   u'.'],
#  [u'First',
#   u',',
#   u'she',
#   u'tried',
#   u'to',
#   u'look',
#   u'down',
#   u'and',
#   u'make',
#   u'out',
#   u'what',
#   u'she',
#   u'was',
#   u'coming',
#   u'to',
#   u',',
#   u'but',
#   u'it',
#   u'was',
#   u'too',
#   u'dark',
#   u'to',
#   u'see',
#   u'anything',
#   u';',
#   u'then',
#   u'she',
#   u'looked',
#   u'at',
#   u'the',
#   u'sides',
#   u'of',
#   u'the',
#   u'well',
#   u',',
#   u'and',
#   u'noticed',
#   u'that',
#   u'they',
#   u'were',
#   u'filled',
#   u'with',
#   u'cupboards',
#   u'and',
#   u'book-shelves',
#   u';',
#   u'here',
#   u'and',
#   u'there',
#   u'she',
#   u'saw',
#   u'maps',
#   u'and',
#   u'pictures',
#   u'hung',
#   u'upon',
#   u'pegs',
#   u'.'],
#  [u'She',
#   u'took',
#   u'down',
#   u'a',
#   u'jar',
#   u'from',
#   u'one',
#   u'of',
#   u'the',
#   u'shelves',
#   u'as',
#   u'she',
#   u'passed',
#   u';',
#   u'it',
#   u'was',
#   u'labelled',
#   u"'ORANGE",
#   u'MARMALADE',
#   u"'",
#   u',',
#   u'but',
#   u'to',
#   u'her',
#   u'great',
#   u'disappointment',
#   u'it',
#   u'was',
#   u'empty',
#   u':',
#   u'she',
#   u'did',
#   u'not',
#   u'like',
#   u'to',
#   u'drop',
#   u'the',
#   u'jar',
#   u'for',
#   u'fear',
#   u'of',
#   u'killing',
#   u'somebody',
#   u',',
#   u'so',
#   u'managed',
#   u'to',
#   u'put',
#   u'it',
#   u'into',
#   u'one',
#   u'of',
#   u'the',
#   u'cupboards',
#   u'as',
#   u'she',
#   u'fell',
#   u'past',
#   u'it',
#   u'.'],
#  [u"'Well", u'!', u"'"],
#  [u'thought',
#   u'Alice',
#   u'to',
#   u'herself',
#   u',',
#   u"'after",
#   u'such',
#   u'a',
#   u'fall',
#   u'as',
#   u'this',
#   u',',
#   u'I',
#   u'shall',
#   u'think',
#   u'nothing',
#   u'of',
#   u'tumbling',
#   u'down',
#   u'stairs',
#   u'!'],
#  [u'How',
#   u'brave',
#   u'they',
#   u"'ll",
#   u'all',
#   u'think',
#   u'me',
#   u'at',
#   u'home',
#   u'!'],
#  [u'Why',
#   u',',
#   u'I',
#   u'would',
#   u"n't",
#   u'say',
#   u'anything',
#   u'about',
#   u'it',
#   u',',
#   u'even',
#   u'if',
#   u'I',
#   u'fell',
#   u'off',
#   u'the',
#   u'top',
#   u'of',
#   u'the',
#   u'house',
#   u'!',
#   u"'"],
#  [u'(', u'Which', u'was', u'very', u'likely', u'true', u'.', u')'],
#  [u'Down', u',', u'down', u',', u'down', u'.'],
#  [u'Would', u'the', u'fall', u'NEVER', u'come', u'to', u'an', u'end', u'!'],
#  [u"'I",
#   u'wonder',
#   u'how',
#   u'many',
#   u'miles',
#   u'I',
#   u"'ve",
#   u'fallen',
#   u'by',
#   u'this',
#   u'time',
#   u'?',
#   u"'"],
#  [u'she', u'said', u'aloud', u'.'],
#  [u"'I",
#   u'must',
#   u'be',
#   u'getting',
#   u'somewhere',
#   u'near',
#   u'the',
#   u'centre',
#   u'of',
#   u'the',
#   u'earth',
#   u'.'],
#  [u'Let',
#   u'me',
#   u'see',
#   u':',
#   u'that',
#   u'would',
#   u'be',
#   u'four',
#   u'thousand',
#   u'miles',
#   u'down',
#   u',',
#   u'I',
#   u'think',
#   u'--',
#   u"'",
#   u'(',
#   u'for',
#   u',',
#   u'you',
#   u'see',
#   u',',
#   u'Alice',
#   u'had',
#   u'learnt',
#   u'several',
#   u'things',
#   u'of',
#   u'this',
#   u'sort',
#   u'in',
#   u'her',
#   u'lessons',
#   u'in',
#   u'the',
#   u'schoolroom',
#   u',',
#   u'and',
#   u'though',
#   u'this',
#   u'was',
#   u'not',
#   u'a',
#   u'VERY',
#   u'good',
#   u'opportunity',
#   u'for',
#   u'showing',
#   u'off',
#   u'her',
#   u'knowledge',
#   u',',
#   u'as',
#   u'there',
#   u'was',
#   u'no',
#   u'one',
#   u'to',
#   u'listen',
#   u'to',
#   u'her',
#   u',',
#   u'still',
#   u'it',
#   u'was',
#   u'good',
#   u'practice',
#   u'to',
#   u'say',
#   u'it',
#   u'over',
#   u')',
#   u"'",
#   u'--',
#   u'yes',
#   u',',
#   u'that',
#   u"'s",
#   u'about',
#   u'the',
#   u'right',
#   u'distance',
#   u'--',
#   u'but',
#   u'then',
#   u'I',
#   u'wonder',
#   u'what',
#   u'Latitude',
#   u'or',
#   u'Longitude',
#   u'I',
#   u"'ve",
#   u'got',
#   u'to',
#   u'?',
#   u"'"],
#  [u'(',
#   u'Alice',
#   u'had',
#   u'no',
#   u'idea',
#   u'what',
#   u'Latitude',
#   u'was',
#   u',',
#   u'or',
#   u'Longitude',
#   u'either',
#   u',',
#   u'but',
#   u'thought',
#   u'they',
#   u'were',
#   u'nice',
#   u'grand',
#   u'words',
#   u'to',
#   u'say',
#   u'.',
#   u')'],
#  [u'Presently', u'she', u'began', u'again', u'.'],
#  [u"'I",
#   u'wonder',
#   u'if',
#   u'I',
#   u'shall',
#   u'fall',
#   u'right',
#   u'THROUGH',
#   u'the',
#   u'earth',
#   u'!'],
#  [u'How',
#   u'funny',
#   u'it',
#   u"'ll",
#   u'seem',
#   u'to',
#   u'come',
#   u'out',
#   u'among',
#   u'the',
#   u'people',
#   u'that',
#   u'walk',
#   u'with',
#   u'their',
#   u'heads',
#   u'downward',
#   u'!'],
#  [u'The',
#   u'Antipathies',
#   u',',
#   u'I',
#   u'think',
#   u'--',
#   u"'",
#   u'(',
#   u'she',
#   u'was',
#   u'rather',
#   u'glad',
#   u'there',
#   u'WAS',
#   u'no',
#   u'one',
#   u'listening',
#   u',',
#   u'this',
#   u'time',
#   u',',
#   u'as',
#   u'it',
#   u'did',
#   u"n't",
#   u'sound',
#   u'at',
#   u'all',
#   u'the',
#   u'right',
#   u'word',
#   u')',
#   u"'",
#   u'--',
#   u'but',
#   u'I',
#   u'shall',
#   u'have',
#   u'to',
#   u'ask',
#   u'them',
#   u'what',
#   u'the',
#   u'name',
#   u'of',
#   u'the',
#   u'country',
#   u'is',
#   u',',
#   u'you',
#   u'know',
#   u'.'],
#  [u'Please',
#   u',',
#   u"Ma'am",
#   u',',
#   u'is',
#   u'this',
#   u'New',
#   u'Zealand',
#   u'or',
#   u'Australia',
#   u'?',
#   u"'"],
#  [u'(',
#   u'and',
#   u'she',
#   u'tried',
#   u'to',
#   u'curtsey',
#   u'as',
#   u'she',
#   u'spoke',
#   u'--',
#   u'fancy',
#   u'CURTSEYING',
#   u'as',
#   u'you',
#   u"'re",
#   u'falling',
#   u'through',
#   u'the',
#   u'air',
#   u'!'],
#  [u'Do', u'you', u'think', u'you', u'could', u'manage', u'it', u'?', u')'],
#  [u"'And",
#   u'what',
#   u'an',
#   u'ignorant',
#   u'little',
#   u'girl',
#   u'she',
#   u"'ll",
#   u'think',
#   u'me',
#   u'for',
#   u'asking',
#   u'!'],
#  [u'No',
#   u',',
#   u'it',
#   u"'ll",
#   u'never',
#   u'do',
#   u'to',
#   u'ask',
#   u':',
#   u'perhaps',
#   u'I',
#   u'shall',
#   u'see',
#   u'it',
#   u'written',
#   u'up',
#   u'somewhere',
#   u'.',
#   u"'"],
#  [u'Down', u',', u'down', u',', u'down', u'.'],
#  [u'There',
#   u'was',
#   u'nothing',
#   u'else',
#   u'to',
#   u'do',
#   u',',
#   u'so',
#   u'Alice',
#   u'soon',
#   u'began',
#   u'talking',
#   u'again',
#   u'.'],
#  [u"'Dinah",
#   u"'ll",
#   u'miss',
#   u'me',
#   u'very',
#   u'much',
#   u'to-night',
#   u',',
#   u'I',
#   u'should',
#   u'think',
#   u'!',
#   u"'"],
#  [u'(', u'Dinah', u'was', u'the', u'cat', u'.', u')'],
#  [u"'I",
#   u'hope',
#   u'they',
#   u"'ll",
#   u'remember',
#   u'her',
#   u'saucer',
#   u'of',
#   u'milk',
#   u'at',
#   u'tea-time',
#   u'.'],
#  [u'Dinah', u'my', u'dear', u'!'],
#  [u'I', u'wish', u'you', u'were', u'down', u'here', u'with', u'me', u'!'],
#  [u'There',
#   u'are',
#   u'no',
#   u'mice',
#   u'in',
#   u'the',
#   u'air',
#   u',',
#   u'I',
#   u"'m",
#   u'afraid',
#   u',',
#   u'but',
#   u'you',
#   u'might',
#   u'catch',
#   u'a',
#   u'bat',
#   u',',
#   u'and',
#   u'that',
#   u"'s",
#   u'very',
#   u'like',
#   u'a',
#   u'mouse',
#   u',',
#   u'you',
#   u'know',
#   u'.'],
#  [u'But', u'do', u'cats', u'eat', u'bats', u',', u'I', u'wonder', u'?', u"'"],
#  [u'And',
#   u'here',
#   u'Alice',
#   u'began',
#   u'to',
#   u'get',
#   u'rather',
#   u'sleepy',
#   u',',
#   u'and',
#   u'went',
#   u'on',
#   u'saying',
#   u'to',
#   u'herself',
#   u',',
#   u'in',
#   u'a',
#   u'dreamy',
#   u'sort',
#   u'of',
#   u'way',
#   u',',
#   u"'Do",
#   u'cats',
#   u'eat',
#   u'bats',
#   u'?'],
#  [u'Do', u'cats', u'eat', u'bats', u'?', u"'"],
#  [u'and', u'sometimes', u',', u"'Do", u'bats', u'eat', u'cats', u'?', u"'"],
#  [u'for',
#   u',',
#   u'you',
#   u'see',
#   u',',
#   u'as',
#   u'she',
#   u'could',
#   u"n't",
#   u'answer',
#   u'either',
#   u'question',
#   u',',
#   u'it',
#   u'did',
#   u"n't",
#   u'much',
#   u'matter',
#   u'which',
#   u'way',
#   u'she',
#   u'put',
#   u'it',
#   u'.'],
#  [u'She',
#   u'felt',
#   u'that',
#   u'she',
#   u'was',
#   u'dozing',
#   u'off',
#   u',',
#   u'and',
#   u'had',
#   u'just',
#   u'begun',
#   u'to',
#   u'dream',
#   u'that',
#   u'she',
#   u'was',
#   u'walking',
#   u'hand',
#   u'in',
#   u'hand',
#   u'with',
#   u'Dinah',
#   u',',
#   u'and',
#   u'saying',
#   u'to',
#   u'her',
#   u'very',
#   u'earnestly',
#   u',',
#   u"'Now",
#   u',',
#   u'Dinah',
#   u',',
#   u'tell',
#   u'me',
#   u'the',
#   u'truth',
#   u':',
#   u'did',
#   u'you',
#   u'ever',
#   u'eat',
#   u'a',
#   u'bat',
#   u'?',
#   u"'"],
#  [u'when', u'suddenly', u',', u'thump', u'!'],
#  [u'thump', u'!'],
#  [u'down',
#   u'she',
#   u'came',
#   u'upon',
#   u'a',
#   u'heap',
#   u'of',
#   u'sticks',
#   u'and',
#   u'dry',
#   u'leaves',
#   u',',
#   u'and',
#   u'the',
#   u'fall',
#   u'was',
#   u'over',
#   u'.'],
#  [u'Alice',
#   u'was',
#   u'not',
#   u'a',
#   u'bit',
#   u'hurt',
#   u',',
#   u'and',
#   u'she',
#   u'jumped',
#   u'up',
#   u'on',
#   u'to',
#   u'her',
#   u'feet',
#   u'in',
#   u'a',
#   u'moment',
#   u':',
#   u'she',
#   u'looked',
#   u'up',
#   u',',
#   u'but',
#   u'it',
#   u'was',
#   u'all',
#   u'dark',
#   u'overhead',
#   u';',
#   u'before',
#   u'her',
#   u'was',
#   u'another',
#   u'long',
#   u'passage',
#   u',',
#   u'and',
#   u'the',
#   u'White',
#   u'Rabbit',
#   u'was',
#   u'still',
#   u'in',
#   u'sight',
#   u',',
#   u'hurrying',
#   u'down',
#   u'it',
#   u'.'],
#  [u'There',
#   u'was',
#   u'not',
#   u'a',
#   u'moment',
#   u'to',
#   u'be',
#   u'lost',
#   u':',
#   u'away',
#   u'went',
#   u'Alice',
#   u'like',
#   u'the',
#   u'wind',
#   u',',
#   u'and',
#   u'was',
#   u'just',
#   u'in',
#   u'time',
#   u'to',
#   u'hear',
#   u'it',
#   u'say',
#   u',',
#   u'as',
#   u'it',
#   u'turned',
#   u'a',
#   u'corner',
#   u',',
#   u"'Oh",
#   u'my',
#   u'ears',
#   u'and',
#   u'whiskers',
#   u',',
#   u'how',
#   u'late',
#   u'it',
#   u"'s",
#   u'getting',
#   u'!',
#   u"'"],
#  [u'She',
#   u'was',
#   u'close',
#   u'behind',
#   u'it',
#   u'when',
#   u'she',
#   u'turned',
#   u'the',
#   u'corner',
#   u',',
#   u'but',
#   u'the',
#   u'Rabbit',
#   u'was',
#   u'no',
#   u'longer',
#   u'to',
#   u'be',
#   u'seen',
#   u':',
#   u'she',
#   u'found',
#   u'herself',
#   u'in',
#   u'a',
#   u'long',
#   u',',
#   u'low',
#   u'hall',
#   u',',
#   u'which',
#   u'was',
#   u'lit',
#   u'up',
#   u'by',
#   u'a',
#   u'row',
#   u'of',
#   u'lamps',
#   u'hanging',
#   u'from',
#   u'the',
#   u'roof',
#   u'.'],
#  [u'There',
#   u'were',
#   u'doors',
#   u'all',
#   u'round',
#   u'the',
#   u'hall',
#   u',',
#   u'but',
#   u'they',
#   u'were',
#   u'all',
#   u'locked',
#   u';',
#   u'and',
#   u'when',
#   u'Alice',
#   u'had',
#   u'been',
#   u'all',
#   u'the',
#   u'way',
#   u'down',
#   u'one',
#   u'side',
#   u'and',
#   u'up',
#   u'the',
#   u'other',
#   u',',
#   u'trying',
#   u'every',
#   u'door',
#   u',',
#   u'she',
#   u'walked',
#   u'sadly',
#   u'down',
#   u'the',
#   u'middle',
#   u',',
#   u'wondering',
#   u'how',
#   u'she',
#   u'was',
#   u'ever',
#   u'to',
#   u'get',
#   u'out',
#   u'again',
#   u'.'],
#  [u'Suddenly',
#   u'she',
#   u'came',
#   u'upon',
#   u'a',
#   u'little',
#   u'three-legged',
#   u'table',
#   u',',
#   u'all',
#   u'made',
#   u'of',
#   u'solid',
#   u'glass',
#   u';',
#   u'there',
#   u'was',
#   u'nothing',
#   u'on',
#   u'it',
#   u'except',
#   u'a',
#   u'tiny',
#   u'golden',
#   u'key',
#   u',',
#   u'and',
#   u"Alice's",
#   u'first',
#   u'thought',
#   u'was',
#   u'that',
#   u'it',
#   u'might',
#   u'belong',
#   u'to',
#   u'one',
#   u'of',
#   u'the',
#   u'doors',
#   u'of',
#   u'the',
#   u'hall',
#   u';',
#   u'but',
#   u',',
#   u'alas',
#   u'!'],
#  [u'either',
#   u'the',
#   u'locks',
#   u'were',
#   u'too',
#   u'large',
#   u',',
#   u'or',
#   u'the',
#   u'key',
#   u'was',
#   u'too',
#   u'small',
#   u',',
#   u'but',
#   u'at',
#   u'any',
#   u'rate',
#   u'it',
#   u'would',
#   u'not',
#   u'open',
#   u'any',
#   u'of',
#   u'them',
#   u'.'],
#  [u'However',
#   u',',
#   u'on',
#   u'the',
#   u'second',
#   u'time',
#   u'round',
#   u',',
#   u'she',
#   u'came',
#   u'upon',
#   u'a',
#   u'low',
#   u'curtain',
#   u'she',
#   u'had',
#   u'not',
#   u'noticed',
#   u'before',
#   u',',
#   u'and',
#   u'behind',
#   u'it',
#   u'was',
#   u'a',
#   u'little',
#   u'door',
#   u'about',
#   u'fifteen',
#   u'inches',
#   u'high',
#   u':',
#   u'she',
#   u'tried',
#   u'the',
#   u'little',
#   u'golden',
#   u'key',
#   u'in',
#   u'the',
#   u'lock',
#   u',',
#   u'and',
#   u'to',
#   u'her',
#   u'great',
#   u'delight',
#   u'it',
#   u'fitted',
#   u'!'],
#  [u'Alice',
#   u'opened',
#   u'the',
#   u'door',
#   u'and',
#   u'found',
#   u'that',
#   u'it',
#   u'led',
#   u'into',
#   u'a',
#   u'small',
#   u'passage',
#   u',',
#   u'not',
#   u'much',
#   u'larger',
#   u'than',
#   u'a',
#   u'rat-hole',
#   u':',
#   u'she',
#   u'knelt',
#   u'down',
#   u'and',
#   u'looked',
#   u'along',
#   u'the',
#   u'passage',
#   u'into',
#   u'the',
#   u'loveliest',
#   u'garden',
#   u'you',
#   u'ever',
#   u'saw',
#   u'.'],
#  [u'How',
#   u'she',
#   u'longed',
#   u'to',
#   u'get',
#   u'out',
#   u'of',
#   u'that',
#   u'dark',
#   u'hall',
#   u',',
#   u'and',
#   u'wander',
#   u'about',
#   u'among',
#   u'those',
#   u'beds',
#   u'of',
#   u'bright',
#   u'flowers',
#   u'and',
#   u'those',
#   u'cool',
#   u'fountains',
#   u',',
#   u'but',
#   u'she',
#   u'could',
#   u'not',
#   u'even',
#   u'get',
#   u'her',
#   u'head',
#   u'through',
#   u'the',
#   u'doorway',
#   u';',
#   u"'and",
#   u'even',
#   u'if',
#   u'my',
#   u'head',
#   u'would',
#   u'go',
#   u'through',
#   u',',
#   u"'",
#   u'thought',
#   u'poor',
#   u'Alice',
#   u',',
#   u"'it",
#   u'would',
#   u'be',
#   u'of',
#   u'very',
#   u'little',
#   u'use',
#   u'without',
#   u'my',
#   u'shoulders',
#   u'.'],
#  [u'Oh',
#   u',',
#   u'how',
#   u'I',
#   u'wish',
#   u'I',
#   u'could',
#   u'shut',
#   u'up',
#   u'like',
#   u'a',
#   u'telescope',
#   u'!'],
#  [u'I',
#   u'think',
#   u'I',
#   u'could',
#   u',',
#   u'if',
#   u'I',
#   u'only',
#   u'know',
#   u'how',
#   u'to',
#   u'begin',
#   u'.',
#   u"'"],
#  [u'For',
#   u',',
#   u'you',
#   u'see',
#   u',',
#   u'so',
#   u'many',
#   u'out-of-the-way',
#   u'things',
#   u'had',
#   u'happened',
#   u'lately',
#   u',',
#   u'that',
#   u'Alice',
#   u'had',
#   u'begun',
#   u'to',
#   u'think',
#   u'that',
#   u'very',
#   u'few',
#   u'things',
#   u'indeed',
#   u'were',
#   u'really',
#   u'impossible',
#   u'.'],
#  [u'There',
#   u'seemed',
#   u'to',
#   u'be',
#   u'no',
#   u'use',
#   u'in',
#   u'waiting',
#   u'by',
#   u'the',
#   u'little',
#   u'door',
#   u',',
#   u'so',
#   u'she',
#   u'went',
#   u'back',
#   u'to',
#   u'the',
#   u'table',
#   u',',
#   u'half',
#   u'hoping',
#   u'she',
#   u'might',
#   u'find',
#   u'another',
#   u'key',
#   u'on',
#   u'it',
#   u',',
#   u'or',
#   u'at',
#   u'any',
#   u'rate',
#   u'a',
#   u'book',
#   u'of',
#   u'rules',
#   u'for',
#   u'shutting',
#   u'people',
#   u'up',
#   u'like',
#   u'telescopes',
#   u':',
#   u'this',
#   u'time',
#   u'she',
#   u'found',
#   u'a',
#   u'little',
#   u'bottle',
#   u'on',
#   u'it',
#   u',',
#   u'(',
#   u"'which",
#   u'certainly',
#   u'was',
#   u'not',
#   u'here',
#   u'before',
#   u',',
#   u"'",
#   u'said',
#   u'Alice',
#   u',',
#   u')',
#   u'and',
#   u'round',
#   u'the',
#   u'neck',
#   u'of',
#   u'the',
#   u'bottle',
#   u'was',
#   u'a',
#   u'paper',
#   u'label',
#   u',',
#   u'with',
#   u'the',
#   u'words',
#   u"'DRINK",
#   u'ME',
#   u"'",
#   u'beautifully',
#   u'printed',
#   u'on',
#   u'it',
#   u'in',
#   u'large',
#   u'letters',
#   u'.'],
#  [u'It',
#   u'was',
#   u'all',
#   u'very',
#   u'well',
#   u'to',
#   u'say',
#   u"'Drink",
#   u'me',
#   u',',
#   u"'",
#   u'but',
#   u'the',
#   u'wise',
#   u'little',
#   u'Alice',
#   u'was',
#   u'not',
#   u'going',
#   u'to',
#   u'do',
#   u'THAT',
#   u'in',
#   u'a',
#   u'hurry',
#   u'.'],
#  [u"'No",
#   u',',
#   u'I',
#   u"'ll",
#   u'look',
#   u'first',
#   u',',
#   u"'",
#   u'she',
#   u'said',
#   u',',
#   u"'and",
#   u'see',
#   u'whether',
#   u'it',
#   u"'s",
#   u'marked',
#   u'``',
#   u'poison',
#   u"''",
#   u'or',
#   u'not',
#   u"'",
#   u';',
#   u'for',
#   u'she',
#   u'had',
#   u'read',
#   u'several',
#   u'nice',
#   u'little',
#   u'histories',
#   u'about',
#   u'children',
#   u'who',
#   u'had',
#   u'got',
#   u'burnt',
#   u',',
#   u'and',
#   u'eaten',
#   u'up',
#   u'by',
#   u'wild',
#   u'beasts',
#   u'and',
#   u'other',
#   u'unpleasant',
#   u'things',
#   u',',
#   u'all',
#   u'because',
#   u'they',
#   u'WOULD',
#   u'not',
#   u'remember',
#   u'the',
#   u'simple',
#   u'rules',
#   u'their',
#   u'friends',
#   u'had',
#   u'taught',
#   u'them',
#   u':',
#   u'such',
#   u'as',
#   u',',
#   u'that',
#   u'a',
#   u'red-hot',
#   u'poker',
#   u'will',
#   u'burn',
#   u'you',
#   u'if',
#   u'you',
#   u'hold',
#   u'it',
#   u'too',
#   u'long',
#   u';',
#   u'and',
#   u'that',
#   u'if',
#   u'you',
#   u'cut',
#   u'your',
#   u'finger',
#   u'VERY',
#   u'deeply',
#   u'with',
#   u'a',
#   u'knife',
#   u',',
#   u'it',
#   u'usually',
#   u'bleeds',
#   u';',
#   u'and',
#   u'she',
#   u'had',
#   u'never',
#   u'forgotten',
#   u'that',
#   u',',
#   u'if',
#   u'you',
#   u'drink',
#   u'much',
#   u'from',
#   u'a',
#   u'bottle',
#   u'marked',
#   u"'poison",
#   u',',
#   u"'",
#   u'it',
#   u'is',
#   u'almost',
#   u'certain',
#   u'to',
#   u'disagree',
#   u'with',
#   u'you',
#   u',',
#   u'sooner',
#   u'or',
#   u'later',
#   u'.'],
#  [u'However',
#   u',',
#   u'this',
#   u'bottle',
#   u'was',
#   u'NOT',
#   u'marked',
#   u"'poison",
#   u',',
#   u"'",
#   u'so',
#   u'Alice',
#   u'ventured',
#   u'to',
#   u'taste',
#   u'it',
#   u',',
#   u'and',
#   u'finding',
#   u'it',
#   u'very',
#   u'nice',
#   u',',
#   u'(',
#   u'it',
#   u'had',
#   u',',
#   u'in',
#   u'fact',
#   u',',
#   u'a',
#   u'sort',
#   u'of',
#   u'mixed',
#   u'flavour',
#   u'of',
#   u'cherry-tart',
#   u',',
#   u'custard',
#   u',',
#   u'pine-apple',
#   u',',
#   u'roast',
#   u'turkey',
#   u',',
#   u'toffee',
#   u',',
#   u'and',
#   u'hot',
#   u'buttered',
#   u'toast',
#   u',',
#   u')',
#   u'she',
#   u'very',
#   u'soon',
#   u'finished',
#   u'it',
#   u'off',
#   u'.'],
#  [u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u"'What",
#   u'a',
#   u'curious',
#   u'feeling',
#   u'!',
#   u"'"],
#  [u'said',
#   u'Alice',
#   u';',
#   u"'I",
#   u'must',
#   u'be',
#   u'shutting',
#   u'up',
#   u'like',
#   u'a',
#   u'telescope',
#   u'.',
#   u"'"],
#  [u'And',
#   u'so',
#   u'it',
#   u'was',
#   u'indeed',
#   u':',
#   u'she',
#   u'was',
#   u'now',
#   u'only',
#   u'ten',
#   u'inches',
#   u'high',
#   u',',
#   u'and',
#   u'her',
#   u'face',
#   u'brightened',
#   u'up',
#   u'at',
#   u'the',
#   u'thought',
#   u'that',
#   u'she',
#   u'was',
#   u'now',
#   u'the',
#   u'right',
#   u'size',
#   u'for',
#   u'going',
#   u'through',
#   u'the',
#   u'little',
#   u'door',
#   u'into',
#   u'that',
#   u'lovely',
#   u'garden',
#   u'.'],
#  [u'First',
#   u',',
#   u'however',
#   u',',
#   u'she',
#   u'waited',
#   u'for',
#   u'a',
#   u'few',
#   u'minutes',
#   u'to',
#   u'see',
#   u'if',
#   u'she',
#   u'was',
#   u'going',
#   u'to',
#   u'shrink',
#   u'any',
#   u'further',
#   u':',
#   u'she',
#   u'felt',
#   u'a',
#   u'little',
#   u'nervous',
#   u'about',
#   u'this',
#   u';',
#   u"'for",
#   u'it',
#   u'might',
#   u'end',
#   u',',
#   u'you',
#   u'know',
#   u',',
#   u"'",
#   u'said',
#   u'Alice',
#   u'to',
#   u'herself',
#   u',',
#   u"'in",
#   u'my',
#   u'going',
#   u'out',
#   u'altogether',
#   u',',
#   u'like',
#   u'a',
#   u'candle',
#   u'.'],
#  [u'I',
#   u'wonder',
#   u'what',
#   u'I',
#   u'should',
#   u'be',
#   u'like',
#   u'then',
#   u'?',
#   u"'"],
#  [u'And',
#   u'she',
#   u'tried',
#   u'to',
#   u'fancy',
#   u'what',
#   u'the',
#   u'flame',
#   u'of',
#   u'a',
#   u'candle',
#   u'is',
#   u'like',
#   u'after',
#   u'the',
#   u'candle',
#   u'is',
#   u'blown',
#   u'out',
#   u',',
#   u'for',
#   u'she',
#   u'could',
#   u'not',
#   u'remember',
#   u'ever',
#   u'having',
#   u'seen',
#   u'such',
#   u'a',
#   u'thing',
#   u'.'],
#  [u'After',
#   u'a',
#   u'while',
#   u',',
#   u'finding',
#   u'that',
#   u'nothing',
#   u'more',
#   u'happened',
#   u',',
#   u'she',
#   u'decided',
#   u'on',
#   u'going',
#   u'into',
#   u'the',
#   u'garden',
#   u'at',
#   u'once',
#   u';',
#   u'but',
#   u',',
#   u'alas',
#   u'for',
#   u'poor',
#   u'Alice',
#   u'!'],
#  [u'when',
#   u'she',
#   u'got',
#   u'to',
#   u'the',
#   u'door',
#   u',',
#   u'she',
#   u'found',
#   u'she',
#   u'had',
#   u'forgotten',
#   u'the',
#   u'little',
#   u'golden',
#   u'key',
#   u',',
#   u'and',
#   u'when',
#   u'she',
#   u'went',
#   u'back',
#   u'to',
#   u'the',
#   u'table',
#   u'for',
#   u'it',
#   u',',
#   u'she',
#   u'found',
#   u'she',
#   u'could',
#   u'not',
#   u'possibly',
#   u'reach',
#   u'it',
#   u':',
#   u'she',
#   u'could',
#   u'see',
#   u'it',
#   u'quite',
#   u'plainly',
#   u'through',
#   u'the',
#   u'glass',
#   u',',
#   u'and',
#   u'she',
#   u'tried',
#   u'her',
#   u'best',
#   u'to',
#   u'climb',
#   u'up',
#   u'one',
#   u'of',
#   u'the',
#   u'legs',
#   u'of',
#   u'the',
#   u'table',
#   u',',
#   u'but',
#   u'it',
#   u'was',
#   u'too',
#   u'slippery',
#   u';',
#   u'and',
#   u'when',
#   u'she',
#   u'had',
#   u'tired',
#   u'herself',
#   u'out',
#   u'with',
#   u'trying',
#   u',',
#   u'the',
#   u'poor',
#   u'little',
#   u'thing',
#   u'sat',
#   u'down',
#   u'and',
#   u'cried',
#   u'.'],
#  [u"'Come",
#   u',',
#   u'there',
#   u"'s",
#   u'no',
#   u'use',
#   u'in',
#   u'crying',
#   u'like',
#   u'that',
#   u'!',
#   u"'"],
#  [u'said',
#   u'Alice',
#   u'to',
#   u'herself',
#   u',',
#   u'rather',
#   u'sharply',
#   u';',
#   u"'I",
#   u'advise',
#   u'you',
#   u'to',
#   u'leave',
#   u'off',
#   u'this',
#   u'minute',
#   u'!',
#   u"'"],
#  [u'She',
#   u'generally',
#   u'gave',
#   u'herself',
#   u'very',
#   u'good',
#   u'advice',
#   u',',
#   u'(',
#   u'though',
#   u'she',
#   u'very',
#   u'seldom',
#   u'followed',
#   u'it',
#   u')',
#   u',',
#   u'and',
#   u'sometimes',
#   u'she',
#   u'scolded',
#   u'herself',
#   u'so',
#   u'severely',
#   u'as',
#   u'to',
#   u'bring',
#   u'tears',
#   u'into',
#   u'her',
#   u'eyes',
#   u';',
#   u'and',
#   u'once',
#   u'she',
#   u'remembered',
#   u'trying',
#   u'to',
#   u'box',
#   u'her',
#   u'own',
#   u'ears',
#   u'for',
#   u'having',
#   u'cheated',
#   u'herself',
#   u'in',
#   u'a',
#   u'game',
#   u'of',
#   u'croquet',
#   u'she',
#   u'was',
#   u'playing',
#   u'against',
#   u'herself',
#   u',',
#   u'for',
#   u'this',
#   u'curious',
#   u'child',
#   u'was',
#   u'very',
#   u'fond',
#   u'of',
#   u'pretending',
#   u'to',
#   u'be',
#   u'two',
#   u'people',
#   u'.'],
#  [u"'But",
#   u'it',
#   u"'s",
#   u'no',
#   u'use',
#   u'now',
#   u',',
#   u"'",
#   u'thought',
#   u'poor',
#   u'Alice',
#   u',',
#   u"'to",
#   u'pretend',
#   u'to',
#   u'be',
#   u'two',
#   u'people',
#   u'!'],
#  [u'Why',
#   u',',
#   u'there',
#   u"'s",
#   u'hardly',
#   u'enough',
#   u'of',
#   u'me',
#   u'left',
#   u'to',
#   u'make',
#   u'ONE',
#   u'respectable',
#   u'person',
#   u'!',
#   u"'"],
#  [u'Soon',
#   u'her',
#   u'eye',
#   u'fell',
#   u'on',
#   u'a',
#   u'little',
#   u'glass',
#   u'box',
#   u'that',
#   u'was',
#   u'lying',
#   u'under',
#   u'the',
#   u'table',
#   u':',
#   u'she',
#   u'opened',
#   u'it',
#   u',',
#   u'and',
#   u'found',
#   u'in',
#   u'it',
#   u'a',
#   u'very',
#   u'small',
#   u'cake',
#   u',',
#   u'on',
#   u'which',
#   u'the',
#   u'words',
#   u"'EAT",
#   u'ME',
#   u"'",
#   u'were',
#   u'beautifully',
#   u'marked',
#   u'in',
#   u'currants',
#   u'.'],
#  [u"'Well",
#   u',',
#   u'I',
#   u"'ll",
#   u'eat',
#   u'it',
#   u',',
#   u"'",
#   u'said',
#   u'Alice',
#   u',',
#   u"'and",
#   u'if',
#   u'it',
#   u'makes',
#   u'me',
#   u'grow',
#   u'larger',
#   u',',
#   u'I',
#   u'can',
#   u'reach',
#   u'the',
#   u'key',
#   u';',
#   u'and',
#   u'if',
#   u'it',
#   u'makes',
#   u'me',
#   u'grow',
#   u'smaller',
#   u',',
#   u'I',
#   u'can',
#   u'creep',
#   u'under',
#   u'the',
#   u'door',
#   u';',
#   u'so',
#   u'either',
#   u'way',
#   u"I'll",
#   u'get',
#   u'into',
#   u'the',
#   u'garden',
#   u',',
#   u'and',
#   u'I',
#   u'do',
#   u"n't",
#   u'care',
#   u'which',
#   u'happens',
#   u'!',
#   u"'"],
#  [u'She',
#   u'ate',
#   u'a',
#   u'little',
#   u'bit',
#   u',',
#   u'and',
#   u'said',
#   u'anxiously',
#   u'to',
#   u'herself',
#   u',',
#   u"'Which",
#   u'way',
#   u'?'],
#  [u'Which', u'way', u'?'],
#  [u"'",
#   u',',
#   u'holding',
#   u'her',
#   u'hand',
#   u'on',
#   u'the',
#   u'top',
#   u'of',
#   u'her',
#   u'head',
#   u'to',
#   u'feel',
#   u'which',
#   u'way',
#   u'it',
#   u'was',
#   u'growing',
#   u',',
#   u'and',
#   u'she',
#   u'was',
#   u'quite',
#   u'surprised',
#   u'to',
#   u'find',
#   u'that',
#   u'she',
#   u'remained',
#   u'the',
#   u'same',
#   u'size',
#   u':',
#   u'to',
#   u'be',
#   u'sure',
#   u',',
#   u'this',
#   u'generally',
#   u'happens',
#   u'when',
#   u'one',
#   u'eats',
#   u'cake',
#   u',',
#   u'but',
#   u'Alice',
#   u'had',
#   u'got',
#   u'so',
#   u'much',
#   u'into',
#   u'the',
#   u'way',
#   u'of',
#   u'expecting',
#   u'nothing',
#   u'but',
#   u'out-of-the-way',
#   u'things',
#   u'to',
#   u'happen',
#   u',',
#   u'that',
#   u'it',
#   u'seemed',
#   u'quite',
#   u'dull',
#   u'and',
#   u'stupid',
#   u'for',
#   u'life',
#   u'to',
#   u'go',
#   u'on',
#   u'in',
#   u'the',
#   u'common',
#   u'way',
#   u'.'],
#  [u'So',
#   u'she',
#   u'set',
#   u'to',
#   u'work',
#   u',',
#   u'and',
#   u'very',
#   u'soon',
#   u'finished',
#   u'off',
#   u'the',
#   u'cake',
#   u'.'],
#  [u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'*',
#   u'CHAPTER',
#   u'II',
#   u'.'],
#  [u'The',
#   u'Pool',
#   u'of',
#   u'Tears',
#   u"'Curiouser",
#   u'and',
#   u'curiouser',
#   u'!',
#   u"'"],
#  [u'cried',
#   u'Alice',
#   u'(',
#   u'she',
#   u'was',
#   u'so',
#   u'much',
#   u'surprised',
#   u',',
#   u'that',
#   u'for',
#   u'the',
#   u'moment',
#   u'she',
#   u'quite',
#   u'forgot',
#   u'how',
#   u'to',
#   u'speak',
#   u'good',
#   u'English',
#   u')',
#   u';',
#   u"'now",
#   u"I'm",
#   u'opening',
#   u'out',
#   u'like',
#   u'the',
#   u'largest',
#   u'telescope',
#   u'that',
#   u'ever',
#   u'was',
#   u'!'],
#  [u'Good-bye', u',', u'feet', u'!', u"'"],
#  [u'(',
#   u'for',
#   u'when',
#   u'she',
#   u'looked',
#   u'down',
#   u'at',
#   u'her',
#   u'feet',
#   u',',
#   u'they',
#   u'seemed',
#   u'to',
#   u'be',
#   u'almost',
#   u'out',
#   u'of',
#   u'sight',
#   u',',
#   u'they',
#   u'were',
#   u'getting',
#   u'so',
#   u'far',
#   u'off',
#   u')',
#   u'.'],
#  [u"'Oh",
#   u',',
#   u'my',
#   u'poor',
#   u'little',
#   u'feet',
#   u',',
#   u'I',
#   u'wonder',
#   u'who',
#   u'will',
#   u'put',
#   u'on',
#   u'your',
#   u'shoes',
#   u'and',
#   u'stockings',
#   u'for',
#   u'you',
#   u'now',
#   u',',
#   u'dears',
#   u'?'],
#  [u'I', u"'m", u'sure', u'_I_', u'sha', u"n't", u'be', u'able', u'!'],
#  [u'I',
#   u'shall',
#   u'be',
#   u'a',
#   u'great',
#   u'deal',
#   u'too',
#   u'far',
#   u'off',
#   u'to',
#   u'trouble',
#   u'myself',
#   u'about',
#   u'you',
#   u':',
#   u'you',
#   u'must',
#   u'manage',
#   u'the',
#   u'best',
#   u'way',
#   u'you',
#   u'can',
#   u';',
#   u'--',
#   u'but',
#   u'I',
#   u'must',
#   u'be',
#   u'kind',
#   u'to',
#   u'them',
#   u',',
#   u"'",
#   u'thought',
#   u'Alice',
#   u',',
#   u"'or",
#   u'perhaps',
#   u'they',
#   u'wo',
#   u"n't",
#   u'walk',
#   u'the',
#   u'way',
#   u'I',
#   u'want',
#   u'to',
#   u'go',
#   u'!'],
#  [u'Let',
#   u'me',
#   u'see',
#   u':',
#   u'I',
#   u"'ll",
#   u'give',
#   u'them',
#   u'a',
#   u'new',
#   u'pair',
#   u'of',
#   u'boots',
#   u'every',
#   u'Christmas',
#   u'.',
#   u"'"],
#  [u'And',
#   u'she',
#   u'went',
#   u'on',
#   u'planning',
#   u'to',
#   u'herself',
#   u'how',
#   u'she',
#   u'would',
#   u'manage',
#   u'it',
#   u'.'],
#  [u"'They",
#   u'must',
#   u'go',
#   u'by',
#   u'the',
#   u'carrier',
#   u',',
#   u"'",
#   u'she',
#   u'thought',
#   u';',
#   u"'and",
#   u'how',
#   u'funny',
#   u'it',
#   u"'ll",
#   u'seem',
#   u',',
#   u'sending',
#   u'presents',
#   u'to',
#   u'one',
#   u"'s",
#   u'own',
#   u'feet',
#   u'!'],
#  [u'And', u'how', u'odd', u'the', u'directions', u'will', u'look', u'!'],
#  [u'ALICE', u"'S", u'RIGHT', u'FOOT', u',', u'ESQ', u'.'],
#  [u'HEARTHRUG',
#   u',',
#   u'NEAR',
#   u'THE',
#   u'FENDER',
#   u',',
#   u'(',
#   u'WITH',
#   u'ALICE',
#   u"'S",
#   u'LOVE',
#   u')',
#   u'.'],
#  [u'Oh',
#   u'dear',
#   u',',
#   u'what',
#   u'nonsense',
#   u'I',
#   u"'m",
#   u'talking',
#   u'!',
#   u"'"],
#  [u'Just',
#   u'then',
#   u'her',
#   u'head',
#   u'struck',
#   u'against',
#   u'the',
#   u'roof',
#   u'of',
#   u'the',
#   u'hall',
#   u':',
#   u'in',
#   u'fact',
#   u'she',
#   u'was',
#   u'now',
#   u'more',
#   u'than',
#   u'nine',
#   u'feet',
#   u'high',
#   u',',
#   u'and',
#   u'she',
#   u'at',
#   u'once',
#   u'took',
#   u'up',
#   u'the',
#   u'little',
#   u'golden',
#   u'key',
#   u'and',
#   u'hurried',
#   u'off',
#   u'to',
#   u'the',
#   u'garden',
#   u'door',
#   u'.'],
#  [u'Poor', u'Alice', u'!'],
#  [u'It',
#   u'was',
#   u'as',
#   u'much',
#   u'as',
#   u'she',
#   u'could',
#   u'do',
#   u',',
#   u'lying',
#   u'down',
#   u'on',
#   u'one',
#   u'side',
#   u',',
#   u'to',
#   u'look',
#   u'through',
#   u'into',
#   u'the',
#   u'garden',
#   u'with',
#   u'one',
#   u'eye',
#   u';',
#   u'but',
#   u'to',
#   u'get',
#   u'through',
#   u'was',
#   u'more',
#   u'hopeless',
#   u'than',
#   u'ever',
#   u':',
#   u'she',
#   u'sat',
#   u'down',
#   u'and',
#   u'began',
#   u'to',
#   u'cry',
#   u'again',
#   u'.'],
#  [u"'You",
#   u'ought',
#   u'to',
#   u'be',
#   u'ashamed',
#   u'of',
#   u'yourself',
#   u',',
#   u"'",
#   u'said',
#   u'Alice',
#   u',',
#   u"'a",
#   u'great',
#   u'girl',
#   u'like',
#   u'you',
#   u',',
#   u"'",
#   u'(',
#   u'she',
#   u'might',
#   u'well',
#   u'say',
#   u'this',
#   u')',
#   u',',
#   u"'to",
#   u'go',
#   u'on',
#   u'crying',
#   u'in',
#   u'this',
#   u'way',
#   u'!'],
#  [u'Stop', u'this', u'moment', u',', u'I', u'tell', u'you', u'!', u"'"],
#  [u'But',
#   u'she',
#   u'went',
#   u'on',
#   u'all',
#   u'the',
#   u'same',
#   u',',
#   u'shedding',
#   u'gallons',
#   u'of',
#   u'tears',
#   u',',
#   u'until',
#   u'there',
#   u'was',
#   u'a',
#   u'large',
#   u'pool',
#   u'all',
#   u'round',
#   u'her',
#   u',',
#   u'about',
#   u'four',
#   u'inches',
#   u'deep',
#   u'and',
#   u'reaching',
#   u'half',
#   u'down',
#   u'the',
#   u'hall',
#   u'.'],
#  [u'After',
#   u'a',
#   u'time',
#   u'she',
#   u'heard',
#   u'a',
#   u'little',
#   u'pattering',
#   u'of',
#   u'feet',
#   u'in',
#   u'the',
#   u'distance',
#   u',',
#   u'and',
#   u'she',
#   u'hastily',
#   u'dried',
#   u'her',
#   u'eyes',
#   u'to',
#   u'see',
#   u'what',
#   u'was',
#   u'coming',
#   u'.'],
#  [u'It',
#   u'was',
#   u'the',
#   u'White',
#   u'Rabbit',
#   u'returning',
#   u',',
#   u'splendidly',
#   u'dressed',
#   u',',
#   u'with',
#   u'a',
#   u'pair',
#   u'of',
#   u'white',
#   u'kid',
#   u'gloves',
#   u'in',
#   u'one',
#   u'hand',
#   u'and',
#   u'a',
#   u'large',
#   u'fan',
#   u'in',
#   u'the',
#   u'other',
#   u':',
#   u'he',
#   u'came',
#   u'trotting',
#   u'along',
#   u'in',
#   u'a',
#   u'great',
#   u'hurry',
#   u',',
#   u'muttering',
#   u'to',
#   u'himself',
#   u'as',
#   u'he',
#   u'came',
#   u',',
#   u"'Oh",
#   u'!'],
#  [u'the', u'Duchess', u',', u'the', u'Duchess', u'!'],
#  [u'Oh', u'!'],
#  [u'wo',
#   u"n't",
#   u'she',
#   u'be',
#   u'savage',
#   u'if',
#   u'I',
#   u"'ve",
#   u'kept',
#   u'her',
#   u'waiting',
#   u'!',
#   u"'"],
#  [u'Alice',
#   u'felt',
#   u'so',
#   u'desperate',
#   u'that',
#   u'she',
#   u'was',
#   u'ready',
#   u'to',
#   u'ask',
#   u'help',
#   u'of',
#   u'any',
#   u'one',
#   u';',
#   u'so',
#   u',',
#   u'when',
#   u'the',
#   u'Rabbit',
#   u'came',
#   u'near',
#   u'her',
#   u',',
#   u'she',
#   u'began',
#   u',',
#   u'in',
#   u'a',
#   u'low',
#   u',',
#   u'timid',
#   u'voice',
#   u',',
#   u"'If",
#   u'you',
#   u'please',
#   u',',
#   u'sir',
#   u'--',
#   u"'",
#   u'The',
#   u'Rabbit',
#   u'started',
#   u'violently',
#   u',',
#   u'dropped',
#   u'the',
#   u'white',
#   u'kid',
#   u'gloves',
#   u'and',
#   u'the',
#   u'fan',
#   u',',
#   u'and',
#   u'skurried',
#   u'away',
#   u'into',
#   u'the',
#   u'darkness',
#   u'as',
#   u'hard',
#   u'as',
#   u'he',
#   u'could',
#   u'go',
#   u'.'],
#  [u'Alice',
#   u'took',
#   u'up',
#   u'the',
#   u'fan',
#   u'and',
#   u'gloves',
#   u',',
#   u'and',
#   u',',
#   u'as',
#   u'the',
#   u'hall',
#   u'was',
#   u'very',
#   u'hot',
#   u',',
#   u'she',
#   u'kept',
#   u'fanning',
#   u'herself',
#   u'all',
#   u'the',
#   u'time',
#   u'she',
#   u'went',
#   u'on',
#   u'talking',
#   u':',
#   u"'Dear",
#   u',',
#   u'dear',
#   u'!'],
#  [u'How', u'queer', u'everything', u'is', u'to-day', u'!'],
#  [u'And',
#   u'yesterday',
#   u'things',
#   u'went',
#   u'on',
#   u'just',
#   u'as',
#   u'usual',
#   u'.'],
#  [u'I',
#   u'wonder',
#   u'if',
#   u'I',
#   u"'ve",
#   u'been',
#   u'changed',
#   u'in',
#   u'the',
#   u'night',
#   u'?'],
#  [u'Let',
#   u'me',
#   u'think',
#   u':',
#   u'was',
#   u'I',
#   u'the',
#   u'same',
#   u'when',
#   u'I',
#   u'got',
#   u'up',
#   u'this',
#   u'morning',
#   u'?'],
#  [u'I',
#   u'almost',
#   u'think',
#   u'I',
#   u'can',
#   u'remember',
#   u'feeling',
#   u'a',
#   u'little',
#   u'different',
#   u'.'],
#  [u'But',
#   u'if',
#   u'I',
#   u"'m",
#   u'not',
#   u'the',
#   u'same',
#   u',',
#   u'the',
#   u'next',
#   u'question',
#   u'is',
#   u',',
#   u'Who',
#   u'in',
#   u'the',
#   u'world',
#   u'am',
#   u'I',
#   u'?'],
#  [u'Ah', u',', u'THAT', u"'S", u'the', u'great', u'puzzle', u'!', u"'"],
#  [u'And',
#   u'she',
#   u'began',
#   u'thinking',
#   u'over',
#   u'all',
#   u'the',
#   u'children',
#   u'she',
#   u'knew',
#   u'that',
#   u'were',
#   u'of',
#   u'the',
#   u'same',
#   u'age',
#   u'as',
#   u'herself',
#   u',',
#   u'to',
#   u'see',
#   u'if',
#   u'she',
#   u'could',
#   u'have',
#   u'been',
#   u'changed',
#   u'for',
#   u'any',
#   u'of',
#   u'them',
#   u'.'],
#  [u"'I",
#   u"'m",
#   u'sure',
#   u'I',
#   u"'m",
#   u'not',
#   u'Ada',
#   u',',
#   u"'",
#   u'she',
#   u'said',
#   u',',
#   u"'for",
#   u'her',
#   u'hair',
#   u'goes',
#   u'in',
#   u'such',
#   u'long',
#   u'ringlets',
#   u',',
#   u'and',
#   u'mine',
#   u'does',
#   u"n't",
#   u'go',
#   u'in',
#   u'ringlets',
#   u'at',
#   u'all',
#   u';',
#   u'and',
#   u'I',
#   u"'m",
#   u'sure',
#   u'I',
#   u"can't",
#   u'be',
#   u'Mabel',
#   u',',
#   u'for',
#   u'I',
#   u'know',
#   u'all',
#   u'sorts',
#   u'of',
#   u'things',
#   u',',
#   u'and',
#   u'she',
#   u',',
#   u'oh',
#   u'!'],
#  [u'she', u'knows', u'such', u'a', u'very', u'little', u'!'],
#  [u'Besides',
#   u',',
#   u'SHE',
#   u"'S",
#   u'she',
#   u',',
#   u'and',
#   u'I',
#   u"'m",
#   u'I',
#   u',',
#   u'and',
#   u'--',
#   u'oh',
#   u'dear',
#   u',',
#   u'how',
#   u'puzzling',
#   u'it',
#   u'all',
#   u'is',
#   u'!'],
#  [u'I',
#   u"'ll",
#   u'try',
#   u'if',
#   u'I',
#   u'know',
#   u'all',
#   u'the',
#   u'things',
#   u'I',
#   u'used',
#   u'to',
#   u'know',
#   u'.'],
#  [u'Let',
#   u'me',
#   u'see',
#   u':',
#   u'four',
#   u'times',
#   u'five',
#   u'is',
#   u'twelve',
#   u',',
#   u'and',
#   u'four',
#   u'times',
#   u'six',
#   u'is',
#   u'thirteen',
#   u',',
#   u'and',
#   u'four',
#   u'times',
#   u'seven',
#   u'is',
#   u'--',
#   u'oh',
#   u'dear',
#   u'!'],
#  [u'I',
#   u'shall',
#   u'never',
#   u'get',
#   u'to',
#   u'twenty',
#   u'at',
#   u'that',
#   u'rate',
#   u'!'],
#  [u'However',
#   u',',
#   u'the',
#   u'Multiplication',
#   u'Table',
#   u'does',
#   u"n't",
#   u'signify',
#   u':',
#   u'let',
#   u"'s",
#   u'try',
#   u'Geography',
#   u'.'],
#  [u'London',
#   u'is',
#   u'the',
#   u'capital',
#   u'of',
#   u'Paris',
#   u',',
#   u'and',
#   u'Paris',
#   u'is',
#   u'the',
#   u'capital',
#   u'of',
#   u'Rome',
#   u',',
#   u'and',
#   u'Rome',
#   u'--',
#   u'no',
#   u',',
#   u'THAT',
#   u"'S",
#   u'all',
#   u'wrong',
#   u',',
#   u'I',
#   u"'m",
#   u'certain',
#   u'!'],
#  [u'I', u'must', u'have', u'been', u'changed', u'for', u'Mabel', u'!'],
#  [u'I',
#   u"'ll",
#   u'try',
#   u'and',
#   u'say',
#   u'``',
#   u'How',
#   u'doth',
#   u'the',
#   u'little',
#   u'--',
#   u"''",
#   u"'",
#   u'and',
#   u'she',
#   u'crossed',
#   u'her',
#   u'hands',
#   u'on',
#   u'her',
#   u'lap',
#   u'as',
#   u'if',
#   u'she',
#   u'were',
#   u'saying',
#   u'lessons',
#   u',',
#   u'and',
#   u'began',
#   u'to',
#   u'repeat',
#   u'it',
#   u',',
#   u'but',
#   u'her',
#   u'voice',
#   u'sounded',
#   u'hoarse',
#   u'and',
#   u'strange',
#   u',',
#   u'and',
#   u'the',
#   u'words',
#   u'did',
#   u'not',
#   u'come',
#   u'the',
#   u'same',
#   u'as',
#   u'they',
#   u'used',
#   u'to',
#   u'do',
#   u':',
#   u'--',
#   u"'How",
#   u'doth',
#   u'the',
#   u'little',
#   u'crocodile',
#   u'Improve',
#   u'his',
#   u'shining',
#   u'tail',
#   u',',
#   u'And',
#   u'pour',
#   u'the',
#   u'waters',
#   u'of',
#   u'the',
#   u'Nile',
#   u'On',
#   u'every',
#   u'golden',
#   u'scale',
#   u'!'],
#  [u"'How",
#   u'cheerfully',
#   u'he',
#   u'seems',
#   u'to',
#   u'grin',
#   u',',
#   u'How',
#   u'neatly',
#   u'spread',
#   u'his',
#   u'claws',
#   u',',
#   u'And',
#   u'welcome',
#   u'little',
#   u'fishes',
#   u'in',
#   u'With',
#   u'gently',
#   u'smiling',
#   u'jaws',
#   u'!',
#   u"'"],
#  [u"'I",
#   u"'m",
#   u'sure',
#   u'those',
#   u'are',
#   u'not',
#   u'the',
#   u'right',
#   u'words',
#   u',',
#   u"'",
#   u'said',
#   u'poor',
#   u'Alice',
#   u',',
#   u'and',
#   u'her',
#   u'eyes',
#   u'filled',
#   u'with',
#   u'tears',
#   u'again',
#   u'as',
#   u'she',
#   u'went',
#   u'on',
#   u',',
#   u"'I",
#   u'must',
#   u'be',
#   u'Mabel',
#   u'after',
#   u'all',
#   u',',
#   u'and',
#   u'I',
#   u'shall',
#   u'have',
#   u'to',
#   u'go',
#   u'and',
#   u'live',
#   u'in',
#   u'that',
#   u'poky',
#   u'little',
#   u'house',
#   u',',
#   u'and',
#   u'have',
#   u'next',
#   u'to',
#   u'no',
#   u'toys',
#   u'to',
#   u'play',
#   u'with',
#   u',',
#   u'and',
#   u'oh',
#   u'!'],
#  [u'ever', u'so', u'many', u'lessons', u'to', u'learn', u'!'],
#  [u'No',
#   u',',
#   u"I've",
#   u'made',
#   u'up',
#   u'my',
#   u'mind',
#   u'about',
#   u'it',
#   u';',
#   u'if',
#   u'I',
#   u"'m",
#   u'Mabel',
#   u',',
#   u'I',
#   u"'ll",
#   u'stay',
#   u'down',
#   u'here',
#   u'!'],
#  [u'It',
#   u"'ll",
#   u'be',
#   u'no',
#   u'use',
#   u'their',
#   u'putting',
#   u'their',
#   u'heads',
#   u'down',
#   u'and',
#   u'saying',
#   u'``',
#   u'Come',
#   u'up',
#   u'again',
#   u',',
#   u'dear',
#   u'!',
#   u"''"],
#  [u'I',
#   u'shall',
#   u'only',
#   u'look',
#   u'up',
#   u'and',
#   u'say',
#   u'``',
#   u'Who',
#   u'am',
#   u'I',
#   u'then',
#   u'?'],
#  [u'Tell',
#   u'me',
#   u'that',
#   u'first',
#   u',',
#   u'and',
#   u'then',
#   u',',
#   u'if',
#   u'I',
#   u'like',
#   u'being',
#   u'that',
#   u'person',
#   u',',
#   u'I',
#   u"'ll",
#   u'come',
#   u'up',
#   u':',
#   u'if',
#   u'not',
#   u',',
#   u'I',
#   u"'ll",
#   u'stay',
#   u'down',
#   u'here',
#   u'till',
#   u'I',
#   u"'m",
#   u'somebody',
#   u'else',
#   u"''",
#   u'--',
#   u'but',
#   u',',
#   u'oh',
#   u'dear',
#   u'!',
#   u"'"],
#  [u'cried',
#   u'Alice',
#   u',',
#   u'with',
#   u'a',
#   u'sudden',
#   u'burst',
#   u'of',
#   u'tears',
#   u',',
#   u"'I",
#   u'do',
#   u'wish',
#   u'they',
#   u'WOULD',
#   u'put',
#   u'their',
#   u'heads',
#   u'down',
#   u'!'],
#  [u'I',
#   u'am',
#   u'so',
#   u'VERY',
#   u'tired',
#   u'of',
#   u'being',
#   u'all',
#   u'alone',
#   u'here',
#   u'!',
#   u"'"],
#  [u'As',
#   u'she',
#   u'said',
#   u'this',
#   u'she',
#   u'looked',
#   u'down',
#   u'at',
#   u'her',
#   u'hands',
#   u',',
#   u'and',
#   u'was',
#   u'surprised',
#   u'to',
#   u'see',
#   u'that',
#   u'she',
#   u'had',
#   u'put',
#   u'on',
#   u'one',
#   u'of',
#   u'the',
#   u'Rabbit',
#   u"'s",
#   u'little',
#   u'white',
#   u'kid',
#   u'gloves',
#   u'while',
#   u'she',
#   u'was',
#   u'talking',
#   u'.'],
#  [u"'How", u'CAN', u'I', u'have', u'done', u'that', u'?', u"'"],
#  [u'she', u'thought', u'.'],
#  [u"'I", u'must', u'be', u'growing', u'small', u'again', u'.', u"'"],
#  [u'She',
#   u'got',
#   u'up',
#   u'and',
#   u'went',
#   u'to',
#   u'the',
#   u'table',
#   u'to',
#   u'measure',
#   u'herself',
#   u'by',
#   u'it',
#   u',',
#   u'and',
#   u'found',
#   u'that',
#   u',',
#   u'as',
#   u'nearly',
#   u'as',
#   u'she',
#   u'could',
#   u'guess',
#   u',',
#   u'she',
#   u'was',
#   u'now',
#   u'about',
#   u'two',
#   u'feet',
#   u'high',
#   u',',
#   u'and',
#   u'was',
#   u'going',
#   u'on',
#   u'shrinking',
#   u'rapidly',
#   u':',
#   u'she',
#   u'soon',
#   u'found',
#   u'out',
#   u'that',
#   u'the',
#   u'cause',
#   u'of',
#   u'this',
#   u'was',
#   u'the',
#   u'fan',
#   u'she',
#   u'was',
#   u'holding',
#   u',',
#   u'and',
#   u'she',
#   u'dropped',
#   u'it',
#   u'hastily',
#   u',',
#   u'just',
#   u'in',
#   u'time',
#   u'to',
#   u'avoid',
#   u'shrinking',
#   u'away',
#   u'altogether',
#   u'.'],
#  [u"'That", u'WAS', u'a', u'narrow', u'escape', u'!', u"'"],
#  [u'said',
#   u'Alice',
#   u',',
#   u'a',
#   u'good',
#   u'deal',
#   u'frightened',
#   u'at',
#   u'the',
#   u'sudden',
#   u'change',
#   u',',
#   u'but',
#   u'very',
#   u'glad',
#   u'to',
#   u'find',
#   u'herself',
#   u'still',
#   u'in',
#   u'existence',
#   u';',
#   u"'and",
#   u'now',
#   u'for',
#   u'the',
#   u'garden',
#   u'!',
#   u"'"],
#  [u'and',
#   u'she',
#   u'ran',
#   u'with',
#   u'all',
#   u'speed',
#   u'back',
#   u'to',
#   u'the',
#   u'little',
#   u'door',
#   u':',
#   u'but',
#   u',',
#   u'alas',
#   u'!'],
#  [u'the',
#   u'little',
#   u'door',
#   u'was',
#   u'shut',
#   u'again',
#   u',',
#   u'and',
#   u'the',
#   u'little',
#   u'golden',
#   u'key',
#   u'was',
#   u'lying',
#   u'on',
#   u'the',
#   u'glass',
#   u'table',
#   u'as',
#   u'before',
#   u',',
#   u"'and",
#   u'things',
#   u'are',
#   u'worse',
#   u'than',
#   u'ever',
#   u',',
#   u"'",
#   u'thought',
#   u'the',
#   u'poor',
#   u'child',
#   u',',
#   u"'for",
#   u'I',
#   u'never',
#   u'was',
#   u'so',
#   u'small',
#   u'as',
#   u'this',
#   u'before',
#   u',',
#   u'never',
#   u'!'],
#  [u'And',
#   u'I',
#   u'declare',
#   u'it',
#   u"'s",
#   u'too',
#   u'bad',
#   u',',
#   u'that',
#   u'it',
#   u'is',
#   u'!',
#   u"'"],
#  [u'As',
#   u'she',
#   u'said',
#   u'these',
#   u'words',
#   u'her',
#   u'foot',
#   u'slipped',
#   u',',
#   u'and',
#   u'in',
#   u'another',
#   u'moment',
#   u',',
#   u'splash',
#   u'!'],
#  [u'she',
#   u'was',
#   u'up',
#   u'to',
#   u'her',
#   u'chin',
#   u'in',
#   u'salt',
#   u'water',
#   u'.'],
#  [u'Her',
#   u'first',
#   u'idea',
#   u'was',
#   u'that',
#   u'she',
#   u'had',
#   u'somehow',
#   u'fallen',
#   u'into',
#   u'the',
#   u'sea',
#   u',',
#   u"'and",
#   u'in',
#   u'that',
#   u'case',
#   u'I',
#   u'can',
#   u'go',
#   u'back',
#   u'by',
#   u'railway',
#   u',',
#   u"'",
#   u'she',
#   u'said',
#   u'to',
#   u'herself',
#   u'.'],
#  [u'(',
#   u'Alice',
#   u'had',
#   u'been',
#   u'to',
#   u'the',
#   u'seaside',
#   u'once',
#   u'in',
#   u'her',
#   u'life',
#   u',',
#   u'and',
#   u'had',
#   u'come',
#   u'to',
#   u'the',
#   u'general',
#   u'conclusion',
#   u',',
#   u'that',
#   u'wherever',
#   u'you',
#   u'go',
#   u'to',
#   u'on',
#   u'the',
#   u'English',
#   u'coast',
#   u'you',
#   u'find',
#   u'a',
#   u'number',
#   u'of',
#   u'bathing',
#   u'machines',
#   u'in',
#   u'the',
#   u'sea',
#   u',',
#   u'some',
#   u'children',
#   u'digging',
#   u'in',
#   u'the',
#   u'sand',
#   u'with',
#   u'wooden',
#   u'spades',
#   u',',
#   u'then',
#   u'a',
#   u'row',
#   u'of',
#   u'lodging',
#   u'houses',
#   u',',
#   u'and',
#   u'behind',
#   u'them',
#   u'a',
#   u'railway',
#   u'station',
#   u'.',
#   u')'],
#  [u'However',
#   u',',
#   u'she',
#   u'soon',
#   u'made',
#   u'out',
#   u'that',
#   u'she',
#   u'was',
#   u'in',
#   u'the',
#   u'pool',
#   u'of',
#   u'tears',
#   u'which',
#   u'she',
#   u'had',
#   u'wept',
#   u'when',
#   u'she',
#   u'was',
#   u'nine',
#   u'feet',
#   u'high',
#   u'.'],
#  [u"'I", u'wish', u'I', u'had', u"n't", u'cried', u'so', u'much', u'!', u"'"],
#  [u'said',
#   u'Alice',
#   u',',
#   u'as',
#   u'she',
#   u'swam',
#   u'about',
#   u',',
#   u'trying',
#   u'to',
#   u'find',
#   u'her',
#   u'way',
#   u'out',
#   u'.'],
#  [u"'I",
#   u'shall',
#   u'be',
#   u'punished',
#   u'for',
#   u'it',
#   u'now',
#   u',',
#   u'I',
#   u'suppose',
#   u',',
#   u'by',
#   u'being',
#   u'drowned',
#   u'in',
#   u'my',
#   u'own',
#   u'tears',
#   u'!'],
#  [u'That',
#   u'WILL',
#   u'be',
#   u'a',
#   u'queer',
#   u'thing',
#   u',',
#   u'to',
#   u'be',
#   u'sure',
#   u'!'],
#  [u'However', u',', u'everything', u'is', u'queer', u'to-day', u'.', u"'"],
#  [u'Just',
#   u'then',
#   u'she',
#   u'heard',
#   u'something',
#   u'splashing',
#   u'about',
#   u'in',
#   u'the',
#   u'pool',
#   u'a',
#   u'little',
#   u'way',
#   u'off',
#   u',',
#   u'and',
#   u'she',
#   u'swam',
#   u'nearer',
#   u'to',
#   u'make',
#   u'out',
#   u'what',
#   u'it',
#   u'was',
#   u':',
#   u'at',
#   u'first',
#   u'she',
#   u'thought',
#   u'it',
#   u'must',
#   u'be',
#   u'a',
#   u'walrus',
#   u'or',
#   u'hippopotamus',
#   u',',
#   u'but',
#   u'then',
#   u'she',
#   u'remembered',
#   u'how',
#   u'small',
#   u'she',
#   u'was',
#   u'now',
#   u',',
#   u'and',
#   u'she',
#   u'soon',
#   u'made',
#   u'out',
#   u'that',
#   u'it',
#   u'was',
#   u'only',
#   u'a',
#   u'mouse',
#   u'that',
#   u'had',
#   u'slipped',
#   u'in',
#   u'like',
#   u'herself',
#   u'.'],
#  [u"'Would",
#   u'it',
#   u'be',
#   u'of',
#   u'any',
#   u'use',
#   u',',
#   u'now',
#   u',',
#   u"'",
#   u'thought',
#   u'Alice',
#   u',',
#   u"'to",
#   u'speak',
#   u'to',
#   u'this',
#   u'mouse',
#   u'?'],
#  [u'Everything',
#   u'is',
#   u'so',
#   u'out-of-the-way',
#   u'down',
#   u'here',
#   u',',
#   u'that',
#   u'I',
#   u'should',
#   u'think',
#   u'very',
#   u'likely',
#   u'it',
#   u'can',
#   u'talk',
#   u':',
#   u'at',
#   u'any',
#   u'rate',
#   u',',
#   u'there',
#   u"'s",
#   u'no',
#   u'harm',
#   u'in',
#   u'trying',
#   u'.',
#   u"'"],
#  [u'So',
#   u'she',
#   u'began',
#   u':',
#   u"'O",
#   u'Mouse',
#   u',',
#   u'do',
#   u'you',
#   u'know',
#   u'the',
#   u'way',
#   u'out',
#   u'of',
#   u'this',
#   u'pool',
#   u'?'],
#  [u'I',
#   u'am',
#   u'very',
#   u'tired',
#   u'of',
#   u'swimming',
#   u'about',
#   u'here',
#   u',',
#   u'O',
#   u'Mouse',
#   u'!',
#   u"'"],
#  [u'(',
#   u'Alice',
#   u'thought',
#   u'this',
#   u'must',
#   u'be',
#   u'the',
#   u'right',
#   u'way',
#   u'of',
#   u'speaking',
#   u'to',
#   u'a',
#   u'mouse',
#   u':',
#   u'she',
#   u'had',
#   u'never',
#   u'done',
#   u'such',
#   u'a',
#   u'thing',
#   u'before',
#   u',',
#   u'but',
#   u'she',
#   u'remembered',
#   u'having',
#   u'seen',
#   u'in',
#   u'her',
#   u'brother',
#   u"'s",
#   u'Latin',
#   u'Grammar',
#   u',',
#   u"'A",
#   u'mouse',
#   u'--',
#   u'of',
#   u'a',
#   u'mouse',
#   u'--',
#   u'to',
#   u'a',
#   u'mouse',
#   u'--',
#   u'a',
#   u'mouse',
#   u'--',
#   u'O',
#   u'mouse',
#   u'!',
#   u"'",
#   u')'],
#  [u'The',
#   u'Mouse',
#   u'looked',
#   u'at',
#   u'her',
#   u'rather',
#   u'inquisitively',
#   u',',
#   u'and',
#   u'seemed',
#   u'to',
#   u'her',
#   u'to',
#   u'wink',
#   u'with',
#   u'one',
#   u'of',
#   u'its',
#   u'little',
#   u'eyes',
#   u',',
#   u'but',
#   u'it',
#   u'said',
#   u'nothing',
#   u'.'],
#  [u"'Perhaps",
#   u'it',
#   u'does',
#   u"n't",
#   u'understand',
#   u'English',
#   u',',
#   u"'",
#   u'thought',
#   u'Alice',
#   u';',
#   u"'I",
#   u'daresay',
#   u"it's",
#   u'a',
#   u'French',
#   u'mouse',
#   u',',
#   u'come',
#   u'over',
#   u'with',
#   u'William',
#   u'the',
#   u'Conqueror',
#   u'.',
#   u"'"],
#  [u'(',
#   u'For',
#   u',',
#   u'with',
#   u'all',
#   u'her',
#   u'knowledge',
#   u'of',
#   u'history',
#   u',',
#   u'Alice',
#   u'had',
#   u'no',
#   u'very',
#   u'clear',
#   u'notion',
#   u'how',
#   u'long',
#   u'ago',
#   u'anything',
#   u'had',
#   u'happened',
#   u'.',
#   u')'],
#  [u'So',
#   u'she',
#   u'began',
#   u'again',
#   u':',
#   u"'Ou",
#   u'est',
#   u'ma',
#   u'chatte',
#   u'?',
#   u"'"],
#  [u'which',
#   u'was',
#   u'the',
#   u'first',
#   u'sentence',
#   u'in',
#   u'her',
#   u'French',
#   u'lesson-book',
#   u'.'],
#  [u'The',
#   u'Mouse',
#   u'gave',
#   u'a',
#   u'sudden',
#   u'leap',
#   u'out',
#   u'of',
#   u'the',
#   u'water',
#   u',',
#   u'and',
#   u'seemed',
#   u'to',
#   u'quiver',
#   u'all',
#   u'over',
#   u'with',
#   u'fright',
#   u'.'],
#  [u"'Oh", u',', u'I', u'beg', u'your', u'pardon', u'!', u"'"],
#  [u'cried',
#   u'Alice',
#   u'hastily',
#   u',',
#   u'afraid',
#   u'that',
#   u'she',
#   u'had',
#   u'hurt',
#   u'the',
#   u'poor',
#   u'animal',
#   u"'s",
#   u'feelings',
#   u'.'],
#  [u"'I",
#   u'quite',
#   u'forgot',
#   u'you',
#   u'did',
#   u"n't",
#   u'like',
#   u'cats',
#   u'.',
#   u"'"],
#  [u"'Not", u'like', u'cats', u'!', u"'"],
#  [u'cried',
#   u'the',
#   u'Mouse',
# ...
#   u'!',
#   u"'"],
#  [u'said',
#   u'Alice',
#   u'as',
#   u'she',
#   u'picked',
#   u'her',
#   u'way',
#   u'through',
#   u'the',
#   u'wood',
#   u'.'],
#  [u"'It",
#   u"'s",
#   u'the',
#   u'stupidest',
#   u'tea-party',
#   u'I',
#   u'ever',
#   u'was',
#   u'at',
#   u'in',
#   u'all',
#   u'my',
#   u'life',
#   u'!',
#   u"'"],
#  [u'Just',
#   u'as',
#   u'she',
#   u'said',
#   u'this',
#   u',',
#   u'she',
#   u'noticed',
#   u'that',
#   u'one',
#   u'of',
#   u'the',
#   u'trees',
#   u'had',
#   u'a',
#   u'door',
#   u'leading',
#   u'right',
#   u'into',
#   u'it',
#   u'.'],
#  [u"'That", u"'s", u'very', u'curious', u'!', u"'"],
#  [u'she', u'thought', u'.'],
#  [u"'But", u'everything', u"'s", u'curious', u'today', u'.'],
#  [u'I',
#   u'think',
#   u'I',
#   u'may',
#   u'as',
#   u'well',
#   u'go',
#   u'in',
#   u'at',
#   u'once',
#   u'.',
#   u"'"],
#  [u'And', u'in', u'she', u'went', u'.'],
#  [u'Once',
#   u'more',
#   u'she',
#   u'found',
#   u'herself',
#   u'in',
#   u'the',
#   u'long',
#   u'hall',
#   u',',
#   u'and',
#   u'close',
#   u'to',
#   u'the',
#   u'little',
#   u'glass',
#   u'table',
#   u'.'],
#  [u"'Now",
#   u',',
#   u'I',
#   u"'ll",
#   u'manage',
#   u'better',
#   u'this',
#   u'time',
#   u',',
#   u"'",
#   u'she',
#   u'said',
#   u'to',
#   u'herself',
#   u',',
#   u'and',
#   u'began',
#   u'by',
#   u'taking',
#   u'the',
#   u'little',
#   u'golden',
#   u'key',
#   u',',
#   u'and',
#   u'unlocking',
#   u'the',
#   u'door',
#   u'that',
#   u'led',
#   u'into',
#   u'the',
#   u'garden',
#   u'.'],
#  [u'Then',
#   u'she',
#   u'went',
#   u'to',
#   u'work',
#   u'nibbling',
#   u'at',
#   u'the',
#   u'mushroom',
#   u'(',
#   u'she',
#   u'had',
#   u'kept',
#   u'a',
#   u'piece',
#   u'of',
#   u'it',
#   u'in',
#   u'her',
#   u'pocket',
#   u')',
#   u'till',
#   u'she',
#   u'was',
#   u'about',
#   u'a',
#   u'foot',
#   u'high',
#   u':',
#   u'then',
#   u'she',
#   u'walked',
#   u'down',
#   u'the',
#   u'little',
#   u'passage',
#   u':',
#   u'and',
#   u'THEN',
#   u'--',
#   u'she',
#   u'found',
#   u'herself',
#   u'at',
#   u'last',
#   u'in',
#   u'the',
#   u'beautiful',
#   u'garden',
#   u',',
#   u'among',
#   u'the',
#   u'bright',
#   u'flower-beds',
#   u'and',
#   u'the',
#   u'cool',
#   u'fountains',
#   u'.'],
#  [u'CHAPTER', u'VIII', u'.'],
#  [u'The',
#   u'Queen',
#   u"'s",
#   u'Croquet-Ground',
#   u'A',
#   u'large',
#   u'rose-tree',
#   u'stood',
#   u'near',
#   u'the',
#   u'entrance',
#   u'of',
#   u'the',
#   u'garden',
#   u':',
#   u'the',
#   u'roses',
#   u'growing',
#   u'on',
#   u'it',
#   u'were',
#   u'white',
#   u',',
#   u'but',
#   u'there',
#   u'were',
#   u'three',
#   u'gardeners',
#   u'at',
#   u'it',
#   u',',
#   u'busily',
#   u'painting',
#   u'them',
#   u'red',
#   u'.'],
#  [u'Alice',
#   u'thought',
#   u'this',
#   u'a',
#   u'very',
#   u'curious',
#   u'thing',
#   u',',
#   u'and',
#   u'she',
#   u'went',
#   u'nearer',
#   u'to',
#   u'watch',
#   u'them',
#   u',',
#   u'and',
#   u'just',
#   u'as',
#   u'she',
#   u'came',
#   u'up',
#   u'to',
#   u'them',
#   u'she',
#   u'heard',
#   u'one',
#   u'of',
#   u'them',
#   u'say',
#   u',',
#   u"'Look",
#   u'out',
#   u'now',
#   u',',
#   u'Five',
#   u'!'],
#  [u'Do',
#   u"n't",
#   u'go',
#   u'splashing',
#   u'paint',
#   u'over',
#   u'me',
#   u'like',
#   u'that',
#   u'!',
#   u"'"],
#  [u"'I",
#   u'could',
#   u"n't",
#   u'help',
#   u'it',
#   u',',
#   u"'",
#   u'said',
#   u'Five',
#   u',',
#   u'in',
#   u'a',
#   u'sulky',
#   u'tone',
#   u';',
#   u"'Seven",
#   u'jogged',
#   u'my',
#   u'elbow',
#   u'.',
#   u"'"],
#  [u'On',
#   u'which',
#   u'Seven',
#   u'looked',
#   u'up',
#   u'and',
#   u'said',
#   u',',
#   u"'That",
#   u"'s",
#   u'right',
#   u',',
#   u'Five',
#   u'!'],
#  [u'Always', u'lay', u'the', u'blame', u'on', u'others', u'!', u"'"],
#  [u"'YOU", u"'D", u'better', u'not', u'talk', u'!', u"'"],
#  [u'said', u'Five', u'.'],
#  [u"'I",
#   u'heard',
#   u'the',
#   u'Queen',
#   u'say',
#   u'only',
#   u'yesterday',
#   u'you',
#   u'deserved',
#   u'to',
#   u'be',
#   u'beheaded',
#   u'!',
#   u"'"],
#  [u"'What", u'for', u'?', u"'"],
#  [u'said', u'the', u'one', u'who', u'had', u'spoken', u'first', u'.'],
#  [u"'That",
#   u"'s",
#   u'none',
#   u'of',
#   u'YOUR',
#   u'business',
#   u',',
#   u'Two',
#   u'!',
#   u"'"],
#  [u'said', u'Seven', u'.'],
#  [u"'Yes", u',', u'it', u'IS', u'his', u'business', u'!', u"'"],
#  [u'said',
#   u'Five',
#   u',',
#   u"'and",
#   u'I',
#   u"'ll",
#   u'tell',
#   u'him',
#   u'--',
#   u'it',
#   u'was',
#   u'for',
#   u'bringing',
#   u'the',
#   u'cook',
#   u'tulip-roots',
#   u'instead',
#   u'of',
#   u'onions',
#   u'.',
#   u"'"],
#  [u'Seven',
#   u'flung',
#   u'down',
#   u'his',
#   u'brush',
#   u',',
#   u'and',
#   u'had',
#   u'just',
#   u'begun',
#   u"'Well",
#   u',',
#   u'of',
#   u'all',
#   u'the',
#   u'unjust',
#   u'things',
#   u'--',
#   u"'",
#   u'when',
#   u'his',
#   u'eye',
#   u'chanced',
#   u'to',
#   u'fall',
#   u'upon',
#   u'Alice',
#   u',',
#   u'as',
#   u'she',
#   u'stood',
#   u'watching',
#   u'them',
#   u',',
#   u'and',
#   u'he',
#   u'checked',
#   u'himself',
#   u'suddenly',
#   u':',
#   u'the',
#   u'others',
#   u'looked',
#   u'round',
#   u'also',
#   u',',
#   u'and',
#   u'all',
#   u'of',
#   u'them',
#   u'bowed',
#   u'low',
#   u'.'],
#  [u"'Would",
#   u'you',
#   u'tell',
#   u'me',
#   u',',
#   u"'",
#   u'said',
#   u'Alice',
#   u',',
#   u'a',
#   u'little',
#   u'timidly',
#   u',',
#   u"'why",
#   u'you',
#   u'are',
#   u'painting',
#   u'those',
#   u'roses',
#   u'?',
#   u"'"],
#  [u'Five',
#   u'and',
#   u'Seven',
#   u'said',
#   u'nothing',
#   u',',
#   u'but',
#   u'looked',
#   u'at',
#   u'Two',
#   u'.'],
#  [u'Two',
#   u'began',
#   u'in',
#   u'a',
#   u'low',
#   u'voice',
#   u',',
#   u"'Why",
#   u'the',
#   u'fact',
#   u'is',
#   u',',
#   u'you',
#   u'see',
#   u',',
#   u'Miss',
#   u',',
#   u'this',
#   u'here',
#   u'ought',
#   u'to',
#   u'have',
#   u'been',
#   u'a',
#   u'RED',
#   u'rose-tree',
#   u',',
#   u'and',
#   u'we',
#   u'put',
#   u'a',
#   u'white',
#   u'one',
#   u'in',
#   u'by',
#   u'mistake',
#   u';',
#   u'and',
#   u'if',
#   u'the',
#   u'Queen',
#   u'was',
#   u'to',
#   u'find',
#   u'it',
#   u'out',
#   u',',
#   u'we',
#   u'should',
#   u'all',
#   u'have',
#   u'our',
#   u'heads',
#   u'cut',
#   u'off',
#   u',',
#   u'you',
#   u'know',
#   u'.'],
#  [u'So',
#   u'you',
#   u'see',
#   u',',
#   u'Miss',
#   u',',
#   u'we',
#   u"'re",
#   u'doing',
#   u'our',
#   u'best',
#   u',',
#   u'afore',
#   u'she',
#   u'comes',
#   u',',
#   u'to',
#   u'--',
#   u"'",
#   u'At',
#   u'this',
#   u'moment',
#   u'Five',
#   u',',
#   u'who',
#   u'had',
#   u'been',
#   u'anxiously',
#   u'looking',
#   u'across',
#   u'the',
#   u'garden',
#   u',',
#   u'called',
#   u'out',
#   u"'The",
#   u'Queen',
#   u'!'],
#  [u'The', u'Queen', u'!', u"'"],
#  [u'and',
#   u'the',
#   u'three',
#   u'gardeners',
#   u'instantly',
#   u'threw',
#   u'themselves',
#   u'flat',
#   u'upon',
#   u'their',
#   u'faces',
#   u'.'],
#  [u'There',
#   u'was',
#   u'a',
#   u'sound',
#   u'of',
#   u'many',
#   u'footsteps',
#   u',',
#   u'and',
#   u'Alice',
#   u'looked',
#   u'round',
#   u',',
#   u'eager',
#   u'to',
#   u'see',
#   u'the',
#   u'Queen',
#   u'.'],
#  [u'First',
#   u'came',
#   u'ten',
#   u'soldiers',
#   u'carrying',
#   u'clubs',
#   u';',
#   u'these',
#   u'were',
#   u'all',
#   u'shaped',
#   u'like',
#   u'the',
#   u'three',
#   u'gardeners',
#   u',',
#   u'oblong',
#   u'and',
#   u'flat',
#   u',',
#   u'with',
#   u'their',
#   u'hands',
#   u'and',
#   u'feet',
#   u'at',
#   u'the',
#   u'corners',
#   u':',
#   u'next',
#   u'the',
#   u'ten',
#   u'courtiers',
#   u';',
#   u'these',
#   u'were',
#   u'ornamented',
#   u'all',
#   u'over',
#   u'with',
#   u'diamonds',
#   u',',
#   u'and',
#   u'walked',
#   u'two',
#   u'and',
#   u'two',
#   u',',
#   u'as',
#   u'the',
#   u'soldiers',
#   u'did',
#   u'.'],
#  [u'After',
#   u'these',
#   u'came',
#   u'the',
#   u'royal',
#   u'children',
#   u';',
#   u'there',
#   u'were',
#   u'ten',
#   u'of',
#   u'them',
#   u',',
#   u'and',
#   u'the',
#   u'little',
#   u'dears',
#   u'came',
#   u'jumping',
#   u'merrily',
#   u'along',
#   u'hand',
#   u'in',
#   u'hand',
#   u',',
#   u'in',
#   u'couples',
#   u':',
#   u'they',
#   u'were',
#   u'all',
#   u'ornamented',
#   u'with',
#   u'hearts',
#   u'.'],
#  [u'Next',
#   u'came',
#   u'the',
#   u'guests',
#   u',',
#   u'mostly',
#   u'Kings',
#   u'and',
#   u'Queens',
#   u',',
#   u'and',
#   u'among',
#   u'them',
#   u'Alice',
#   u'recognised',
#   u'the',
#   u'White',
#   u'Rabbit',
#   u':',
#   u'it',
#   u'was',
#   u'talking',
#   u'in',
#   u'a',
#   u'hurried',
#   u'nervous',
#   u'manner',
#   u',',
#   u'smiling',
#   u'at',
#   u'everything',
#   u'that',
#   u'was',
#   u'said',
#   u',',
#   u'and',
#   u'went',
#   u'by',
#   u'without',
#   u'noticing',
#   u'her',
#   u'.'],
#  [u'Then',
#   u'followed',
#   u'the',
#   u'Knave',
#   u'of',
#   u'Hearts',
#   u',',
#   u'carrying',
#   u'the',
#   u"King's",
#   u'crown',
#   u'on',
#   u'a',
#   u'crimson',
#   u'velvet',
#   u'cushion',
#   u';',
#   u'and',
#   u',',
#   u'last',
#   u'of',
#   u'all',
#   u'this',
#   u'grand',
#   u'procession',
#   u',',
#   u'came',
#   u'THE',
#   u'KING',
#   u'AND',
#   u'QUEEN',
#   u'OF',
#   u'HEARTS',
#   u'.'],
#  [u'Alice',
#   u'was',
#   u'rather',
#   u'doubtful',
#   u'whether',
#   u'she',
#   u'ought',
#   u'not',
#   u'to',
#   u'lie',
#   u'down',
#   u'on',
#   u'her',
#   u'face',
#   u'like',
#   u'the',
#   u'three',
#   u'gardeners',
#   u',',
#   u'but',
#   u'she',
#   u'could',
#   u'not',
#   u'remember',
#   u'ever',
#   u'having',
#   u'heard',
#   u'of',
#   u'such',
#   u'a',
#   u'rule',
#   u'at',
#   u'processions',
#   u';',
#   u"'and",
#   u'besides',
#   u',',
#   u'what',
#   u'would',
#   u'be',
#   u'the',
#   u'use',
#   u'of',
#   u'a',
#   u'procession',
#   u',',
#   u"'",
#   u'thought',
#   u'she',
#   u',',
#   u"'if",
#   u'people',
#   u'had',
#   u'all',
#   u'to',
#   u'lie',
#   u'down',
#   u'upon',
#   u'their',
#   u'faces',
#   u',',
#   u'so',
#   u'that',
#   u'they',
#   u'could',
#   u"n't",
#   u'see',
#   u'it',
#   u'?',
#   u"'"],
#  [u'So',
#   u'she',
#   u'stood',
#   u'still',
#   u'where',
#   u'she',
#   u'was',
#   u',',
#   u'and',
#   u'waited',
#   u'.'],
#  [u'When',
#   u'the',
#   u'procession',
#   u'came',
#   u'opposite',
#   u'to',
#   u'Alice',
#   u',',
#   u'they',
#   u'all',
#   u'stopped',
#   u'and',
#   u'looked',
#   u'at',
#   u'her',
#   u',',
#   u'and',
#   u'the',
#   u'Queen',
#   u'said',
#   u'severely',
#   u"'Who",
#   u'is',
#   u'this',
#   u'?',
#   u"'"],
#  [u'She',
#   u'said',
#   u'it',
#   u'to',
#   u'the',
#   u'Knave',
#   u'of',
#   u'Hearts',
#   u',',
#   u'who',
#   u'only',
#   u'bowed',
#   u'and',
#   u'smiled',
#   u'in',
#   u'reply',
#   u'.'],
#  [u"'Idiot", u'!', u"'"],
#  [u'said',
#   u'the',
#   u'Queen',
#   u',',
#   u'tossing',
#   u'her',
#   u'head',
#   u'impatiently',
#   u';',
#   u'and',
#   u',',
#   u'turning',
#   u'to',
#   u'Alice',
#   u',',
#   u'she',
#   u'went',
#   u'on',
#   u',',
#   u"'What",
#   u"'s",
#   u'your',
#   u'name',
#   u',',
#   u'child',
#   u'?',
#   u"'"],
#  [u"'My",
#   u'name',
#   u'is',
#   u'Alice',
#   u',',
#   u'so',
#   u'please',
#   u'your',
#   u'Majesty',
#   u',',
#   u"'",
#   u'said',
#   u'Alice',
#   u'very',
#   u'politely',
#   u';',
#   u'but',
#   u'she',
#   u'added',
#   u',',
#   u'to',
#   u'herself',
#   u',',
#   u"'Why",
#   u',',
#   u'they',
#   u"'re",
#   u'only',
#   u'a',
#   u'pack',
#   u'of',
#   u'cards',
#   u',',
#   u'after',
#   u'all',
#   u'.'],
#  [u'I', u'need', u"n't", u'be', u'afraid', u'of', u'them', u'!', u"'"],
#  [u"'And", u'who', u'are', u'THESE', u'?', u"'"],
#  [u'said',
#   u'the',
#   u'Queen',
#   u',',
#   u'pointing',
#   u'to',
#   u'the',
#   u'three',
#   u'gardeners',
#   u'who',
#   u'were',
#   u'lying',
#   u'round',
#   u'the',
#   u'rosetree',
#   u';',
#   u'for',
#   u',',
#   u'you',
#   u'see',
#   u',',
#   u'as',
#   u'they',
#   u'were',
#   u'lying',
#   u'on',
#   u'their',
#   u'faces',
#   u',',
#   u'and',
#   u'the',
#   u'pattern',
#   u'on',
#   u'their',
#   u'backs',
#   u'was',
#   u'the',
#   u'same',
#   u'as',
#   u'the',
#   u'rest',
#   u'of',
#   u'the',
#   u'pack',
#   u',',
#   u'she',
#   u'could',
#   u'not',
#   u'tell',
#   u'whether',
#   u'they',
#   u'were',
#   u'gardeners',
#   u',',
#   u'or',
#   u'soldiers',
#   u',',
#   u'or',
#   u'courtiers',
#   u',',
#   u'or',
#   u'three',
#   u'of',
#   u'her',
#   u'own',
#   u'children',
#   u'.'],
#  [u"'How", u'should', u'I', u'know', u'?', u"'"],
#  [u'said',
#   u'Alice',
#   u',',
#   u'surprised',
#   u'at',
#   u'her',
#   u'own',
#   u'courage',
#   u'.'],
#  [u"'It", u"'s", u'no', u'business', u'of', u'MINE', u'.', u"'"],
#  [u'The',
#   u'Queen',
#   u'turned',
#   u'crimson',
#   u'with',
#   u'fury',
#   u',',
#   u'and',
#   u',',
#   u'after',
#   u'glaring',
#   u'at',
#   u'her',
#   u'for',
#   u'a',
#   u'moment',
#   u'like',
#   u'a',
#   u'wild',
#   u'beast',
#   u',',
#   u'screamed',
#   u"'Off",
#   u'with',
#   u'her',
#   u'head',
#   u'!'],
#  [u'Off', u'--', u"'", u"'Nonsense", u'!', u"'"],
#  [u'said',
#   u'Alice',
#   u',',
#   u'very',
#   u'loudly',
#   u'and',
#   u'decidedly',
#   u',',
#   u'and',
#   u'the',
#   u'Queen',
#   u'was',
#   u'silent',
#   u'.'],
#  [u'The',
#   u'King',
#   u'laid',
#   u'his',
#   u'hand',
#   u'upon',
#   u'her',
#   u'arm',
#   u',',
#   u'and',
#   u'timidly',
#   u'said',
#   u"'Consider",
#   u',',
#   u'my',
#   u'dear',
#   u':',
#   u'she',
#   u'is',
#   u'only',
#   u'a',
#   u'child',
#   u'!',
#   u"'"],
#  [u'The',
#   u'Queen',
#   u'turned',
#   u'angrily',
#   u'away',
#   u'from',
#   u'him',
#   u',',
#   u'and',
#   u'said',
#   u'to',
#   u'the',
#   u'Knave',
#   u"'Turn",
#   u'them',
#   u'over',
#   u'!',
#   u"'"],
#  [u'The',
#   u'Knave',
#   u'did',
#   u'so',
#   u',',
#   u'very',
#   u'carefully',
#   u',',
#   u'with',
#   u'one',
#   u'foot',
#   u'.'],
#  [u"'Get", u'up', u'!', u"'"],
#  [u'said',
#   u'the',
#   u'Queen',
#   u',',
#   u'in',
#   u'a',
#   u'shrill',
#   u',',
#   u'loud',
#   u'voice',
#   u',',
#   u'and',
#   u'the',
#   u'three',
#   u'gardeners',
#   u'instantly',
#   u'jumped',
#   u'up',
#   u',',
#   u'and',
#   u'began',
#   u'bowing',
#   u'to',
#   u'the',
#   u'King',
#   u',',
#   u'the',
#   u'Queen',
#   u',',
#   u'the',
#   u'royal',
#   u'children',
#   u',',
#   u'and',
#   u'everybody',
#   u'else',
#   u'.'],
#  [u"'Leave", u'off', u'that', u'!', u"'"],
#  [u'screamed', u'the', u'Queen', u'.'],
#  [u"'You", u'make', u'me', u'giddy', u'.', u"'"],
#  [u'And',
#   u'then',
#   u',',
#   u'turning',
#   u'to',
#   u'the',
#   u'rose-tree',
#   u',',
#   u'she',
#   u'went',
#   u'on',
#   u',',
#   u"'What",
#   u'HAVE',
#   u'you',
#   u'been',
#   u'doing',
#   u'here',
#   u'?',
#   u"'"],
#  [u"'May",
#   u'it',
#   u'please',
#   u'your',
#   u'Majesty',
#   u',',
#   u"'",
#   u'said',
#   u'Two',
#   u',',
#   u'in',
#   u'a',
#   u'very',
#   u'humble',
#   u'tone',
#   u',',
#   u'going',
#   u'down',
#   u'on',
#   u'one',
#   u'knee',
#   u'as',
#   u'he',
#   u'spoke',
#   u',',
#   u"'we",
#   u'were',
#   u'trying',
#   u'--',
#   u"'",
#   u"'I",
#   u'see',
#   u'!',
#   u"'"],
#  [u'said',
#   u'the',
#   u'Queen',
#   u',',
#   u'who',
#   u'had',
#   u'meanwhile',
#   u'been',
#   u'examining',
#   u'the',
#   u'roses',
#   u'.'],
#  [u"'Off", u'with', u'their', u'heads', u'!', u"'"],
#  [u'and',
#   u'the',
#   u'procession',
#   u'moved',
#   u'on',
#   u',',
#   u'three',
#   u'of',
#   u'the',
#   u'soldiers',
#   u'remaining',
#   u'behind',
#   u'to',
#   u'execute',
#   u'the',
#   u'unfortunate',
#   u'gardeners',
#   u',',
#   u'who',
#   u'ran',
#   u'to',
#   u'Alice',
#   u'for',
#   u'protection',
#   u'.'],
#  [u"'You", u'sha', u"n't", u'be', u'beheaded', u'!', u"'"],
#  [u'said',
#   u'Alice',
#   u',',
#   u'and',
#   u'she',
#   u'put',
#   u'them',
#   u'into',
#   u'a',
#   u'large',
#   u'flower-pot',
#   u'that',
#   u'stood',
#   u'near',
#   u'.'],
#  [u'The',
#   u'three',
#   u'soldiers',
#   u'wandered',
#   u'about',
#   u'for',
#   u'a',
#   u'minute',
#   u'or',
#   u'two',
#   u',',
#   u'looking',
#   u'for',
#   u'them',
#   u',',
#   u'and',
#   u'then',
#   u'quietly',
#   u'marched',
#   u'off',
#   u'after',
#   u'the',
#   u'others',
#   u'.'],
#  [u"'Are", u'their', u'heads', u'off', u'?', u"'"],
#  [u'shouted', u'the', u'Queen', u'.'],
#  [u"'Their",
#   u'heads',
#   u'are',
#   u'gone',
#   u',',
#   u'if',
#   u'it',
#   u'please',
#   u'your',
#   u'Majesty',
#   u'!',
#   u"'"],
#  [u'the', u'soldiers', u'shouted', u'in', u'reply', u'.'],
#  [u"'That", u"'s", u'right', u'!', u"'"],
#  [u'shouted', u'the', u'Queen', u'.'],
#  [u"'Can", u'you', u'play', u'croquet', u'?', u"'"],
#  [u'The',
#   u'soldiers',
#   u'were',
#   u'silent',
#   u',',
#   u'and',
#   u'looked',
#   u'at',
#   u'Alice',
#   u',',
#   u'as',
#   u'the',
#   u'question',
#   u'was',
#   u'evidently',
#   u'meant',
#   u'for',
#   u'her',
#   u'.'],
#  [u"'Yes", u'!', u"'"],
#  [u'shouted', u'Alice', u'.'],
#  [u"'Come", u'on', u',', u'then', u'!', u"'"],
#  [u'roared',
#   u'the',
#   u'Queen',
#   u',',
#   u'and',
#   u'Alice',
#   u'joined',
#   u'the',
#   u'procession',
#   u',',
#   u'wondering',
#   u'very',
#   u'much',
#   u'what',
#   u'would',
#   u'happen',
#   u'next',
#   u'.'],
#  [u"'It",
#   u"'s",
#   u'--',
#   u'it',
#   u"'s",
#   u'a',
#   u'very',
#   u'fine',
#   u'day',
#   u'!',
#   u"'"],
#  [u'said', u'a', u'timid', u'voice', u'at', u'her', u'side', u'.'],
#  [u'She',
#   u'was',
#   u'walking',
#   u'by',
#   u'the',
#   u'White',
#   u'Rabbit',
#   u',',
#   u'who',
#   u'was',
#   u'peeping',
#   u'anxiously',
#   u'into',
#   u'her',
#   u'face',
#   u'.'],
#  [u"'Very",
#   u',',
#   u"'",
#   u'said',
#   u'Alice',
#   u':',
#   u"'",
#   u'--',
#   u'where',
#   u"'s",
#   u'the',
#   u'Duchess',
#   u'?',
#   u"'"],
#  [u"'Hush", u'!'],
#  [u'Hush', u'!', u"'"],
#  [u'said',
#   u'the',
#   u'Rabbit',
#   u'in',
#   u'a',
#   u'low',
#   u',',
#   u'hurried',
#   u'tone',
#   u'.'],
#  ...]

# %%
# Count the number of words in each sentence
emma_word_counts = []
for sent in emma_sentences:
    words = [x for x in nltk.word_tokenize(sent) if x not in ['.','?']]
    emma_word_counts.append(len(words))
print "Word counts per sentence", emma_word_counts
print "Word count overall", sum(emma_word_counts)
# Out:
# Word counts per sentence [57, 37, 43, 30, 9, 73, 45, 23, 22, 10, 19, 30, 26, 10, 51, 13, 56, 47, 74, 74, 13, 11, 80, 71, 39, 7, 5, 34, 33, 4, 31, 124, 50, 14, 15, 52, 19, 18, 25, 14, 11, 5, 8, 10, 11, 4, 32, 13, 8, 10, 26, 11, 6, 6, 17, 10, 47, 49, 32, 18, 12, 39, 16, 38, 35, 29, 13, 29, 32, 11, 6, 20, 11, 8, 5, 4, 6, 3, 15, 13, 9, 11, 34, 5, 4, 3, 4, 6, 21, 40, 16, 3, 26, 21, 12, 5, 16, 5, 3, 4, 21, 10, 75, 22, 18, 10, 36, 24, 26, 13, 31, 11, 17, 87, 15, 29, 45, 7, 8, 22, 8, 21, 9, 19, 5, 63, 3, 7, 25, 17, 58, 33, 16, 4, 24, 10, 71, 4, 5, 15, 36, 7, 28, 24, 32, 11, 28, 19, 24, 28, 11, 4, 17, 71, 22, 29, 23, 7, 14, 37, 28, 16, 32, 58, 68, 59, 12, 56, 39, 43, 60, 13, 66, 57, 7, 26, 9, 40, 57, 71, 36, 68, 55, 16, 7, 46, 38, 21, 36, 14, 26, 31, 32, 21, 18, 10, 6, 20, 9, 51, 52, 88, 50, 101, 24, 8, 26, 40, 20, 47, 17, 61, 45, 33, 12, 61, 38, 30, 62, 64, 59, 15, 26, 34, 21, 41, 8, 35, 17, 13, 52, 28, 22, 113, 59, 17, 73, 49, 49, 78, 20, 8, 30, 10, 37, 20, 58, 89, 4, 24, 10, 21, 80, 34, 26, 79, 80, 11, 63, 55, 8, 9, 36, 18, 4, 9, 6, 12, 10, 10, 31, 11, 62, 13, 37, 16, 10, 43, 41, 24, 36, 43, 24, 11, 6, 6, 14, 16, 12, 14, 22, 18, 26, 4, 21, 46, 42, 157, 27, 115, 33, 34, 37, 17, 6, 6, 11, 29, 8, 9, 48, 7, 7, 5, 3, 2, 8, 31, 32, 20, 5, 34, 26, 25, 10, 15, 27, 13, 2, 3, 7, 17, 10, 6, 23, 7, 22, 22, 18, 28, 33, 4, 3, 24, 13, 18, 9, 30, 3, 6, 11, 25, 34, 5, 12, 23, 22, 69, 8, 5, 26, 65, 15, 45, 11, 29, 34, 82, 4, 1, 24, 29, 34, 25, 17, 40, 17, 21, 35, 48, 21, 12, 44, 15, 17, 9, 8, 13, 22, 9, 11, 6, 8, 23, 32, 15, 24, 38, 16, 43, 8, 4, 34, 9, 14, 6, 11, 20, 17, 13, 9, 7, 16, 6, 10, 8, 9, 9, 35, 10, 20, 13, 8, 24, 5, 6, 24, 29, 7, 30, 34, 10, 26, 4, 10, 39, 52, 21, 11, 11, 37, 12, 14, 38, 20, 29, 13, 38, 14, 37, 63, 56, 20, 65, 40, 5, 12, 14, 5, 25, 10, 17, 15, 2, 30, 23, 31, 16, 54, 8, 14, 26, 4, 7, 15, 48, 41, 13, 21, 38, 39, 31, 29, 10, 21, 11, 18, 13, 16, 45, 14, 8, 20, 17, 67, 3, 17, 2, 32, 6, 17, 10, 13, 5, 4, 11, 36, 14, 13, 17, 5, 20, 18, 16, 20, 41, 30, 8, 3, 13, 14, 3, 3, 16, 28, 8, 15, 10, 2, 22, 20, 29, 4, 7, 15, 7, 22, 21, 27, 20, 13, 17, 42, 11, 20, 32, 10, 80, 55, 29, 18, 27, 17, 15, 7, 8, 19, 13, 9, 15, 19, 16, 19, 22, 17, 61, 23, 25, 45, 13, 95, 23, 8, 26, 29, 23, 32, 28, 14, 6, 46, 10, 7, 7, 10, 10, 8, 19, 25, 11, 12, 25, 6, 25, 7, 8, 41, 13, 14, 12, 19, 19, 6, 6, 28, 19, 5, 9, 7, 23, 37, 24, 5, 21, 15, 8, 9, 13, 3, 9, 6, 12, 31, 41, 5, 18, 34, 46, 41, 49, 5, 14, 12, 10, 38, 12, 4, 7, 7, 20, 37, 48, 63, 12, 27, 8, 4, 7, 8, 61, 91, 15, 60, 33, 31, 2, 27, 15, 11, 34, 36, 18, 35, 10, 20, 19, 6, 8, 72, 15, 23, 108, 29, 4, 14, 32, 22, 52, 13, 6, 2, 7, 11, 9, 12, 14, 22, 11, 30, 7, 14, 5, 10, 5, 9, 13, 39, 19, 5, 15, 49, 10, 18, 8, 7, 17, 72, 15, 7, 19, 8, 19, 49, 47, 7, 11, 15, 21, 46, 11, 10, 23, 59, 7, 100, 6, 11, 19, 52, 24, 9, 7, 2, 3, 6, 7, 6, 10, 44, 20, 36, 6, 39, 58, 38, 6, 8, 13, 16, 22, 6, 3, 9, 3, 8, 10, 2, 5, 8, 6, 9, 10, 15, 39, 16, 16, 6, 8, 8, 16, 19, 15, 3, 22, 19, 7, 14, 10, 8, 12, 20, 66, 16, 18, 20, 11, 3, 85, 20, 10, 30, 19, 19, 9, 39, 12, 53, 7, 17, 28, 9, 21, 33, 12, 9, 16, 9, 5, 17, 38, 21, 10, 7, 13, 14, 27, 13, 10, 118, 55, 12, 5, 29, 14, 55, 3, 3, 17, 7, 5, 5, 54, 98, 13, 8, 37, 18, 18, 15, 22, 22, 25, 19, 16, 9, 16, 15, 20, 17, 25, 12, 24, 11, 19, 51, 14, 13, 26, 13, 31, 17, 9, 8, 51, 40, 69, 33, 43, 18, 8, 8, 13, 9, 7, 19, 9, 47, 25, 13, 27, 20, 35, 21, 21, 25, 16, 3, 30, 9, 13, 4, 10, 12, 9, 12, 13, 44, 3, 2, 4, 13, 4, 14, 6, 15, 20, 36, 14, 11, 22, 12, 3, 16, 27, 62, 10, 11, 15, 23, 12, 9, 24, 14, 37, 6, 66, 37, 22, 9, 22, 15, 47, 7, 3, 26, 16, 3, 8, 7, 5, 14, 12, 12, 6, 7, 26, 34, 12, 11, 7, 41, 9, 22, 23, 10, 13, 20, 27, 14, 24, 33, 52, 38, 7, 25, 24, 19, 2, 29, 24, 13, 7, 9, 8, 52, 19, 27, 100, 44, 39, 15, 5, 25, 12, 7, 10, 10, 22, 4, 16, 16, 7, 29, 22, 14, 30, 140, 45, 28, 25, 12, 6, 3, 10, 26, 2, 5, 16, 32, 12, 41, 39, 12, 14, 21, 16, 46, 99, 22, 9, 32, 54, 28, 17, 45, 6, 22, 12, 2, 31, 25, 72, 27, 3, 11, 26, 66, 4, 12, 27, 13, 10, 17, 49, 30, 15, 36, 6, 11, 9, 16, 5, 46, 24, 28, 12, 24, 12, 2 ...
# Word count overall 184697

# %%
alice_word_counts = []
for sent in alice_sentences:
    words = [x for x in nltk.word_tokenize(sent) if x not in ['.','?']]
    alice_word_counts.append(len(words))
print "Word counts per sentence", alice_word_counts
print "Word count overall", sum(alice_word_counts)
# Out:
# Word counts per sentence [13, 67, 60, 32, 3, 6, 119, 22, 41, 36, 57, 59, 3, 21, 10, 22, 7, 5, 9, 12, 3, 11, 96, 23, 4, 11, 18, 51, 11, 20, 8, 13, 18, 5, 13, 13, 6, 11, 4, 9, 29, 9, 27, 5, 8, 23, 47, 5, 2, 17, 49, 45, 44, 50, 48, 25, 50, 36, 61, 13, 13, 27, 94, 25, 129, 59, 26, 12, 39, 52, 9, 31, 27, 87, 12, 18, 70, 19, 16, 41, 58, 14, 2, 79, 13, 22, 9, 35, 5, 26, 22, 9, 50, 16, 12, 26, 8, 6, 12, 10, 40, 3, 43, 35, 9, 33, 25, 46, 6, 2, 13, 67, 33, 6, 8, 10, 14, 10, 19, 9, 31, 53, 7, 22, 13, 26, 10, 13, 29, 8, 79, 24, 61, 7, 21, 20, 12, 41, 20, 12, 34, 7, 2, 7, 70, 7, 29, 16, 46, 13, 16, 9, 29, 64, 24, 10, 14, 19, 11, 7, 65, 18, 28, 16, 13, 55, 25, 25, 23, 10, 9, 19, 8, 14, 9, 5, 10, 9, 19, 26, 73, 23, 14, 4, 14, 10, 13, 10, 6, 13, 12, 29, 17, 60, 13, 17, 26, 10, 24, 67, 44, 13, 2, 43, 48, 67, 31, 9, 18, 27, 3, 12, 7, 8, 36, 16, 7, 6, 14, 4, 4, 10, 3, 35, 3, 20, 29, 10, 32, 7, 18, 9, 23, 36, 3, 27, 19, 31, 5, 35, 18, 27, 40, 41, 30, 17, 51, 16, 8, 6, 38, 3, 45, 7, 15, 9, 9, 7, 8, 9, 41, 49, 41, 26, 41, 10, 10, 30, 75, 27, 30, 6, 6, 6, 22, 5, 8, 4, 15, 11, 18, 9, 7, 3, 11, 6, 9, 19, 14, 9, 31, 14, 7, 8, 12, 14, 8, 8, 14, 3, 19, 15, 13, 16, 9, 37, 19, 11, 14, 9, 8, 22, 6, 12, 16, 43, 2, 43, 3, 5, 6, 13, 10, 67, 34, 16, 5, 28, 15, 13, 20, 27, 5, 37, 19, 12, 17, 12, 8, 14, 29, 76, 24, 31, 26, 41, 47, 2, 8, 53, 42, 6, 53, 29, 30, 10, 27, 14, 39, 17, 26, 9, 7, 3, 7, 19, 39, 3, 4, 3, 8, 10, 46, 38, 17, 38, 46, 12, 2, 4, 16, 8, 7, 4, 2, 9, 7, 13, 11, 7, 6, 6, 9, 17, 20, 39, 10, 17, 14, 10, 2, 8, 15, 14, 61, 34, 14, 23, 4, 33, 23, 12, 2, 13, 4, 10, 32, 67, 15, 16, 29, 4, 7, 68, 8, 3, 8, 19, 8, 21, 13, 28, 5, 36, 27, 5, 29, 42, 18, 32, 28, 31, 45, 9, 61, 24, 5, 52, 201, 43, 11, 45, 3, 13, 10, 20, 7, 33, 54, 56, 41, 4, 3, 9, 45, 7, 4, 4, 24, 9, 41, 8, 56, 8, 26, 3, 4, 4, 11, 40, 2, 3, 35, 4, 5, 8, 12, 8, 4, 12, 6, 27, 39, 35, 6, 3, 23, 7, 15, 51, 41, 40, 43, 43, 43, 41, 22, 11, 12, 10, 22, 21, 7, 8, 2, 27, 9, 25, 5, 3, 33, 9, 19, 9, 7, 18, 26, 11, 23, 39, 4, 6, 4, 27, 37, 28, 6, 36, 44, 37, 30, 64, 8, 2, 7, 16, 25, 45, 71, 3, 3, 7, 3, 5, 7, 33, 15, 35, 7, 23, 29, 15, 20, 50, 5, 12, 2, 11, 4, 3, 11, 28, 6, 10, 22, 4, 12, 16, 33, 31, 57, 42, 8, 16, 34, 55, 41, 10, 7, 17, 33, 23, 31, 29, 2, 75, 37, 23, 38, 9, 23, 9, 12, 52, 10, 19, 34, 38, 15, 26, 22, 20, 26, 16, 4, 57, 22, 7, 8, 8, 3, 9, 15, 17, 9, 16, 18, 7, 2, 12, 21, 8, 56, 11, 12, 10, 23, 31, 38, 15, 3, 66, 15, 24, 17, 26, 54, 36, 10, 12, 25, 28, 27, 14, 30, 50, 22, 62, 1, 14, 2, 3, 64, 1, 2, 2, 3, 2, 12, 14, 21, 17, 35, 47, 57, 37, 25, 20, 21, 46, 25, 6, 28, 4, 27, 25, 18, 35, 21, 32, 59, 8, 30, 32, 16, 16, 17, 10, 15, 14, 21, 14, 8, 34, 10, 14, 18, 3, 4, 8, 2, 17, 25, 14, 4, 7, 29, 16, 5, 11, 10, 9, 19, 13, 17, 16, 8, 3, 7, 22, 13, 39, 46, 23, 8, 3, 27, 41, 2, 21, 14, 42, 59, 13, 2, 63, 24, 23, 4, 8, 7, 18, 13, 15, 10, 10, 16, 19, 24, 9, 19, 21, 25, 10, 2, 19, 15, 4, 6, 14, 28, 8, 3, 28, 35, 43, 45, 9, 8, 37, 11, 5, 3, 11, 8, 12, 28, 51, 10, 6, 2, 17, 4, 3, 10, 26, 12, 4, 20, 16, 21, 30, 7, 8, 16, 11, 8, 3, 26, 22, 4, 11, 7, 8, 11, 21, 2, 9, 5, 22, 38, 8, 18, 26, 25, 7, 2, 6, 4, 2, 55, 9, 7, 10, 31, 42, 31, 7, 5, 2, 23, 7, 8, 12, 2, 31, 9, 2, 15, 11, 4, 13, 6, 10, 18, 6, 3, 6, 9, 6, 24, 6, 4, 6, 2, 22, 47, 15, 16, 71, 15, 20, 23, 8, 7, 4, 32, 11, 22, 7, 16, 3, 22, 7, 10, 8, 5, 4, 7, 22, 7, 13, 19, 34, 37, 21, 8, 31, 21, 15, 20, 46, 2, 3, 4, 3, 89, 30, 75, 11, 10, 15, 20, 6, 2, 5, 11, 4, 17, 33, 58, 2, 35, 37, 11, 20, 14, 8, 7, 2, 14, 3, 7, 10, 2, 8, 20, 52, 20, 10, 58, 38, 4, 11, 18, 52, 34, 41, 33, 69, 10, 25, 16, 3, 26, 35, 9, 5, 66, 5, 8, 7, 27, 6, 13, 24, 18, 11, 4, 36, 5, 3, 5, 19, 34, 11, 6, 24, 7, 14, 23, 5, 3, 12, 5, 5, 3, 5, 18, 3, 2, 6, 17, 11, 7, 15, 13, 2, 3, 9, 34, 3, 2, 10, 3, 20, 7, 11, 7, 5, 7, 6, 20, 40, 53, 183, 49, 7, 5, 45, 23, 78, 6, 16, 10, 25, 34, 21, 119, 7, 7, 49, 6, 6, 19, 21, 27, 9, 20, 7, 11, 15, 30, 10, 14, 6, 7, 17, 32, 49, 8, 64, 50, 27, 58, 47, 49, 24, 27, 18, 23, 17, 8, 57, 2, 24, 19, 36, 33, 59, 45, 16, 22, 11, 7, 3, 13, 13, 46, 19, 22, 34, 19, 4, 49,  ...
# Word count overall 32133

# %%
# Which novel has more average words per sentence?
# Given their target audience, is this what you would expect?

#emma:
sum(emma_word_counts)/len(emma_sentences)
# Out:
# 24

# %%
#alice:
sum(alice_word_counts)/len(alice_sentences)
# Out:
# 19

# %%
# Create a flat list (i.e. not a list of lists) of words in
# the two novels

#emma is already a list

alice_words = nltk.word_tokenize(nltk.corpus.gutenberg.raw('carroll-alice.txt'))
alice_words
# Out:
# [u'[',
#  u'Alice',
#  u"'s",
#  u'Adventures',
#  u'in',
#  u'Wonderland',
#  u'by',
#  u'Lewis',
#  u'Carroll',
#  u'1865',
#  u']',
#  u'CHAPTER',
#  u'I',
#  u'.',
#  u'Down',
#  u'the',
#  u'Rabbit-Hole',
#  u'Alice',
#  u'was',
#  u'beginning',
#  u'to',
#  u'get',
#  u'very',
#  u'tired',
#  u'of',
#  u'sitting',
#  u'by',
#  u'her',
#  u'sister',
#  u'on',
#  u'the',
#  u'bank',
#  u',',
#  u'and',
#  u'of',
#  u'having',
#  u'nothing',
#  u'to',
#  u'do',
#  u':',
#  u'once',
#  u'or',
#  u'twice',
#  u'she',
#  u'had',
#  u'peeped',
#  u'into',
#  u'the',
#  u'book',
#  u'her',
#  u'sister',
#  u'was',
#  u'reading',
#  u',',
#  u'but',
#  u'it',
#  u'had',
#  u'no',
#  u'pictures',
#  u'or',
#  u'conversations',
#  u'in',
#  u'it',
#  u',',
#  u"'and",
#  u'what',
#  u'is',
#  u'the',
#  u'use',
#  u'of',
#  u'a',
#  u'book',
#  u',',
#  u"'",
#  u'thought',
#  u'Alice',
#  u"'without",
#  u'pictures',
#  u'or',
#  u'conversation',
#  u'?',
#  u"'",
#  u'So',
#  u'she',
#  u'was',
#  u'considering',
#  u'in',
#  u'her',
#  u'own',
#  u'mind',
#  u'(',
#  u'as',
#  u'well',
#  u'as',
#  u'she',
#  u'could',
#  u',',
#  u'for',
#  u'the',
#  u'hot',
#  u'day',
#  u'made',
#  u'her',
#  u'feel',
#  u'very',
#  u'sleepy',
#  u'and',
#  u'stupid',
#  u')',
#  u',',
#  u'whether',
#  u'the',
#  u'pleasure',
#  u'of',
#  u'making',
#  u'a',
#  u'daisy-chain',
#  u'would',
#  u'be',
#  u'worth',
#  u'the',
#  u'trouble',
#  u'of',
#  u'getting',
#  u'up',
#  u'and',
#  u'picking',
#  u'the',
#  u'daisies',
#  u',',
#  u'when',
#  u'suddenly',
#  u'a',
#  u'White',
#  u'Rabbit',
#  u'with',
#  u'pink',
#  u'eyes',
#  u'ran',
#  u'close',
#  u'by',
#  u'her',
#  u'.',
#  u'There',
#  u'was',
#  u'nothing',
#  u'so',
#  u'VERY',
#  u'remarkable',
#  u'in',
#  u'that',
#  u';',
#  u'nor',
#  u'did',
#  u'Alice',
#  u'think',
#  u'it',
#  u'so',
#  u'VERY',
#  u'much',
#  u'out',
#  u'of',
#  u'the',
#  u'way',
#  u'to',
#  u'hear',
#  u'the',
#  u'Rabbit',
#  u'say',
#  u'to',
#  u'itself',
#  u',',
#  u"'Oh",
#  u'dear',
#  u'!',
#  u'Oh',
#  u'dear',
#  u'!',
#  u'I',
#  u'shall',
#  u'be',
#  u'late',
#  u'!',
#  u"'",
#  u'(',
#  u'when',
#  u'she',
#  u'thought',
#  u'it',
#  u'over',
#  u'afterwards',
#  u',',
#  u'it',
#  u'occurred',
#  u'to',
#  u'her',
#  u'that',
#  u'she',
#  u'ought',
#  u'to',
#  u'have',
#  u'wondered',
#  u'at',
#  u'this',
#  u',',
#  u'but',
#  u'at',
#  u'the',
#  u'time',
#  u'it',
#  u'all',
#  u'seemed',
#  u'quite',
#  u'natural',
#  u')',
#  u';',
#  u'but',
#  u'when',
#  u'the',
#  u'Rabbit',
#  u'actually',
#  u'TOOK',
#  u'A',
#  u'WATCH',
#  u'OUT',
#  u'OF',
#  u'ITS',
#  u'WAISTCOAT-POCKET',
#  u',',
#  u'and',
#  u'looked',
#  u'at',
#  u'it',
#  u',',
#  u'and',
#  u'then',
#  u'hurried',
#  u'on',
#  u',',
#  u'Alice',
#  u'started',
#  u'to',
#  u'her',
#  u'feet',
#  u',',
#  u'for',
#  u'it',
#  u'flashed',
#  u'across',
#  u'her',
#  u'mind',
#  u'that',
#  u'she',
#  u'had',
#  u'never',
#  u'before',
#  u'seen',
#  u'a',
#  u'rabbit',
#  u'with',
#  u'either',
#  u'a',
#  u'waistcoat-pocket',
#  u',',
#  u'or',
#  u'a',
#  u'watch',
#  u'to',
#  u'take',
#  u'out',
#  u'of',
#  u'it',
#  u',',
#  u'and',
#  u'burning',
#  u'with',
#  u'curiosity',
#  u',',
#  u'she',
#  u'ran',
#  u'across',
#  u'the',
#  u'field',
#  u'after',
#  u'it',
#  u',',
#  u'and',
#  u'fortunately',
#  u'was',
#  u'just',
#  u'in',
#  u'time',
#  u'to',
#  u'see',
#  u'it',
#  u'pop',
#  u'down',
#  u'a',
#  u'large',
#  u'rabbit-hole',
#  u'under',
#  u'the',
#  u'hedge',
#  u'.',
#  u'In',
#  u'another',
#  u'moment',
#  u'down',
#  u'went',
#  u'Alice',
#  u'after',
#  u'it',
#  u',',
#  u'never',
#  u'once',
#  u'considering',
#  u'how',
#  u'in',
#  u'the',
#  u'world',
#  u'she',
#  u'was',
#  u'to',
#  u'get',
#  u'out',
#  u'again',
#  u'.',
#  u'The',
#  u'rabbit-hole',
#  u'went',
#  u'straight',
#  u'on',
#  u'like',
#  u'a',
#  u'tunnel',
#  u'for',
#  u'some',
#  u'way',
#  u',',
#  u'and',
#  u'then',
#  u'dipped',
#  u'suddenly',
#  u'down',
#  u',',
#  u'so',
#  u'suddenly',
#  u'that',
#  u'Alice',
#  u'had',
#  u'not',
#  u'a',
#  u'moment',
#  u'to',
#  u'think',
#  u'about',
#  u'stopping',
#  u'herself',
#  u'before',
#  u'she',
#  u'found',
#  u'herself',
#  u'falling',
#  u'down',
#  u'a',
#  u'very',
#  u'deep',
#  u'well',
#  u'.',
#  u'Either',
#  u'the',
#  u'well',
#  u'was',
#  u'very',
#  u'deep',
#  u',',
#  u'or',
#  u'she',
#  u'fell',
#  u'very',
#  u'slowly',
#  u',',
#  u'for',
#  u'she',
#  u'had',
#  u'plenty',
#  u'of',
#  u'time',
#  u'as',
#  u'she',
#  u'went',
#  u'down',
#  u'to',
#  u'look',
#  u'about',
#  u'her',
#  u'and',
#  u'to',
#  u'wonder',
#  u'what',
#  u'was',
#  u'going',
#  u'to',
#  u'happen',
#  u'next',
#  u'.',
#  u'First',
#  u',',
#  u'she',
#  u'tried',
#  u'to',
#  u'look',
#  u'down',
#  u'and',
#  u'make',
#  u'out',
#  u'what',
#  u'she',
#  u'was',
#  u'coming',
#  u'to',
#  u',',
#  u'but',
#  u'it',
#  u'was',
#  u'too',
#  u'dark',
#  u'to',
#  u'see',
#  u'anything',
#  u';',
#  u'then',
#  u'she',
#  u'looked',
#  u'at',
#  u'the',
#  u'sides',
#  u'of',
#  u'the',
#  u'well',
#  u',',
#  u'and',
#  u'noticed',
#  u'that',
#  u'they',
#  u'were',
#  u'filled',
#  u'with',
#  u'cupboards',
#  u'and',
#  u'book-shelves',
#  u';',
#  u'here',
#  u'and',
#  u'there',
#  u'she',
#  u'saw',
#  u'maps',
#  u'and',
#  u'pictures',
#  u'hung',
#  u'upon',
#  u'pegs',
#  u'.',
#  u'She',
#  u'took',
#  u'down',
#  u'a',
#  u'jar',
#  u'from',
#  u'one',
#  u'of',
#  u'the',
#  u'shelves',
#  u'as',
#  u'she',
#  u'passed',
#  u';',
#  u'it',
#  u'was',
#  u'labelled',
#  u"'ORANGE",
#  u'MARMALADE',
#  u"'",
#  u',',
#  u'but',
#  u'to',
#  u'her',
#  u'great',
#  u'disappointment',
#  u'it',
#  u'was',
#  u'empty',
#  u':',
#  u'she',
#  u'did',
#  u'not',
#  u'like',
#  u'to',
#  u'drop',
#  u'the',
#  u'jar',
#  u'for',
#  u'fear',
#  u'of',
#  u'killing',
#  u'somebody',
#  u',',
#  u'so',
#  u'managed',
#  u'to',
#  u'put',
#  u'it',
#  u'into',
#  u'one',
#  u'of',
#  u'the',
#  u'cupboards',
#  u'as',
#  u'she',
#  u'fell',
#  u'past',
#  u'it',
#  u'.',
#  u"'Well",
#  u'!',
#  u"'",
#  u'thought',
#  u'Alice',
#  u'to',
#  u'herself',
#  u',',
#  u"'after",
#  u'such',
#  u'a',
#  u'fall',
#  u'as',
#  u'this',
#  u',',
#  u'I',
#  u'shall',
#  u'think',
#  u'nothing',
#  u'of',
#  u'tumbling',
#  u'down',
#  u'stairs',
#  u'!',
#  u'How',
#  u'brave',
#  u'they',
#  u"'ll",
#  u'all',
#  u'think',
#  u'me',
#  u'at',
#  u'home',
#  u'!',
#  u'Why',
#  u',',
#  u'I',
#  u'would',
#  u"n't",
#  u'say',
#  u'anything',
#  u'about',
#  u'it',
#  u',',
#  u'even',
#  u'if',
#  u'I',
#  u'fell',
#  u'off',
#  u'the',
#  u'top',
#  u'of',
#  u'the',
#  u'house',
#  u'!',
#  u"'",
#  u'(',
#  u'Which',
#  u'was',
#  u'very',
#  u'likely',
#  u'true',
#  u'.',
#  u')',
#  u'Down',
#  u',',
#  u'down',
#  u',',
#  u'down',
#  u'.',
#  u'Would',
#  u'the',
#  u'fall',
#  u'NEVER',
#  u'come',
#  u'to',
#  u'an',
#  u'end',
#  u'!',
#  u"'I",
#  u'wonder',
#  u'how',
#  u'many',
#  u'miles',
#  u'I',
#  u"'ve",
#  u'fallen',
#  u'by',
#  u'this',
#  u'time',
#  u'?',
#  u"'",
#  u'she',
#  u'said',
#  u'aloud',
#  u'.',
#  u"'I",
#  u'must',
#  u'be',
#  u'getting',
#  u'somewhere',
#  u'near',
#  u'the',
#  u'centre',
#  u'of',
#  u'the',
#  u'earth',
#  u'.',
#  u'Let',
#  u'me',
#  u'see',
#  u':',
#  u'that',
#  u'would',
#  u'be',
#  u'four',
#  u'thousand',
#  u'miles',
#  u'down',
#  u',',
#  u'I',
#  u'think',
#  u'--',
#  u"'",
#  u'(',
#  u'for',
#  u',',
#  u'you',
#  u'see',
#  u',',
#  u'Alice',
#  u'had',
#  u'learnt',
#  u'several',
#  u'things',
#  u'of',
#  u'this',
#  u'sort',
#  u'in',
#  u'her',
#  u'lessons',
#  u'in',
#  u'the',
#  u'schoolroom',
#  u',',
#  u'and',
#  u'though',
#  u'this',
#  u'was',
#  u'not',
#  u'a',
#  u'VERY',
#  u'good',
#  u'opportunity',
#  u'for',
#  u'showing',
#  u'off',
#  u'her',
#  u'knowledge',
#  u',',
#  u'as',
#  u'there',
#  u'was',
#  u'no',
#  u'one',
#  u'to',
#  u'listen',
#  u'to',
#  u'her',
#  u',',
#  u'still',
#  u'it',
#  u'was',
#  u'good',
#  u'practice',
#  u'to',
#  u'say',
#  u'it',
#  u'over',
#  u')',
#  u"'",
#  u'--',
#  u'yes',
#  u',',
#  u'that',
#  u"'s",
#  u'about',
#  u'the',
#  u'right',
#  u'distance',
#  u'--',
#  u'but',
#  u'then',
#  u'I',
#  u'wonder',
#  u'what',
#  u'Latitude',
#  u'or',
#  u'Longitude',
#  u'I',
#  u"'ve",
#  u'got',
#  u'to',
#  u'?',
#  u"'",
#  u'(',
#  u'Alice',
#  u'had',
#  u'no',
#  u'idea',
#  u'what',
#  u'Latitude',
#  u'was',
#  u',',
#  u'or',
#  u'Longitude',
#  u'either',
#  u',',
#  u'but',
#  u'thought',
#  u'they',
#  u'were',
#  u'nice',
#  u'grand',
#  u'words',
#  u'to',
#  u'say',
#  u'.',
#  u')',
#  u'Presently',
#  u'she',
#  u'began',
#  u'again',
#  u'.',
#  u"'I",
#  u'wonder',
#  u'if',
#  u'I',
#  u'shall',
#  u'fall',
#  u'right',
#  u'THROUGH',
#  u'the',
#  u'earth',
#  u'!',
#  u'How',
#  u'funny',
#  u'it',
#  u"'ll",
#  u'seem',
#  u'to',
#  u'come',
#  u'out',
#  u'among',
#  u'the',
#  u'people',
#  u'that',
#  u'walk',
#  u'with',
#  u'their',
#  u'heads',
#  u'downward',
#  u'!',
#  u'The',
#  u'Antipathies',
#  u',',
#  u'I',
#  u'think',
#  u'--',
#  u"'",
#  u'(',
#  u'she',
#  u'was',
#  u'rather',
#  u'glad',
#  u'there',
#  u'WAS',
#  u'no',
#  u'one',
#  u'listening',
#  u',',
#  u'this',
#  u'time',
#  u',',
#  u'as',
#  u'it',
#  u'did',
#  u"n't",
#  u'sound',
#  u'at',
#  u'all',
#  u'the',
#  u'right',
#  u'word',
#  u')',
#  u"'",
#  u'--',
#  u'but',
#  u'I',
#  u'shall',
#  u'have',
#  u'to',
#  u'ask',
#  u'them',
#  u'what',
#  u'the',
#  u'name',
#  u'of',
#  u'the',
#  u'country',
#  u'is',
#  u',',
#  u'you',
#  u'know',
#  u'.',
#  u'Please',
#  u',',
#  u"Ma'am",
#  u',',
#  u'is',
#  u'this',
#  u'New',
#  u'Zealand',
#  u'or',
#  u'Australia',
#  u'?',
#  u"'",
#  u'(',
#  u'and',
#  u'she',
#  u'tried',
#  u'to',
#  u'curtsey',
#  u'as',
#  u'she',
#  u'spoke',
#  u'--',
#  u'fancy',
#  u'CURTSEYING',
#  u'as',
#  u'you',
#  u"'re",
#  u'falling',
#  u'through',
#  u'the',
#  u'air',
#  u'!',
#  u'Do',
#  u'you',
#  u'think',
#  u'you',
#  u'could',
#  u'manage',
#  u'it',
#  u'?',
#  u')',
#  u"'And",
#  u'what',
#  u'an',
#  u'ignorant',
#  u'little',
#  u'girl',
#  u'she',
#  u"'ll",
#  u'think',
#  u'me',
#  u'for',
#  u'asking',
#  u'!',
#  u'No',
#  u',',
#  u'it',
#  u"'ll",
#  u'never',
#  u'do',
#  u'to',
#  u'ask',
#  u':',
#  u'perhaps',
#  u'I',
#  u'shall',
#  u'see',
#  u'it',
#  u'written',
#  u'up',
#  u'somewhere',
#  u'.',
#  u"'",
#  u'Down',
#  u',',
#  u'down',
#  u',',
#  u'down',
#  u'.',
#  u'There',
#  u'was',
#  u'nothing',
#  u'else',
#  u'to',
#  u'do',
#  u',',
#  u'so',
#  u'Alice',
#  u'soon',
#  u'began',
#  u'talking',
#  u'again',
#  u'.',
#  u"'Dinah",
#  u"'ll",
#  u'miss',
#  u'me',
#  u'very',
#  u'much',
#  u'to-night',
#  u',',
#  u'I',
#  u'should',
#  u'think',
#  u'!',
#  u"'",
#  u'(',
#  u'Dinah',
#  u'was',
#  u'the',
#  u'cat',
#  u'.',
#  u')',
#  u"'I",
#  u'hope',
#  u'they',
#  u"'ll",
#  u'remember',
#  u'her',
#  u'saucer',
#  u'of',
#  u'milk',
#  u'at',
#  u'tea-time',
#  u'.',
#  u'Dinah',
#  u'my',
#  u'dear',
#  u'!',
#  u'I',
#  u'wish',
#  u'you',
#  u'were',
#  u'down',
#  u'here',
#  u'with',
#  u'me',
#  u'!',
#  u'There',
#  u'are',
#  u'no',
#  u'mice',
#  u'in',
#  u'the',
#  u'air',
#  u',',
#  u'I',
#  u"'m",
#  u'afraid',
#  u',',
#  u'but',
#  u'you',
#  u'might',
#  u'catch',
#  u'a',
#  u'bat',
#  u',',
#  u'and',
#  u'that',
#  u"'s",
#  u'very',
#  ...]

# %%
# For each novel, construct a set of all the distinct words used
emma_distinct_word = set()
for x in emma_words:
        emma_distinct_word.add(x)
emma_distinct_word
# Out:
# {u'yellow',
#  u'four',
#  u'Does',
#  u'hanging',
#  u'aggression',
#  u'briskness',
#  u'looking',
#  u'eligible',
#  u'snowing',
#  u'rouse',
#  u'scold',
#  u'unanswered',
#  u'Fetch',
#  u'lord',
#  u'eligibly',
#  u'meadows',
#  u'sinking',
#  u'stipulate',
#  u'sweetbread',
#  u'stabbed',
#  u'bringing',
#  u'disturb',
#  u'recollections',
#  u'scholar',
#  u'_answer_',
#  u'Acquit',
#  u'her.',
#  u'tired',
#  u'cordially',
#  u'woollen-draper',
#  u'pulse',
#  u'tires',
#  u'elegant',
#  u'second',
#  u'consenting',
#  u'errors',
#  u'nature.',
#  u'contributed',
#  u'Wrong',
#  u'increasing',
#  u'inducement',
#  u'hero',
#  u'intellects',
#  u'interrupting',
#  u'here',
#  u'properest',
#  u'hers',
#  u'natured',
#  u'substance',
#  u'gardeners',
#  u'unwillingness',
#  u'pretensions',
#  u'reports',
#  u'military',
#  u'criticism',
#  u'_would_',
#  u'divide',
#  u'secluded',
#  u'explained',
#  u'civilities',
#  u'summons',
#  u'brought',
#  u'anywhere.',
#  u'cherishing',
#  u'spoke',
#  u'music',
#  u'therefore',
#  u'strike',
#  u'females',
#  u'successful',
#  u'brings',
#  u'whirling',
#  u'hurt',
#  u'glass',
#  u'midst',
#  u'hold',
#  u'circumstances',
#  u'locked',
#  u'pursue',
#  u'accomplishment',
#  u'eatable',
#  u'example',
#  u'misfortunes',
#  u'La',
#  u'unjust',
#  u'caution',
#  u'want',
#  u'reprove',
#  u'absolute',
#  u'travel',
#  u'feature',
#  u'how',
#  u'hot',
#  u'hesitatingly',
#  u'hop',
#  u'preferable',
#  u'dignified',
#  u'A',
#  u'Bates',
#  u'beauty',
#  u'Charming',
#  u'perfection.',
#  u'wrong',
#  u'destined',
#  u'melodies',
#  u'CHARADE',
#  u'unselfish',
#  u'misfortune.',
#  u'matter-of-fact',
#  u'testify',
#  u'ballroom',
#  u'endeavoured',
#  u'presiding',
#  u'Another',
#  u'wind',
#  u'wine',
#  u'blind',
#  u'welcomed',
#  u'concurrence',
#  u'enquiring',
#  u'Donwell',
#  u'rewarded',
#  u'strawberry-beds.',
#  u'dreamer',
#  u'admirably',
#  u'His',
#  u'Abbots',
#  u'fit',
#  u'heretofore',
#  u'fix',
#  u'occupations',
#  u'Smiths',
#  u'distinguishing',
#  u'clearest-headed',
#  u'admirable',
#  u'easier',
#  u'grievous',
#  u'enrich',
#  u'educating',
#  u'effects',
#  u'sixteen',
#  u'silver',
#  u'prize',
#  u'rumour',
#  u'_with_',
#  u'blushes',
#  u"Dixon's",
#  u'arrow',
#  u'blushed',
#  u'_engagement_',
#  u'preceded',
#  u'whim',
#  u'hood-wink',
#  u'correct.',
#  u'_Elton_',
#  u'blinder',
#  u'turnip',
#  u'precedes',
#  u'fortnight',
#  u'worn-out',
#  u'allay',
#  u'message',
#  u'backgammon',
#  u'borne',
#  u'misfortune',
#  u'speed.',
#  u'indiscretion',
#  u'excepting',
#  u'encourage',
#  u'adapt',
#  u'mend',
#  u'Vanity',
#  u'foundation',
#  u'assured',
#  u'Adopt',
#  u'threatened',
#  u'_her_',
#  u'checked',
#  u'estimate',
#  u'contrition',
#  u'Soft',
#  u'universally',
#  u'mimic',
#  u'enormous',
#  u'ate',
#  u'Baly-craig',
#  u'perhaps.',
#  u'moment',
#  u'disturbed',
#  u'speedy',
#  u'Boarding-school',
#  u'loudness',
#  u'playfully',
#  u'clamorous',
#  u'elms',
#  u'service',
#  u'engagement',
#  u'needed',
#  u'_say_',
#  u'master',
#  u'bitter',
#  u'sure.',
#  u'listen',
#  u'hows',
#  u'was.',
#  u'positively',
#  u'Beautiful',
#  u'exultation',
#  u'tree',
#  u'project',
#  u'idle',
#  u'exclaimed',
#  u'endure',
#  u'seminary',
#  u'feeling',
#  u'festivity',
#  u'exploring',
#  u'well.',
#  u'shrubs',
#  u'thaw',
#  u'dozen',
#  u'affairs',
#  u'forgive',
#  u'wholesome',
#  u'reverie',
#  u'eagerly',
#  u'gratification',
#  u'recommended',
#  u'amusing',
#  u'They',
#  u'sweet-tempered',
#  u'imprudent',
#  u'Stokes.',
#  u'shall',
#  u'Wish',
#  u'object',
#  u'mouth',
#  u'letter',
#  u'Woodhouse-ing',
#  u'retaining',
#  u'morality',
#  u'Kingston',
#  u'scream',
#  u'came',
#  u'saying',
#  u'Composure',
#  u'meetings',
#  u'undue',
#  u'terror.',
#  u'falsehoods',
#  u'tempted',
#  u'four-and-twenty',
#  u'lessons',
#  u'touches',
#  u'busy',
#  u'vexations',
#  u'lights',
#  u'quaint',
#  u'cousins',
#  u'_compliments_',
#  u'touched',
#  u'rich',
#  u'heartily',
#  u'rice',
#  u'emphatically',
#  u'Churchills',
#  u'terrors',
#  u'pocket',
#  u'altogether',
#  u'X',
#  u'relish',
#  u'nicely',
#  u'boarder',
#  u'patch',
#  u'esteeming',
#  u'adherence',
#  u'them.',
#  u'hasten',
#  u'wedding-present.',
#  u'fair',
#  u'expediency',
#  u'_You_',
#  u'unexpectedly',
#  u'result',
#  u'fail',
#  u'John',
#  u'requisite.',
#  u'best',
#  u'avert',
#  u'playfulness',
#  u'solicitude',
#  u'loth',
#  u'counsel',
#  u'preserve',
#  u'letting',
#  u'men',
#  u'involved.',
#  u'extend',
#  u'nature',
#  u'councillors',
#  u'feared.',
#  u'twinkling',
#  u'_felt_',
#  u'extent',
#  u'defiance',
#  u'dexterously',
#  u'debt',
#  u'WINDSOR-JULY',
#  u'pity',
#  u'accident',
#  u'sacrificing',
#  u'refinement',
#  u'country',
#  u'Blessed',
#  u'demanded',
#  u"Churchill's",
#  u'planned',
#  u'self-denying',
#  u'asked',
#  u'mortified',
#  u'honouring',
#  u'vain',
#  u'Liable',
#  u'_small_',
#  u'office-door',
#  u'advances.',
#  u'parley',
#  u'union',
#  u'aspersion',
#  u'subside',
#  u'.',
#  u"Ceremonies'",
#  u'much',
#  u'privilege',
#  u'life',
#  u'retrospect',
#  u'pointing',
#  u'confinement',
#  u'child',
#  u'evasions',
#  u'worked',
#  u'doth',
#  u'diverted',
#  u'contemplated',
#  u'contingencies',
#  u'employ',
#  u'misconstrued',
#  u'unfelt',
#  u'Campbell',
#  u'charmed.',
#  u'Goddard',
#  u'remembering',
#  u'congratulation',
#  u'played',
#  u'ill-equipped',
#  u'to-morrow',
#  u'anticipating',
#  u'trusted',
#  u'memorial',
#  u'severity',
#  u'things',
#  u'demands',
#  u'any',
#  u'haphazard',
#  u'harmony',
#  u'passed.',
#  u'principals',
#  u'Randalls.',
#  u'exertion',
#  u'fairly',
#  u'boiled',
#  u'ill-usage',
#  u'consents',
#  u'Contrary',
#  u'supper',
#  u'tune',
#  u'smallness',
#  u'_blunder_',
#  u'coldness',
#  u'thing.',
#  u'ascending.',
#  u'veils',
#  u'opinions',
#  u'outlived',
#  u'Thank',
#  u'absurdities',
#  u'disguise',
#  u'exclaiming',
#  u'succeeding',
#  u'previous',
#  u'spectacles',
#  u'dialogues',
#  u'ease',
#  u'had',
#  u'hay',
#  u'disparity',
#  u'collections',
#  u'beloved',
#  u'has',
#  u'hat',
#  u'good-humoured',
#  u'elevation',
#  u'disagreement',
#  u'possible',
#  u'Three',
#  u'unequivocally',
#  u'possibly',
#  u'chuse',
#  u'birth',
#  u'shadow',
#  u'opinion.',
#  u'desire',
#  u'Lords',
#  u'seaside',
#  u'remind',
#  u'misled',
#  u'stept',
#  u'steps',
#  u'prologue',
#  u'_broke_',
#  u'over-throw',
#  u"Emma's",
#  u'effusion',
#  u'attorney',
#  u'right',
#  u'old',
#  u'crowd',
#  u'people',
#  u'crown',
#  u'sure',
#  u'Between',
#  u'sea-bathing',
#  u'creep',
#  u'enemies',
#  u'for',
#  u'communications',
#  u'sick-chamber',
#  u'contributing',
#  u'over-powered',
#  u'summoned',
#  u'pondered',
#  u'palatable',
#  u'extenuation',
#  u'losing',
#  u'moralised',
#  u'Think',
#  u'shaken',
#  u'Suckling',
#  u'restlessness',
#  u'visitors',
#  u'grievously',
#  u'recollect',
#  u'despair',
#  u'repellent',
#  u'slightly',
#  u'consulting',
#  u'nought',
#  u'Scotland',
#  u'respectably',
#  u'son',
#  u'administer',
#  u'respectable',
#  u'beings',
#  u'wrap',
#  u'Alderneys',
#  u'waits',
#  u'impossible.',
#  u'support',
#  u'constantly',
#  u'avail',
#  u'greatness',
#  u'resulted',
#  u'happy',
#  u'offer',
#  u'forming',
#  u'`Nobody',
#  u'so.',
#  u'talents',
#  u'wedding-day',
#  u'_Bath_',
#  u'congratulations',
#  u'feet',
#  u'Sir',
#  u'proud',
#  u'disgrace',
#  u'Six',
#  u"''",
#  u'proves',
#  u'exist',
#  u'accounting',
#  u'effusions',
#  u'protested',
#  u'solicitation',
#  u'floor',
#  u'uttered',
#  u'grammatical',
#  u'conferring',
#  u'momentary',
#  u'smell',
#  u"'s",
#  u'transported',
#  u"'d",
#  u'intent',
#  u'_Philip_',
#  u"'T",
#  u'Madness',
#  u'_White-Hart_',
#  u'good-natured',
#  u'Madeira',
#  u'time',
#  u'push',
#  u'conferred',
#  u'gown',
#  u'whoever',
#  u'deserve.',
#  u'`It',
#  u'chair',
#  u'`If',
#  u'rousing',
#  u'indolent',
#  u'vex',
#  u'recurrence',
#  u'Believe',
#  u'fatigues',
#  u'choice',
#  u'gloomy',
#  u'rapturous',
#  u'rationality',
#  u'stays',
#  u'fullest',
#  u'exact',
#  u'minute',
#  u'tear',
#  u'leave',
#  u'figure-pieces',
#  u'settle',
#  u'good.',
#  u'Tan',
#  u'prevent',
#  u'occurrence',
#  u'sigh',
#  u'M.',
#  u'steaks',
#  u'lengthened',
#  u'educate',
#  u'proprieties',
#  u'example.',
#  u'unfeelingly',
#  u'freaks',
#  u'deadening',
#  u'pretty.',
#  u'falling',
#  u'ground',
#  u'True',
#  u'Me',
#  u'Emma',
#  u'honour',
#  u'funeral',
#  u'understanding',
#  u'contemplate',
#  u'yards',
#  u'Mr',
#  u'alone',
#  u'likenesses',
#  u'My',
#  u'brilliant',
#  u'coxcomb',
#  u'studied',
#  u'wherever',
#  u'commonly',
#  u'accomplished',
#  u'MY',
#  u'concealed',
#  u'love',
#  u'prefer',
#  u'Abbey',
#  u'betraying',
#  u'XVIII',
#  u'_time_',
#  u'August',
#  u'working',
#  u'positive',
#  u'angry',
#  u'predictions',
#  u'papas',
#  u'by',
#  u'imaginations',
#  u'vigour',
#  u'opposed',
#  u'wondering',
#  u'Those',
#  u'wicked',
#  u'introducing',
#  u'``',
#  u'afford',
#  u'subsistence',
#  u'apparent',
#  u'refrain',
#  u'approving',
#  u'everywhere',
#  u'virtue',
#  u'behalf',
#  u'valued',
#  u'anything',
#  u'originally',
#  u'`I',
#  u'Midsummer',
#  u'privy',
#  u'inflamed',
#  u'believes',
#  u'papa.',
#  u'values',
#  u'believed',
#  u'Our',
#  u'detached',
#  u'admired',
#  u'parishes',
#  u'greatcoat',
#  u'unequalled',
#  u'admires',
#  u'allowed',
#  u'evidently',
#  u'kindness.',
#  u'winter',
#  u'divided',
#  u'Who',
#  u'vainly',
#  u'thanking',
#  u'Why',
#  u'undertook',
#  u'absenting',
#  u'spot',
#  u'applications',
#  u'explored',
#  u'date',
#  u'such',
#  u'revealed',
#  u'disagreeable',
#  u'Captain',
#  u'natural',
#  u'varieties',
#  u'conscious',
#  u'ordinarily',
#  u'attestation',
#  u'so',
#  u'snowed',
#  u'Trouble',
#  u'double-dyed',
#  u'privation',
#  u'Barnes',
#  u'footstep',
#  u'years',
#  u'course',
#  u'quarrelled',
#  u'omitting',
#  u'pollards',
#  u'tendency',
#  u're-urged',
#  u'solitary',
#  u'solace',
#  u'troubles',
#  u'stupidity',
#  u'attraction',
#  u'suspicion',
#  u'suspension',
#  u"Sucklings'",
#  u'instantly',
#  u'conveying',
#  u'matches',
#  u'remonstrated',
#  u'overpowering',
#  u'arriving',
#  u'epithets',
#  u'reckoning',
#  u'twilight',
#  u'Caroline.',
#  u'matched',
#  u'_you_',
#  u'trouble.',
#  u'tender-hearted',
#  u'quarter',
#  u'cordiality',
#  u'invention.',
#  u'square',
#  u'receipt',
#  u'M',
#  u'owing',
#  u'entering',
#  u'paling',
#  u'superior.',
#  u'neighbourhood',
#  u'Elizabeth',
#  u'abide',
#  u'seriously',
#  u'suggesting',
#  u'bordering',
#  u'Oftentimes',
#  u'plotting',
#  u'complimented',
#  u'hairdresser',
#  u'million',
#  u'possibility',
#  u'quite',
#  u'disrespect',
#  u'Offended',
#  u'Either',
#  u'besides',
#  u'quits',
#  u'remainder',
#  u'liberally',
#  u'patronage',
#  u'disguised',
#  u'modest',
#  u'_The_',
#  u'crossness',
#  u'undesirable',
#  u'neglect',
#  u'emotion',
#  u'saving',
#  u'`no',
#  u'properer',
#  u'spoken',
#  u'one',
#  u'habitation',
#  u'open',
#  u'awkwardnesses',
#  u'affords',
#  u'languish',
#  u'goodhumoured',
#  u'solitarily',
#  u'vouchsafing',
#  u'indicate',
#  u'dissipate',
#  u'encourager',
#  u'thick-headed',
#  u'lingering',
#  u'pressingly',
#  u'conciliating.',
#  u'shawl',
#  u'proving',
#  u'much.',
#  u'ridiculous',
#  u'Waiving',
#  u'chilblains',
#  u'representing',
#  u'Seven',
#  u'companionably',
#  u'overtaken',
#  u'depressed',
#  u'rival',
#  u'folly',
#  u'future',
#  u'_happily_',
#  u'wins',
#  u'wandering',
#  u'prospect',
#  u'addressing',
#  u'illness',
#  u'nicer',
#  u'turned',
#  u'argument',
#  u'jewels',
#  u'sad',
#  u'say',
#  u'rained',
#  u'buried',
#  u'lurking',
#  u'uninterrupted',
#  u'saw',
#  u'self-consequence',
#  u'sat',
#  u'_Woodhouse_',
#  u'fashionable',
#  u'unsuitable',
#  u'_unrequited_',
#  u'aside',
#  u'note',
#  u'rumination',
#  u'transcribed',
#  u'take',
#  u'Half',
#  u'wanting',
#  u'Hall',
#  u'creditably',
#  u'appellation',
#  u'altered',
#  u'opposite',
#  u'syllable',
#  u'discerning',
#  u'knew',
#  u'compress',
#  u'taste.',
#  u'remarks',
#  u'knee',
#  u'pages',
#  u'gentleman-like',
#  u'lawn',
#  u'spruce-beer.',
#  u'guidable',
#  u'blockhead',
#  u'drive',
#  u'Weston',
#  u'ways',
#  u'not.',
#  u'trembled',
#  u'walking',
#  u'murmurs',
#  u'pencilled',
#  u'imagines',
#  u'merit',
#  u'bright',
#  u'inconsistent',
#  u'scarce',
#  u'imagined',
#  u'slow',
#  u'unkind',
#  u'cloak',
#  u'effect.',
#  u'tears',
#  u'going',
#  u'uppermost',
#  u'entreaties',
#  u'wilfully',
#  u'guarded',
#  u'rejoiced',
#  u'usual.',
#  u'_letting_',
#  u'assistant',
#  u'XIV',
#  u'XIX',
#  u'Having',
#  u'prime',
#  u'keenly',
#  u'artist',
#  u'borrow',
#  u'though',
#  u'liable',
#  u'cry-out',
#  u'vision',
#  u'gout',
#  u'smooth.',
#  u'purest',
#  u'mutton',
#  u'That',
#  u'alarming',
#  u'ostensible',
#  u'affecting',
#  u'illiberal',
#  u'untainted',
#  u'man.',
#  u'screen',
#  u'gratefully',
#  u'reigns',
#  u'aggrandise',
#  u'suppressed',
#  u'brisk-moving',
#  u'concentrated',
#  u'conversed',
#  u'Braithwaites',
#  u'cramp',
#  u'enjoy.',
#  u'many',
#  u'deduction',
#  u'loudly',
#  u'Fairfax.',
#  u'expression',
#  u'doctoring',
#  u'allowance',
#  u'riddle',
#  u'side.',
#  u'inclining',
#  u'hurts',
#  u'gaiety',
#  u'Westons',
#  u'considers',
#  u'caring',
#  u'plantation',
#  u'stretch',
#  u'vacation',
#  u'breath',
#  u'practised',
#  u'combined',
#  u'motives',
#  u'wants',
#  u'amity.',
#  u'enable',
#  u'Whenever',
#  u'influence',
#  u'thousand',
#  u'Weston.',
#  u'observe',
#  u'former',
#  u'felling',
#  u'pretence',
#  u'single',
#  u'Him',
#  u'intimately',
#  u'conveyance',
#  u'newspaper',
#  u'situation',
#  u'endured',
#  u'stupidest',
#  u'prevalence',
#  u'salting-pan',
#  u'engaged',
#  u'dubious',
#  u'over-careful',
#  u'regularity',
#  u'presides',
#  u'engages',
#  u'fame',
#  u'Towards',
#  u'verified',
#  u'preparatory',
#  u'perpetually',
#  u'forebodings',
#  u'respite',
#  u'irksome',
#  u'sickness',
#  u'I',
#  u'obtruding',
#  u'XVI',
#  u'Anywhere',
#  u'_is_',
#  u'unmanageable',
#  u'card-room',
#  u'flocks',
#  u'vacant',
#  u'bailiff',
#  u'commonest',
#  u'peculiarities',
#  u'conversable',
#  u'_party_',
#  u'summer',
#  u'dinner-time',
#  u'being',
#  u'rest',
#  u'disperse',
#  u'provocation',
#  u'presumption',
#  u'cogitation',
#  u'medals',
#  u'hereabouts',
#  u'instrument',
#  u'dryly',
#  u'overthrow',
#  u'half-ashamed',
#  u'joyful',
#  u'around',
#  u'sums',
#  u'dark',
#  u'traffic',
#  u'sorry.',
#  u'world',
#  u'apprehending',
#  u'dare',
#  u'meat',
#  u'stranger',
#  u'paused.',
#  u'superiority',
#  u'prophetically',
#  u'nursery-maids',
#  u'stationary',
#  u'completest',
#  u'Perry',
#  u'Woodhouse',
#  u'likely.',
#  u'moreover',
#  u'thinks',
#  u'carriage-horses',
#  u'dimensions',
#  u'23rd',
#  u'restoring',
#  u'refer',
#  u'unsuccessfully',
#  u'power',
#  u'intimate',
#  u'`well',
#  u'prepared',
#  u'stone',
#  u'joyfully',
#  u'industry',
#  u'side',
#  u'practicable',
#  u'act',
#  u'luck',
#  u'sleety',
#  u'No',
#  u'antidote',
#  u'sneering',
#  u'widower',
#  u'lively',
#  u'parties',
#  u'her',
#  u'endeavouring',
#  u'meals',
#  u'sealed',
#  u'series',
#  u'_think_',
#  u'complete',
#  ...}

# %%
alice_distinct_word = []
for x in alice_words:
    if x not in alice_distinct_word:
        alice_distinct_word.append(x)
alice_distinct_word
# Out:
# [u'[',
#  u'Alice',
#  u"'s",
#  u'Adventures',
#  u'in',
#  u'Wonderland',
#  u'by',
#  u'Lewis',
#  u'Carroll',
#  u'1865',
#  u']',
#  u'CHAPTER',
#  u'I',
#  u'.',
#  u'Down',
#  u'the',
#  u'Rabbit-Hole',
#  u'was',
#  u'beginning',
#  u'to',
#  u'get',
#  u'very',
#  u'tired',
#  u'of',
#  u'sitting',
#  u'her',
#  u'sister',
#  u'on',
#  u'bank',
#  u',',
#  u'and',
#  u'having',
#  u'nothing',
#  u'do',
#  u':',
#  u'once',
#  u'or',
#  u'twice',
#  u'she',
#  u'had',
#  u'peeped',
#  u'into',
#  u'book',
#  u'reading',
#  u'but',
#  u'it',
#  u'no',
#  u'pictures',
#  u'conversations',
#  u"'and",
#  u'what',
#  u'is',
#  u'use',
#  u'a',
#  u"'",
#  u'thought',
#  u"'without",
#  u'conversation',
#  u'?',
#  u'So',
#  u'considering',
#  u'own',
#  u'mind',
#  u'(',
#  u'as',
#  u'well',
#  u'could',
#  u'for',
#  u'hot',
#  u'day',
#  u'made',
#  u'feel',
#  u'sleepy',
#  u'stupid',
#  u')',
#  u'whether',
#  u'pleasure',
#  u'making',
#  u'daisy-chain',
#  u'would',
#  u'be',
#  u'worth',
#  u'trouble',
#  u'getting',
#  u'up',
#  u'picking',
#  u'daisies',
#  u'when',
#  u'suddenly',
#  u'White',
#  u'Rabbit',
#  u'with',
#  u'pink',
#  u'eyes',
#  u'ran',
#  u'close',
#  u'There',
#  u'so',
#  u'VERY',
#  u'remarkable',
#  u'that',
#  u';',
#  u'nor',
#  u'did',
#  u'think',
#  u'much',
#  u'out',
#  u'way',
#  u'hear',
#  u'say',
#  u'itself',
#  u"'Oh",
#  u'dear',
#  u'!',
#  u'Oh',
#  u'shall',
#  u'late',
#  u'over',
#  u'afterwards',
#  u'occurred',
#  u'ought',
#  u'have',
#  u'wondered',
#  u'at',
#  u'this',
#  u'time',
#  u'all',
#  u'seemed',
#  u'quite',
#  u'natural',
#  u'actually',
#  u'TOOK',
#  u'A',
#  u'WATCH',
#  u'OUT',
#  u'OF',
#  u'ITS',
#  u'WAISTCOAT-POCKET',
#  u'looked',
#  u'then',
#  u'hurried',
#  u'started',
#  u'feet',
#  u'flashed',
#  u'across',
#  u'never',
#  u'before',
#  u'seen',
#  u'rabbit',
#  u'either',
#  u'waistcoat-pocket',
#  u'watch',
#  u'take',
#  u'burning',
#  u'curiosity',
#  u'field',
#  u'after',
#  u'fortunately',
#  u'just',
#  u'see',
#  u'pop',
#  u'down',
#  u'large',
#  u'rabbit-hole',
#  u'under',
#  u'hedge',
#  u'In',
#  u'another',
#  u'moment',
#  u'went',
#  u'how',
#  u'world',
#  u'again',
#  u'The',
#  u'straight',
#  u'like',
#  u'tunnel',
#  u'some',
#  u'dipped',
#  u'not',
#  u'about',
#  u'stopping',
#  u'herself',
#  u'found',
#  u'falling',
#  u'deep',
#  u'Either',
#  u'fell',
#  u'slowly',
#  u'plenty',
#  u'look',
#  u'wonder',
#  u'going',
#  u'happen',
#  u'next',
#  u'First',
#  u'tried',
#  u'make',
#  u'coming',
#  u'too',
#  u'dark',
#  u'anything',
#  u'sides',
#  u'noticed',
#  u'they',
#  u'were',
#  u'filled',
#  u'cupboards',
#  u'book-shelves',
#  u'here',
#  u'there',
#  u'saw',
#  u'maps',
#  u'hung',
#  u'upon',
#  u'pegs',
#  u'She',
#  u'took',
#  u'jar',
#  u'from',
#  u'one',
#  u'shelves',
#  u'passed',
#  u'labelled',
#  u"'ORANGE",
#  u'MARMALADE',
#  u'great',
#  u'disappointment',
#  u'empty',
#  u'drop',
#  u'fear',
#  u'killing',
#  u'somebody',
#  u'managed',
#  u'put',
#  u'past',
#  u"'Well",
#  u"'after",
#  u'such',
#  u'fall',
#  u'tumbling',
#  u'stairs',
#  u'How',
#  u'brave',
#  u"'ll",
#  u'me',
#  u'home',
#  u'Why',
#  u"n't",
#  u'even',
#  u'if',
#  u'off',
#  u'top',
#  u'house',
#  u'Which',
#  u'likely',
#  u'true',
#  u'Would',
#  u'NEVER',
#  u'come',
#  u'an',
#  u'end',
#  u"'I",
#  u'many',
#  u'miles',
#  u"'ve",
#  u'fallen',
#  u'said',
#  u'aloud',
#  u'must',
#  u'somewhere',
#  u'near',
#  u'centre',
#  u'earth',
#  u'Let',
#  u'four',
#  u'thousand',
#  u'--',
#  u'you',
#  u'learnt',
#  u'several',
#  u'things',
#  u'sort',
#  u'lessons',
#  u'schoolroom',
#  u'though',
#  u'good',
#  u'opportunity',
#  u'showing',
#  u'knowledge',
#  u'listen',
#  u'still',
#  u'practice',
#  u'yes',
#  u'right',
#  u'distance',
#  u'Latitude',
#  u'Longitude',
#  u'got',
#  u'idea',
#  u'nice',
#  u'grand',
#  u'words',
#  u'Presently',
#  u'began',
#  u'THROUGH',
#  u'funny',
#  u'seem',
#  u'among',
#  u'people',
#  u'walk',
#  u'their',
#  u'heads',
#  u'downward',
#  u'Antipathies',
#  u'rather',
#  u'glad',
#  u'WAS',
#  u'listening',
#  u'sound',
#  u'word',
#  u'ask',
#  u'them',
#  u'name',
#  u'country',
#  u'know',
#  u'Please',
#  u"Ma'am",
#  u'New',
#  u'Zealand',
#  u'Australia',
#  u'curtsey',
#  u'spoke',
#  u'fancy',
#  u'CURTSEYING',
#  u"'re",
#  u'through',
#  u'air',
#  u'Do',
#  u'manage',
#  u"'And",
#  u'ignorant',
#  u'little',
#  u'girl',
#  u'asking',
#  u'No',
#  u'perhaps',
#  u'written',
#  u'else',
#  u'soon',
#  u'talking',
#  u"'Dinah",
#  u'miss',
#  u'to-night',
#  u'should',
#  u'Dinah',
#  u'cat',
#  u'hope',
#  u'remember',
#  u'saucer',
#  u'milk',
#  u'tea-time',
#  u'my',
#  u'wish',
#  u'are',
#  u'mice',
#  u"'m",
#  u'afraid',
#  u'might',
#  u'catch',
#  u'bat',
#  u'mouse',
#  u'But',
#  u'cats',
#  u'eat',
#  u'bats',
#  u'And',
#  u'saying',
#  u'dreamy',
#  u"'Do",
#  u'sometimes',
#  u'answer',
#  u'question',
#  u'matter',
#  u'which',
#  u'felt',
#  u'dozing',
#  u'begun',
#  u'dream',
#  u'walking',
#  u'hand',
#  u'earnestly',
#  u"'Now",
#  u'tell',
#  u'truth',
#  u'ever',
#  u'thump',
#  u'came',
#  u'heap',
#  u'sticks',
#  u'dry',
#  u'leaves',
#  u'bit',
#  u'hurt',
#  u'jumped',
#  u'overhead',
#  u'long',
#  u'passage',
#  u'sight',
#  u'hurrying',
#  u'lost',
#  u'away',
#  u'wind',
#  u'turned',
#  u'corner',
#  u'ears',
#  u'whiskers',
#  u'behind',
#  u'longer',
#  u'low',
#  u'hall',
#  u'lit',
#  u'row',
#  u'lamps',
#  u'hanging',
#  u'roof',
#  u'doors',
#  u'round',
#  u'locked',
#  u'been',
#  u'side',
#  u'other',
#  u'trying',
#  u'every',
#  u'door',
#  u'walked',
#  u'sadly',
#  u'middle',
#  u'wondering',
#  u'Suddenly',
#  u'three-legged',
#  u'table',
#  u'solid',
#  u'glass',
#  u'except',
#  u'tiny',
#  u'golden',
#  u'key',
#  u"Alice's",
#  u'first',
#  u'belong',
#  u'alas',
#  u'locks',
#  u'small',
#  u'any',
#  u'rate',
#  u'open',
#  u'However',
#  u'second',
#  u'curtain',
#  u'fifteen',
#  u'inches',
#  u'high',
#  u'lock',
#  u'delight',
#  u'fitted',
#  u'opened',
#  u'led',
#  u'larger',
#  u'than',
#  u'rat-hole',
#  u'knelt',
#  u'along',
#  u'loveliest',
#  u'garden',
#  u'longed',
#  u'wander',
#  u'those',
#  u'beds',
#  u'bright',
#  u'flowers',
#  u'cool',
#  u'fountains',
#  u'head',
#  u'doorway',
#  u'go',
#  u'poor',
#  u"'it",
#  u'without',
#  u'shoulders',
#  u'shut',
#  u'telescope',
#  u'only',
#  u'begin',
#  u'For',
#  u'out-of-the-way',
#  u'happened',
#  u'lately',
#  u'few',
#  u'indeed',
#  u'really',
#  u'impossible',
#  u'waiting',
#  u'back',
#  u'half',
#  u'hoping',
#  u'find',
#  u'rules',
#  u'shutting',
#  u'telescopes',
#  u'bottle',
#  u"'which",
#  u'certainly',
#  u'neck',
#  u'paper',
#  u'label',
#  u"'DRINK",
#  u'ME',
#  u'beautifully',
#  u'printed',
#  u'letters',
#  u'It',
#  u"'Drink",
#  u'wise',
#  u'THAT',
#  u'hurry',
#  u"'No",
#  u'marked',
#  u'``',
#  u'poison',
#  u"''",
#  u'read',
#  u'histories',
#  u'children',
#  u'who',
#  u'burnt',
#  u'eaten',
#  u'wild',
#  u'beasts',
#  u'unpleasant',
#  u'because',
#  u'WOULD',
#  u'simple',
#  u'friends',
#  u'taught',
#  u'red-hot',
#  u'poker',
#  u'will',
#  u'burn',
#  u'hold',
#  u'cut',
#  u'your',
#  u'finger',
#  u'deeply',
#  u'knife',
#  u'usually',
#  u'bleeds',
#  u'forgotten',
#  u'drink',
#  u"'poison",
#  u'almost',
#  u'certain',
#  u'disagree',
#  u'sooner',
#  u'later',
#  u'NOT',
#  u'ventured',
#  u'taste',
#  u'finding',
#  u'fact',
#  u'mixed',
#  u'flavour',
#  u'cherry-tart',
#  u'custard',
#  u'pine-apple',
#  u'roast',
#  u'turkey',
#  u'toffee',
#  u'buttered',
#  u'toast',
#  u'finished',
#  u'*',
#  u"'What",
#  u'curious',
#  u'feeling',
#  u'now',
#  u'ten',
#  u'face',
#  u'brightened',
#  u'size',
#  u'lovely',
#  u'however',
#  u'waited',
#  u'minutes',
#  u'shrink',
#  u'further',
#  u'nervous',
#  u"'for",
#  u"'in",
#  u'altogether',
#  u'candle',
#  u'flame',
#  u'blown',
#  u'thing',
#  u'After',
#  u'while',
#  u'more',
#  u'decided',
#  u'possibly',
#  u'reach',
#  u'plainly',
#  u'best',
#  u'climb',
#  u'legs',
#  u'slippery',
#  u'sat',
#  u'cried',
#  u"'Come",
#  u'crying',
#  u'sharply',
#  u'advise',
#  u'leave',
#  u'minute',
#  u'generally',
#  u'gave',
#  u'advice',
#  u'seldom',
#  u'followed',
#  u'scolded',
#  u'severely',
#  u'bring',
#  u'tears',
#  u'remembered',
#  u'box',
#  u'cheated',
#  u'game',
#  u'croquet',
#  u'playing',
#  u'against',
#  u'child',
#  u'fond',
#  u'pretending',
#  u'two',
#  u"'But",
#  u"'to",
#  u'pretend',
#  u'hardly',
#  u'enough',
#  u'left',
#  u'ONE',
#  u'respectable',
#  u'person',
#  u'Soon',
#  u'eye',
#  u'lying',
#  u'cake',
#  u"'EAT",
#  u'currants',
#  u'makes',
#  u'grow',
#  u'can',
#  u'smaller',
#  u'creep',
#  u"I'll",
#  u'care',
#  u'happens',
#  u'ate',
#  u'anxiously',
#  u"'Which",
#  u'holding',
#  u'growing',
#  u'surprised',
#  u'remained',
#  u'same',
#  u'sure',
#  u'eats',
#  u'expecting',
#  u'dull',
#  u'life',
#  u'common',
#  u'set',
#  u'work',
#  u'II',
#  u'Pool',
#  u'Tears',
#  u"'Curiouser",
#  u'curiouser',
#  u'forgot',
#  u'speak',
#  u'English',
#  u"'now",
#  u"I'm",
#  u'opening',
#  u'largest',
#  u'Good-bye',
#  u'far',
#  u'shoes',
#  u'stockings',
#  u'dears',
#  u'_I_',
#  u'sha',
#  u'able',
#  u'deal',
#  u'myself',
#  u'kind',
#  u"'or",
#  u'wo',
#  u'want',
#  u'give',
#  u'new',
#  u'pair',
#  u'boots',
#  u'Christmas',
#  u'planning',
#  u"'They",
#  u'carrier',
#  u'sending',
#  u'presents',
#  u'odd',
#  u'directions',
#  u'ALICE',
#  u"'S",
#  u'RIGHT',
#  u'FOOT',
#  u'ESQ',
#  u'HEARTHRUG',
#  u'NEAR',
#  u'THE',
#  u'FENDER',
#  u'WITH',
#  u'LOVE',
#  u'nonsense',
#  u'Just',
#  u'struck',
#  u'nine',
#  u'Poor',
#  u'hopeless',
#  u'cry',
#  u"'You",
#  u'ashamed',
#  u'yourself',
#  u"'a",
#  u'Stop',
#  u'shedding',
#  u'gallons',
#  u'until',
#  u'pool',
#  u'reaching',
#  u'heard',
#  u'pattering',
#  u'hastily',
#  u'dried',
#  u'returning',
#  u'splendidly',
#  u'dressed',
#  u'white',
#  u'kid',
#  u'gloves',
#  u'fan',
#  u'he',
#  u'trotting',
#  u'muttering',
#  u'himself',
#  u'Duchess',
#  u'savage',
#  u'kept',
#  u'desperate',
#  u'ready',
#  u'help',
#  u'timid',
#  u'voice',
#  u"'If",
#  u'please',
#  u'sir',
#  u'violently',
#  u'dropped',
#  u'skurried',
#  u'darkness',
#  u'hard',
#  u'fanning',
#  u"'Dear",
#  u'queer',
#  u'everything',
#  u'to-day',
#  u'yesterday',
#  u'usual',
#  u'changed',
#  u'night',
#  u'morning',
#  u'different',
#  u'Who',
#  u'am',
#  u'Ah',
#  u'puzzle',
#  u'thinking',
#  u'knew',
#  u'age',
#  u'Ada',
#  u'hair',
#  u'goes',
#  u'ringlets',
#  u'mine',
#  u'does',
#  u"can't",
#  u'Mabel',
#  u'sorts',
#  u'oh',
#  u'knows',
#  u'Besides',
#  u'SHE',
#  u'puzzling',
#  u'try',
#  u'used',
#  u'times',
#  u'five',
#  u'twelve',
#  u'six',
#  u'thirteen',
#  u'seven',
#  u'twenty',
#  u'Multiplication',
#  u'Table',
#  u'signify',
#  u'let',
#  u'Geography',
#  u'London',
#  u'capital',
#  u'Paris',
#  u'Rome',
#  u'wrong',
#  u'doth',
#  u'crossed',
#  u'hands',
#  u'lap',
#  u'repeat',
#  u'sounded',
#  u'hoarse',
#  u'strange',
#  u"'How",
#  u'crocodile',
#  u'Improve',
#  u'his',
#  u'shining',
#  u'tail',
#  u'pour',
#  u'waters',
#  u'Nile',
#  u'On',
#  u'scale',
#  u'cheerfully',
#  u'seems',
#  u'grin',
#  u'neatly',
#  u'spread',
#  u'claws',
#  u'welcome',
#  u'fishes',
#  u'With',
#  u'gently',
#  u'smiling',
#  u'jaws',
#  u'live',
#  u'poky',
#  u'toys',
#  u'play',
#  u'learn',
#  u"I've",
#  u'stay',
#  u'putting',
#  u'Come',
#  u'Tell',
#  u'being',
#  u'till',
#  u'sudden',
#  u'burst',
#  u'alone',
#  u'As',
#  u'CAN',
#  u'done',
#  u'measure',
#  u'nearly',
#  u'guess',
#  u'shrinking',
#  u'rapidly',
#  u'cause',
#  u'avoid',
#  u"'That",
#  u'narrow',
#  u'escape',
#  u'frightened',
#  u'change',
#  u'existence',
#  u'speed',
#  u'worse',
#  u'declare',
#  u'bad',
#  u'these',
#  u'foot',
#  u'slipped',
#  u'splash',
#  u'chin',
#  u'salt',
#  u'water',
#  u'Her',
#  u'somehow',
#  u'sea',
#  u'case',
#  u'railway',
#  u'seaside',
#  u'general',
#  u'conclusion',
#  u'wherever',
#  u'coast',
#  u'number',
#  u'bathing',
#  u'machines',
#  u'digging',
#  u'sand',
#  u'wooden',
#  u'spades',
#  u'lodging',
#  u'houses',
#  u'station',
#  u'wept',
#  u'swam',
#  u'punished',
#  u'suppose',
#  u'drowned',
#  u'That',
#  u'WILL',
#  u'something',
#  u'splashing',
#  u'nearer',
#  u'walrus',
#  u'hippopotamus',
#  u"'Would",
#  u'Everything',
#  u'talk',
#  u'harm',
#  u"'O",
#  u'Mouse',
#  u'swimming',
#  u'O',
#  u'speaking',
#  u'brother',
#  u'Latin',
#  u'Grammar',
#  u"'A",
#  u'inquisitively',
#  u'wink',
#  u'its',
#  u"'Perhaps",
#  u'understand',
#  u'daresay',
#  u"it's",
#  u'French',
#  u'William',
#  u'Conqueror',
#  u'history',
#  u'clear',
#  u'notion',
#  u'ago',
#  u"'Ou",
#  u'est',
#  u'ma',
#  u'chatte',
#  u'sentence',
#  u'lesson-book',
#  u'leap',
#  u'quiver',
#  u'fright',
#  u'beg',
#  u'pardon',
#  u'animal',
#  u'feelings',
#  u"'Not",
#  u'shrill',
#  u'passionate',
#  u'YOU',
#  u'soothing',
#  u'tone',
#  u"'do",
#  u'angry',
#  u'yet',
#  u'show',
#  u'our',
#  u"you'd",
#  u'quiet',
#  u'lazily',
#  u'sits',
#  u'purring',
#  u'nicely',
#  u'fire',
#  u'licking',
#  u'paws',
#  u'washing',
#  u'soft',
#  u'nurse',
#  u"she's",
#  u'catching',
#  ...]

# %%
# Calculate the lexical diversity of each novel (distinct words / word count)
float(len(emma_distinct_word)) / sum(emma_word_counts)
# Out:
# 0.04584265039497122

# %%
float(len(alice_distinct_word))/sum(alice_word_counts)
# Out:
# 0.0992437680888806

# %%
# (Optional, only for the very keen)
# Repeat the above analysis for all the Gutenberg samples
# Create a dataframe with the names of the novels, when they were written,
# whether they were for children, the lexical diversity and the average sentence length.
# Can you use logistic regression to predict the audience, based on the content?

# %% [markdown]
# ## Lab Part 2

# %%
# Make nltk.Text objects from the two novels
words = nltk.word_tokenize(emma)
emma = nltk.Text(words)

words1 = nltk.word_tokenize(alice)
alice = nltk.Text(words1)

# %%
# Does Jane Austen ever mention the word 'young' in Emma? What about Lewis Carroll?
emma.concordance('young')
# Out:
# Displaying 25 of 192 matches:
# marriage . A worthy employment for a young lady 's mind ! But if , which I rath
# e . '' `` Mr. Elton is a very pretty young man , to be sure , and a very good y
# g man , to be sure , and a very good young man , and I have a great regard for
# hildren of their own , nor any other young creature of equal kindred to care fo
# is fond report of him as a very fine young man had made Highbury feel a sort of
# formed a very favourable idea of the young man ; and such a pleasing attention
# Mr. Knightley ; and by Mr. Elton , a young man living alone without liking it ,
# ee of popularity for a woman neither young , handsome , rich , nor married . Mi
# nciples and new systems -- and where young ladies for enormous pay might be scr
# was no wonder that a train of twenty young couple now walked after her to churc
#  a long visit in the country to some young ladies who had been at school there
# f Harriet Smith 's being exactly the young friend she wanted -- exactly the som
# was a single man ; that there was no young Mrs. Martin , no wife in the case ;
# hout having any idea of his name . A young farmer , whether on horseback or on
# oubt of his being a very respectable young man . I know , indeed , that he is s
# ` Only four-and-twenty . That is too young to settle . His mother is perfectly
# if he could meet with a good sort of young woman in the same rank as his own ,
# w no alarming symptoms of love . The young man had been the first admirer , but
# neat , and he looked like a sensible young man , but his person had no other ad
# n life seem to allow it ; but if any young man were to set about copying him ,
# erable . On the contrary , I think a young man might be very safely recommended
# son fixed on by Emma for driving the young farmer out of Harriet 's head . She
# umoured , well-meaning , respectable young man , without any deficiency of usef
#  . And he was really a very pleasing young man , a young man whom any woman not
# really a very pleasing young man , a young man whom any woman not fastidious mi

# %%
alice.concordance('young')
# Out:
# Displaying 5 of 5 matches:
#  'Hold your tongue , Ma ! ' said the young Crab , a little snappishly . 'You 'r
# You are old , Father William , ' the young man said , 'And your hair has become
# m getting tired of this . I vote the young lady tells us a story . ' 'I 'm afra
#  ! ' said the Queen , 'and take this young lady to see the Mock Turtle , and to
# ears , but said nothing . 'This here young lady , ' said the Gryphon , 'she wan

# %%
# What are the common contexts for these words?
emma.common_contexts(['young'])
# Out:
# accomplished_woman worthy_man the_farmer the_man unexceptionable_man
# a_man so_as amiable_man pretty_woman the_are a_man's too_: pert_lawyer
# of_person alarming_man ,_cox a_woman too_; the_woman of_men

# %%
alice.common_contexts(['young'])
# Out:
# the_man here_lady the_crab the_lady this_lady

# %%
# Where does the word 'cat' appear in Alice and Wonderland?
#alice.dispersion_plot(['cat'])

# %% [markdown]
# ## Lab Part 3
#
# ###Stemming
# What:  Reduce a word to its base/stem form
#
# Why:   Often makes sense to treat multiple word forms the same way
#
# Notes: Uses a "simple" and fast rule-based approach
#        Output can be undesirable for irregular words
#        Stemmed words are usually not shown to users (used for analysis/indexing)
#        Some search engines treat words with the same stem as synonyms

# %%
# Create an English stemmer that uses the Snowball technique
# nltk.stem.snowball.SnowballStemmer
from nltk.stem.snowball import SnowballStemmer
snowball = SnowballStemmer('english')
snowball.stem('running')
# Out:
# u'run'

# %%
# Stem the following words: charge, charging, charged
snowball.stem('charge')
# Out:
# u'charg'

# %%
snowball.stem('charging')
# Out:
# u'charg'

# %%
snowball.stem('charged')
# Out:
# u'charg'

# %%
# Can you stem "words" with punctuation in them? Or which have no letters?
snowball.stem('swimming.')
# Out:
# u'swimming.'

# %%
snowball.stem('running!!')
# Out:
# u'running!!'

# %%
snowball.stem('123')
# Out:
# u'123'

# %%
# Create a new list of words from the novels by dropping out spurious non-words.
# You might find word_is_just_letters() helpful
def word_is_just_letters(word):
    import re
    return re.search('^[a-zA-Z]+', word)

# %%
# Stem all those words
#snowball.stem(word_is_just_letters('swimming.'))

# %%
# create two collections.Counter objects (one for each novel)
# so that you can easily count word stems. If you give
# the stemmed lists as an argument to constructor, 
# you can use .most_common(25) to get the top 25 tokens

# %% [markdown]
# ###Lemmatization / synset
# What:  Derive the canonical form ('lemma') of a word
#
# Why:   Can be better than stemming, reduces words to a 'normal' form.
#
# Notes: Uses a dictionary-based approach (slower than stemming)

# %%
nltk.corpus.wordnet
# Out:
# <WordNetCorpusReader in u'/Users/tianjiaoxie/nltk_data/corpora/wordnet'>

# %%
# What synsets does 'dog' belong to?
dog = nltk.corpus.wordnet.synsets('dog')
dog
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01'),
#  Synset('chase.v.01')]

# %%
# Which synset is the one you were thinking of?
dog[2]
# Out:
# Synset('dog.n.03')

# %%
# What is its hypernym?
dog[2].hypernyms()
# Out:
# [Synset('chap.n.01')]

# %%
wolves = nltk.corpus.wordnet.synsets('wolves')
wolves
# Out:
# [Synset('wolf.n.01'),
#  Synset('wolf.n.02'),
#  Synset('wolf.n.03'),
#  Synset('wolf.n.04'),
#  Synset('beast.n.02')]

# %%
# How closely related are those concepts (dogs and wolves)?
dog[2].path_similarity(wolves[4])
# Out:
# 0.125

# %%
# How closely related are the concepts 'dog' and 'novel'?
novel = nltk.corpus.wordnet.synsets('novel')
novel
# Out:
# [Synset('novel.n.01'),
#  Synset('novel.n.02'),
#  Synset('fresh.s.04'),
#  Synset('novel.s.02')]

# %%
dog[2].path_similarity(novel[1])
# Out:
# 0.08333333333333333

# %% [markdown]
# ## Lab Part 3 Part of speech tagging
#
# Other:
# - Analysing data with the Alchemy API
# - Further Reading

# %% [markdown]
# ###Part of Speech Tagging
#
# What:  Determine the part of speech of a word
#
# Why:   This can inform other methods and models such as Named Entity Recognition
#
# Notes: http://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %%
# Use nltk.pos_tag to parse a sentence

# %%
# (Optional for the enthusiastic)
# What verbs did Jane Austen use a lot of?

# %% [markdown]
# ## Lab Part 4
# ###Stopword Removal
#
# What:  Remove common words that will likely appear in any text
#
# Why:   They don't tell you much about your text

# %%
# most of top 25 stemmed tokens are "worthless"
c.most_common(25)

# %%
# view the list of stopwords
stopwords = nltk.corpus.stopwords.words('english')
sorted(stopwords)

# %%
##################
### Exercise  ####
##################


# Create a variable called stemmed_stops which is the 
# stemmed version of each stopword in stopwords
# Use the stemmer we used up above!

# Then create a list called stemmed_tokens_no_stop that 
# contains only the tokens in stemmed_tokens that aren't in 
# stemmed_stops

# Show the 25 most common stemmed non stop word tokens

# %% [markdown]
# ## Lab Part 5
# ###Named Entity Recognition
#
# What:  Automatically extract the names of people, places, organizations, etc.
#
# Why:   Can help you to identify "important" words
#
# Notes: Training NER classifier requires a lot of annotated training data
#        Should be trained on data relevant to your task
#        Stanford NER classifier is the "gold standard"

# %%
sentence = 'Ian is an instructor for General Assembly'

tokenized = nltk.word_tokenize(sentence)

tokenized

# %%
tagged = nltk.pos_tag(tokenized)

tagged

# %%
chunks = nltk.ne_chunk(tagged)

chunks

# %%
def extract_entities(text):
    entities = []
    # tokenize into sentences
    for sentence in nltk.sent_tokenize(text):
        # tokenize sentences into words
        # add part-of-speech tags
        # use NLTK's NER classifier
        chunks = nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sentence)))
        # parse the results
        entities.extend([chunk for chunk in chunks if hasattr(chunk, 'label')])
    return entities

for entity in extract_entities('Ian is an instructor for General Assembly'):
    print '[' + entity.label() + '] ' + ' '.join(c[0] for c in entity.leaves())

# %% [markdown]
# ## Lab Part 6
# ###Term Frequency - Inverse Document Frequency (TF-IDF)
#
# What:  Computes "relative frequency" that a word appears in a document
#            compared to its frequency across all documents
#
# Why:   More useful than "term frequency" for identifying "important" words in
#            each document (high frequency in that document, low frequency in
#            other documents)
#
# Notes: Used for search engine scoring, text summarization, document clustering
#
# How:
#     TF(t) = (Number of times term t appears in a document) / (Total number of terms in the document).
#     IDF(t) = log_e(Total number of documents / Number of documents with term t in it).

# %%
sample = ['Bob likes sports', 'Bob hates sports', 'Bob likes likes trees']

import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer()

# %%
# Each row represents a sentence
# Each column represents a word
vect.fit_transform(sample).toarray()
vect.get_feature_names()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
tfidf.fit_transform(sample).toarray()
tfidf.get_feature_names()

# %%
# the IDF of each word
idf = tfidf.idf_
print dict(zip(tfidf.get_feature_names(), idf))

# %%
###############
## Exercise ###
###############


# for each sentence in sample, find the most "interesting 
#words" by ordering their tfidf in ascending order

# %% [markdown]
# ## Lab Part 7
#
# ###LDA - Latent Dirichlet Allocation
#
# What:  Way of automatically discovering topics from sentences
#
# Why:   Much quicker than manually creating and identifying topic clusters

# %%
import lda

# Instantiate a count vectorizer with two additional parameters
vect = CountVectorizer(stop_words='english', ngram_range=[1,3]) 
sentences_train = vect.fit_transform(sentences)

# %%
# Instantiate an LDA model
model = lda.LDA(n_topics=10, n_iter=500)
model.fit(sentences_train) # Fit the model 
n_top_words = 10
topic_word = model.topic_word_
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vect.get_feature_names())[np.argsort(topic_dist)][:-n_top_words:-1]
    print('Topic {}: {}'.format(i, ', '.join(topic_words)))

# %%
# EXAMPLE: Automatically summarize a document


# corpus of 2000 movie reviews
from nltk.corpus import movie_reviews
reviews = [movie_reviews.raw(filename) for filename in movie_reviews.fileids()]

# %%
# create document-term matrix
tfidf = TfidfVectorizer(stop_words='english')
dtm = tfidf.fit_transform(reviews)
features = tfidf.get_feature_names()

# %%
import numpy as np

# %%
# find the most and least "interesting" sentences in a randomly selected review
def summarize():
    
    # choose a random movie review    
    review_id = np.random.randint(0, len(reviews))
    review_text = reviews[review_id]

    # we are going to score each sentence in the review for "interesting-ness"
    sent_scores = []
    # tokenize document into sentences
    for sentence in nltk.sent_tokenize(review_text):
        # exclude short sentences
        if len(sentence) > 6:
            score = 0
            token_count = 0
            # tokenize sentence into words
            tokens = nltk.word_tokenize(sentence)
            # compute sentence "score" by summing TFIDF for each word
            for token in tokens:
                if token in features:
                    score += dtm[review_id, features.index(token)]
                    token_count += 1
            # divide score by number of tokens
            sent_scores.append((score / float(token_count + 1), sentence))

    # lowest scoring sentences
    print '\nLOWEST:\n'
    for sent_score in sorted(sent_scores)[:3]:
        print sent_score[1]

    # highest scoring sentences
    print '\nHIGHEST:\n'
    for sent_score in sorted(sent_scores, reverse=True)[:3]:
        print sent_score[1]

# try it out!
summarize()

# %% [markdown]
# ## Lab Part 8

# %%
# TextBlob Demo: "Simplified Text Processing"
# Installation: pip install textblob
! pip install textblob

# %%
from textblob import TextBlob, Word

# %%
# identify words and noun phrases
blob = TextBlob('Greg and Thamali are instructors for General Assembly')
blob.words
blob.noun_phrases

# %%
# sentiment analysis
blob = TextBlob('I hate this horrible movie. This movie is not very good.')
blob.sentences
blob.sentiment.polarity
[sent.sentiment.polarity for sent in blob.sentences]

# %%
# sentiment subjectivity
TextBlob("I am a cool person").sentiment.subjectivity # Pretty subjective
TextBlob("I am a person").sentiment.subjectivity # Pretty objective
# different scores for essentially the same sentence
print TextBlob('Greg and Thamali are instructors for General Assembly in Sydney').sentiment.subjectivity

# %%
# singularize and pluralize
blob = TextBlob('Put away the dishes.')
[word.singularize() for word in blob.words]

# %%
[word.pluralize() for word in blob.words]

# %%
# spelling correction
blob = TextBlob('15 minuets late')
blob.correct()

# %%
# spellcheck
Word('parot').spellcheck()

# %%
# definitions
Word('bank').define()
Word('bank').define('v')

# %%
# translation and language identification
blob = TextBlob('Welcome to the classroom.')
blob.translate(to='es')
blob = TextBlob('Hola amigos')
blob.detect_language()
